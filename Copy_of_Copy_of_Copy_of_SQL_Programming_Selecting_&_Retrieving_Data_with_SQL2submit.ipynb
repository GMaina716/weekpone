# %% [markdown]
# <font color="green">*To start working on this notebook, or any other notebook that we will use in the Moringa Data Science Course, we will need to save our own copy of it. We can do this by clicking File > Save a Copy in Drive. We will then be able to make edits to our own copy of this notebook.*</font>

# %% [markdown]
# # Selecting & Retrieving Data with SQL

# %% [markdown]
# ## 1.1 Let's first connect to our Database

# %%
# We will first load the sql extension into our environment
#
# %load_ext sql

# Then connect to our in memory sqlite database
# NB: This database will cease to exist as soon as the database connection is closed
#
# %sql sqlite://
# Out:
# 'Connected: @None'

# %% [markdown]
# ## 1.2 Importing Data From a CSV File

# %%
# Importing the python libraries that we will need in this notebook
#
import csv
import pandas as pd

# %% [markdown]
# Then we will download our csv file from Interpol: [here](https://bit.ly/InterpolDataset) and World Cup [here](http://bit.ly/MSWorldCupData)  . Open the link and then on our browser  Click File > Save Page As > Save. Lastly, upload it to our current environment on Colaboratory by clicking View > Table of Contents > Files then Upload.  (NB: Do not load file from url)

# %%
# Loading the first table from a local CSV file
#
with open('Countries.csv','r') as f:
    Interpol = pd.read_csv(f, index_col=0, encoding='utf-8') 

# Then storing it in an SQL table of our in memory sqlite database
##%sql DROP TABLE Interpol;
# %sql PERSIST Interpol;
# Out:
#  * sqlite://
# 'Persisted interpol'

# %%
# We will load all the other dataset that we will need i.e. WorldCup
#
with open('WorldCup.csv','r') as f:
    WorldCup = pd.read_csv(f, index_col=0, encoding='utf-8') 
    
#%sql DROP TABLE if EXISTS WorldCup;
# %sql PERSIST WorldCup;
# Out:
#  * sqlite://
# 'Persisted worldcup'

# %%
# Let's preview our Interpol table so that we can understand it
# Try to understand all the attributes (i.e columns) since this
# will be one of the datasets that we will work with through this session
#
# %sql select * from Interpol limit 5;
# Out:
#  * sqlite://
# Done.
# [('Albania', 3, 3, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/al.gif'),
#  ('Angola', 0, 0, 1, 'Northern Africa', 'http://www.crwflags.com/fotw/images/a/ao.gif'),
#  ('Argentina', 2, 2, 1, 'South America', 'http://www.crwflags.com/fotw/images/a/ar.gif'),
#  ('Australia', 1, 1, 2, 'Oceania', 'http://www.crwflags.com/fotw/images/a/au.gif'),
#  ('Austria', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/at.gif')]

# %%
# Let's preview our Worldcup table so that we can also understand it.
# You will be acting as a football commentator performing research on the 
# world cup matches played in the past.
# 
# %sql SELECT * FROM WorldCup limit 5;
# Out:
#  * sqlite://
# Done.
# [(1930, '13 Jul 1930 - 15:00 ', 'Group 1', 'Pocitos', 'Montevideo ', 'France', 4, 1, 'Mexico', ' ', 4444.0, 3, 0, 'LOMBARDI Domingo (URU)', 'CRISTOPHE Henry (BEL)', 'REGO Gilberto (BRA)', 201, 1096, 'FRA', 'MEX'),
#  (1930, '13 Jul 1930 - 15:00 ', 'Group 4', 'Parque Central', 'Montevideo ', 'USA', 3, 0, 'Belgium', ' ', 18346.0, 2, 0, 'MACIAS Jose (ARG)', 'MATEUCCI Francisco (URU)', 'WARNKEN Alberto (CHI)', 201, 1090, 'USA', 'BEL'),
#  (1930, '14 Jul 1930 - 12:45 ', 'Group 2', 'Parque Central', 'Montevideo ', 'Yugoslavia', 2, 1, 'Brazil', ' ', 24059.0, 2, 0, 'TEJADA Anibal (URU)', 'VALLARINO Ricardo (URU)', 'BALWAY Thomas (FRA)', 201, 1093, 'YUG', 'BRA'),
#  (1930, '14 Jul 1930 - 14:50 ', 'Group 3', 'Pocitos', 'Montevideo ', 'Romania', 3, 1, 'Peru', ' ', 2549.0, 1, 0, 'WARNKEN Alberto (CHI)', 'LANGENUS Jean (BEL)', 'MATEUCCI Francisco (URU)', 201, 1098, 'ROU', 'PER'),
#  (1930, '15 Jul 1930 - 16:00 ', 'Group 1', 'Parque Central', 'Montevideo ', 'Argentina', 1, 0, 'France', ' ', 23409.0, 0, 0, 'REGO Gilberto (BRA)', 'SAUCEDO Ulises (BOL)', 'RADULESCU Constantin (ROU)', 201, 1085, 'ARG', 'FRA')]

# %% [markdown]
# ## 1.3 Select Single Columns

# %%
# Example 1
# This is how we will select a single column (i.e. the Country Column) from the Interpol Dataset
#
# %%sql
SELECT Country FROM Interpol;
# Out:
#  * sqlite://
# Done.
# [('Albania',),
#  ('Angola',),
#  ('Argentina',),
#  ('Australia',),
#  ('Austria',),
#  ('Bangladesh',),
#  ('Belarus',),
#  ('Belgium',),
#  ('Belize',),
#  ('Bolivia',),
#  ('Botswana',),
#  ('Brazil',),
#  ('Cambodia',),
#  ('Canada',),
#  ('Cayman Islands',),
#  ('Chile',),
#  ('Colombia',),
#  ('Congo',),
#  ('Costa Rica',),
#  ('Croatia',),
#  ('Curaçao',),
#  ('Czech Republic',),
#  ('Denmark',),
#  ('Dominican Republic',),
#  ('Ecuador',),
#  ('El Salvador',),
#  ('Estonia',),
#  ('Finland',),
#  ('France',),
#  ('Georgia, Asia',),
#  ('Germany',),
#  ('Greece',),
#  ('Honduras',),
#  ('Hungary',),
#  ('India',),
#  ('Indonesia',),
#  ('Iraq',),
#  ('Ireland',),
#  ('Italy',),
#  ('Kenya',),
#  ('Lesotho',),
#  ('Lithuania',),
#  ('Macedonia',),
#  ('Mali',),
#  ('Malta',),
#  ('Mexico',),
#  ('Montenegro',),
#  ('Morocco',),
#  ('Mozambique',),
#  ('Namibia',),
#  ('New Zealand',),
#  ('Nicaragua',),
#  ('Norway',),
#  ('Pakistan',),
#  ('Panama',),
#  ('Paraguay',),
#  ('Peru',),
#  ('Poland',),
#  ('Qatar',),
#  ('Romania',),
#  ('Russia',),
#  ('Serbia',),
#  ('Slovakia',),
#  ('Somalia',),
#  ('South Africa',),
#  ('Spain',),
#  ('Swaziland',),
#  ('Sweden',),
#  ('Tanzania',),
#  ('The Netherlands',),
#  ('Turkey',),
#  ('Ukraine',),
#  ('United Kingdom',),
#  ('United States',),
#  ('Uruguay',),
#  ('Venezuela',),
#  ('Zambia',),
#  ('Zimbabwe',)]

# %%
# Example 2
# Let's get the European countries without National fugitives  
# 
# %%sql
SELECT DISTINCT Country FROM Interpol
WHERE "National Fugitives" = 0 AND Region = "Europe"
# Out:
#  * sqlite://
# Done.
# [('Belgium',),
#  ('Denmark',),
#  ('France',),
#  ('Macedonia',),
#  ('Malta',),
#  ('Norway',),
#  ('Serbia',),
#  ('Turkey',)]

# %%
# Example 3
# Let's select the regions without National fugitives
#
# %%sql
SELECT Region FROM Interpol
WHERE "National Fugitives" = 0
# Out:
#  * sqlite://
# Done.
# [('Northern Africa',),
#  ('Europe',),
#  ('South America',),
#  ('Southern Africa',),
#  ('Asia',),
#  ('Central America',),
#  ('Sub Saharan Africa',),
#  ('Central America',),
#  ('Central America',),
#  ('Europe',),
#  ('South America',),
#  ('Europe',),
#  ('Asia',),
#  ('Southern Africa',),
#  ('Europe',),
#  ('Sub Saharan Africa',),
#  ('Europe',),
#  ('Southern Africa',),
#  ('Southern Africa',),
#  ('Oceania',),
#  ('Europe',),
#  ('Central America',),
#  ('Asia',),
#  ('Europe',),
#  ('Sub Saharan Africa',),
#  ('Europe',),
#  ('South America',),
#  ('Southern Africa',)]

# %% [markdown]
# ### <font color="green"> 1.3 Challenges</font>

# %%
# Challenge 1
# Using the Interpol Dataset, let us get the Northern African countries that  
# do not host possible fugitives or captured fugitives
# 
# %%sql
--SELECT * FROM Interpol;
SELECT "Country" FROM Interpol WHERE "Region"="Northern Africa" AND "Possible Hosted Fugitives / Captured Fugitives"=0;
# Out:
#  * sqlite://
# Done.
# []

# %%
# Challenge 2
# Using the Interpol Dataset, let us get the countries without a National fugitive and a Wanted fugitive
#
# %%sql
--SELECT * FROM Interpol;
SELECT "Country" FROM Interpol WHERE "National Fugitives"=0 AND "Wanted Fugitives"=0;
# Out:
#  * sqlite://
# Done.
# [('Angola',),
#  ('Bolivia',),
#  ('Cambodia',),
#  ('Cayman Islands',),
#  ('Congo',),
#  ('Ecuador',),
#  ('France',),
#  ('India',),
#  ('Lesotho',),
#  ('Macedonia',),
#  ('Malta',),
#  ('Mozambique',),
#  ('Namibia',),
#  ('New Zealand',),
#  ('Panama',),
#  ('Qatar',),
#  ('Serbia',),
#  ('Turkey',),
#  ('Zimbabwe',)]

# %%
# Challenge 3
# Using the Interpol Dataset, which european countries have 3 National Fugitives
# 
# %%sql
--SELECT * FROM Interpol;
SELECT "Country" FROM Interpol WHERE Region="Europe" AND "National Fugitives"=3;
# Out:
#  * sqlite://
# Done.
# [('Albania',), ('Czech Republic',), ('Montenegro',)]

# %% [markdown]
# ## 1.4 Multiple columns

# %%
# Example 1
# Using the Interpol dataset, we would like to know the countries and their respective No. of Captured fugitives.
#
# %%sql
SELECT Country, "Possible Hosted Fugitives / Captured Fugitives" FROM Interpol;
# Out:
#  * sqlite://
# Done.
# [('Albania', 0),
#  ('Angola', 1),
#  ('Argentina', 1),
#  ('Australia', 2),
#  ('Austria', 0),
#  ('Bangladesh', 1),
#  ('Belarus', 0),
#  ('Belgium', 0),
#  ('Belize', 0),
#  ('Bolivia', 2),
#  ('Botswana', 1),
#  ('Brazil', 3),
#  ('Cambodia', 1),
#  ('Canada', 2),
#  ('Cayman Islands', 1),
#  ('Chile', 0),
#  ('Colombia', 1),
#  ('Congo', 1),
#  ('Costa Rica', 2),
#  ('Croatia', 1),
#  ('Curaçao', 0),
#  ('Czech Republic', 0),
#  ('Denmark', 0),
#  ('Dominican Republic', 2),
#  ('Ecuador', 1),
#  ('El Salvador', 0),
#  ('Estonia', 0),
#  ('Finland', 3),
#  ('France', 7),
#  ('Georgia, Asia', 0),
#  ('Germany', 3),
#  ('Greece', 3),
#  ('Honduras', 1),
#  ('Hungary', 0),
#  ('India', 1),
#  ('Indonesia', 0),
#  ('Iraq', 1),
#  ('Ireland', 0),
#  ('Italy', 3),
#  ('Kenya', 2),
#  ('Lesotho', 1),
#  ('Lithuania', 0),
#  ('Macedonia', 1),
#  ('Mali', 0),
#  ('Malta', 1),
#  ('Mexico', 6),
#  ('Montenegro', 1),
#  ('Morocco', 3),
#  ('Mozambique', 2),
#  ('Namibia', 1),
#  ('New Zealand', 1),
#  ('Nicaragua', 0),
#  ('Norway', 0),
#  ('Pakistan', 2),
#  ('Panama', 2),
#  ('Paraguay', 1),
#  ('Peru', 0),
#  ('Poland', 3),
#  ('Qatar', 1),
#  ('Romania', 0),
#  ('Russia', 3),
#  ('Serbia', 1),
#  ('Slovakia', 0),
#  ('Somalia', 0),
#  ('South Africa', 4),
#  ('Spain', 13),
#  ('Swaziland', 1),
#  ('Sweden', 1),
#  ('Tanzania', 2),
#  ('The Netherlands', 8),
#  ('Turkey', 1),
#  ('Ukraine', 1),
#  ('United Kingdom', 7),
#  ('United States', 6),
#  ('Uruguay', 1),
#  ('Venezuela', 0),
#  ('Zambia', 2),
#  ('Zimbabwe', 2)]

# %%
# Example 2
# Using the world cup dataset, let's get teams that played in the matches with their respective referee
# 
# %%sql
SELECT "Home_Team_Name", "Away_Team_Name", Referee FROM WorldCup;
# Out:
#  * sqlite://
# Done.
# [('France', 'Mexico', 'LOMBARDI Domingo (URU)'),
#  ('USA', 'Belgium', 'MACIAS Jose (ARG)'),
#  ('Yugoslavia', 'Brazil', 'TEJADA Anibal (URU)'),
#  ('Romania', 'Peru', 'WARNKEN Alberto (CHI)'),
#  ('Argentina', 'France', 'REGO Gilberto (BRA)'),
#  ('Chile', 'Mexico', 'CRISTOPHE Henry (BEL)'),
#  ('Yugoslavia', 'Bolivia', 'MATEUCCI Francisco (URU)'),
#  ('USA', 'Paraguay', 'MACIAS Jose (ARG)'),
#  ('Uruguay', 'Peru', 'LANGENUS Jean (BEL)'),
#  ('Chile', 'France', 'TEJADA Anibal (URU)'),
#  ('Argentina', 'Mexico', 'SAUCEDO Ulises (BOL)'),
#  ('Brazil', 'Bolivia', 'BALWAY Thomas (FRA)'),
#  ('Paraguay', 'Belgium', 'VALLARINO Ricardo (URU)'),
#  ('Uruguay', 'Romania', 'REGO Gilberto (BRA)'),
#  ('Argentina', 'Chile', 'LANGENUS Jean (BEL)'),
#  ('Argentina', 'USA', 'LANGENUS Jean (BEL)'),
#  ('Uruguay', 'Yugoslavia', 'REGO Gilberto (BRA)'),
#  ('Uruguay', 'Argentina', 'LANGENUS Jean (BEL)'),
#  ('Austria', 'France', 'VAN MOORSEL Johannes (NED)'),
#  ('Hungary', 'Egypt', 'BARLASSINA Rinaldo (ITA)'),
#  ('Switzerland', 'Netherlands', 'EKLIND Ivan (SWE)'),
#  ('Sweden', 'Argentina', 'BRAUN Eugen (AUT)'),
#  ('Germany', 'Belgium', 'MATTEA Francesco (ITA)'),
#  ('Spain', 'Brazil', 'BIRLEM Alfred (GER)'),
#  ('Italy', 'USA', 'MERCET Rene (SUI)'),
#  ('Czechoslovakia', 'Romania', 'LANGENUS Jean (BEL)'),
#  ('Czechoslovakia', 'Switzerland', 'BERANEK Alois (AUT)'),
#  ('Germany', 'Sweden', 'BARLASSINA Rinaldo (ITA)'),
#  ('Italy', 'Spain', 'BAERT Louis (BEL)'),
#  ('Austria', 'Hungary', 'MATTEA Francesco (ITA)'),
#  ('Italy', 'Spain', 'MERCET Rene (SUI)'),
#  ('Italy', 'Austria', 'EKLIND Ivan (SWE)'),
#  ('Czechoslovakia', 'Germany', 'BARLASSINA Rinaldo (ITA)'),
#  ('Germany', 'Austria', 'CARRARO Albino (ITA)'),
#  ('Italy', 'Czechoslovakia', 'EKLIND Ivan (SWE)'),
#  ('Switzerland', 'Germany', 'LANGENUS Jean (BEL)'),
#  ('Hungary', 'Dutch East Indies', 'CONRIE Roger (FRA)'),
#  ('France', 'Belgium', 'WUETHRICH Hans (SUI)'),
#  ('Cuba', 'Romania', 'SCARPI Giuseppe (ITA)'),
#  ('Italy', 'Norway', 'BERANEK Alois (AUT)'),
#  ('Brazil', 'Poland', 'EKLIND Ivan (SWE)'),
#  ('Czechoslovakia', 'Netherlands', 'LECLERCQ Lucien (FRA)'),
#  ('Cuba', 'Romania', 'BIRLEM Alfred (GER)'),
#  ('Switzerland', 'Germany', 'EKLIND Ivan (SWE)'),
#  ('Brazil', 'Czechoslovakia', 'VON HERTZKA Pal (HUN)'),
#  ('Hungary', 'Switzerland', 'BARLASSINA Rinaldo (ITA)'),
#  ('Sweden', 'Cuba', 'KRIST Gustav (TCH)'),
#  ('Italy', 'France', 'BAERT Louis (BEL)'),
#  ('Brazil', 'Czechoslovakia', 'CAPDEVILLE Georges (FRA)'),
#  ('Hungary', 'Sweden', 'LECLERCQ Lucien (FRA)'),
#  ('Italy', 'Brazil', 'WUETHRICH Hans (SUI)'),
#  ('Brazil', 'Sweden', 'LANGENUS Jean (BEL)'),
#  ('Italy', 'Hungary', 'CAPDEVILLE Georges (FRA)'),
#  ('Brazil', 'Mexico', 'READER George (ENG)'),
#  ('England', 'Chile', 'VAN DER MEER Karel (NED)'),
#  ('Spain', 'USA', 'VIANA Mario (BRA)'),
#  ('Sweden', 'Italy', 'LUTZ Jean (SUI)'),
#  ('Yugoslavia', 'Switzerland', 'GALEATI Giovanni (ITA)'),
#  ('Brazil', 'Switzerland', 'AZON ROMA Ramon (ESP)'),
#  ('Yugoslavia', 'Mexico', 'LEAFE Reginald (ENG)'),
#  ('Spain', 'Chile', 'MALCHER Alberto (BRA)'),
#  ('Sweden', 'Paraguay', 'MITCHELL Robert (SCO)'),
#  ('USA', 'England', 'DATTILO Generoso (ITA)'),
#  ('Brazil', 'Yugoslavia', 'GRIFFITHS Benjamin (WAL)'),
#  ('Spain', 'England', 'GALEATI Giovanni (ITA)'),
#  ('Italy', 'Paraguay', 'ELLIS Arthur (ENG)'),
#  ('Uruguay', 'Bolivia', 'READER George (ENG)'),
#  ('Switzerland', 'Mexico', 'EKLIND Ivan (SWE)'),
#  ('Chile', 'USA', 'GARDELLI Mario (BRA)'),
#  ('Uruguay', 'Spain', 'GRIFFITHS Benjamin (WAL)'),
#  ('Brazil', 'Sweden', 'ELLIS Arthur (ENG)'),
#  ('Brazil', 'Spain', 'LEAFE Reginald (ENG)'),
#  ('Uruguay', 'Sweden', 'GALEATI Giovanni (ITA)'),
#  ('Sweden', 'Spain', 'VAN DER MEER Karel (NED)'),
#  ('Uruguay', 'Brazil', 'READER George (ENG)'),
#  ('Uruguay', 'Czechoslovakia', 'ELLIS Arthur (ENG)'),
#  ('Austria', 'Scotland', 'FRANKEN Laurent (BEL)'),
#  ('Brazil', 'Mexico', 'WYSSLING Paul (SUI)'),
#  ('Yugoslavia', 'France', 'GRIFFITHS Benjamin (WAL)'),
#  ('Germany FR', 'Turkey', 'DA COSTA VIEIRA Jose (POR)'),
#  ('Hungary', 'Korea Republic', 'VINCENTI Raymond (FRA)'),
#  ('England', 'Belgium', 'SCHMETZER Emil (FRG)'),
#  ('Switzerland', 'Italy', 'VIANA Mario (BRA)'),
#  ('Uruguay', 'Scotland', 'ORLANDINI Vincenzo (ITA)'),
#  ('Austria', 'Czechoslovakia', 'STEFANOVIC Vasa (YUG)'),
#  ('France', 'Mexico', 'ASENSI Manuel (ESP)'),
#  ('Brazil', 'Yugoslavia', 'FAULTLESS Charlie (SCO)'),
#  ('Hungary', 'Germany FR', 'LING William (ENG)'),
#  ('Turkey', 'Korea Republic', 'MARINO Esteban (URU)'),
#  ('England', 'Switzerland', 'ZSOLT Istvan (HUN)'),
#  ('Italy', 'Belgium', 'STEINER Carl (AUT)'),
#  ('Germany FR', 'Turkey', 'VINCENTI Raymond (FRA)'),
#  ('Switzerland', 'Italy', 'GRIFFITHS Benjamin (WAL)'),
#  ('Uruguay', 'England', 'STEINER Carl (AUT)'),
#  ('Austria', 'Switzerland', 'FAULTLESS Charlie (SCO)'),
#  ('Germany FR', 'Yugoslavia', 'ZSOLT Istvan (HUN)'),
#  ('Hungary', 'Brazil', 'ELLIS Arthur (ENG)'),
#  ('Germany FR', 'Austria', 'ORLANDINI Vincenzo (ITA)'),
#  ('Hungary', 'Uruguay', 'GRIFFITHS Benjamin (WAL)'),
#  ('Austria', 'Uruguay', 'WYSSLING Paul (SUI)'),
#  ('Germany FR', 'Hungary', 'LING William (ENG)'),
#  ('Sweden', 'Mexico', 'LATYCHEV Nikolaj (URS)'),
#  ('Soviet Union', 'England', 'ZSOLT Istvan (HUN)'),
#  ('Argentina', 'Germany FR', 'LEAFE Reginald (ENG)'),
#  ('Hungary', 'Wales', 'CODESAL Jose Maria (URU)'),
#  ('France', 'Paraguay', 'GARDEAZABAL Juan (ESP)'),
#  ('Yugoslavia', 'Scotland', 'WYSSLING Paul (SUI)'),
#  ('Brazil', 'Austria', 'GUIGUE Maurice (FRA)'),
#  ('Northern Ireland', 'Czechoslovakia', 'SEIPELT Fritz (AUT)'),
#  ('Brazil', 'England', 'DUSCH Albert (GER)'),
#  ('Mexico', 'Wales', 'LEMESIC Leo (YUG)'),
#  ('Paraguay', 'Scotland', 'ORLANDINI Vincenzo (ITA)'),
#  ('Yugoslavia', 'France', 'GRIFFITHS Benjamin (WAL)'),
#  ('Soviet Union', 'Austria', 'JORGENSEN Carl Frederik (DEN)'),
#  ('Germany FR', 'Czechoslovakia', 'ELLIS Arthur (ENG)'),
#  ('Argentina', 'Northern Ireland', 'AHLNER Sten (SWE)'),
#  ('Sweden', 'Hungary', 'MOWAT Jack (SCO)'),
#  ('Sweden', 'Wales', 'VAN NUFFEL Lucien (BEL)'),
#  ('Brazil', 'Soviet Union', 'GUIGUE Maurice (FRA)'),
#  ('Germany FR', 'Northern Ireland', 'FERNANDES CAMPOS Joaquim (POR)'),
#  ('Hungary', 'Mexico', 'ERIKSSON Arne (FIN)'),
#  ('Paraguay', 'Yugoslavia', 'MACKO Martin (TCH)'),
#  ('France', 'Scotland', 'BROZZI Juan (ARG)'),
#  ('England', 'Austria', 'BRONKHORST Jan (NED)'),
#  ('Czechoslovakia', 'Argentina', 'ELLIS Arthur (ENG)'),
#  ('Soviet Union', 'England', 'DUSCH Albert (GER)'),
#  ('Northern Ireland', 'Czechoslovakia', 'GUIGUE Maurice (FRA)'),
#  ('Wales', 'Hungary', 'LATYCHEV Nikolaj (URS)'),
#  ('Brazil', 'Wales', 'SEIPELT Fritz (AUT)'),
#  ('Germany FR', 'Yugoslavia', 'WYSSLING Paul (SUI)'),
#  ('Sweden', 'Soviet Union', 'LEAFE Reginald (ENG)'),
#  ('France', 'Northern Ireland', 'GARDEAZABAL Juan (ESP)'),
#  ('Sweden', 'Germany FR', 'ZSOLT Istvan (HUN)'),
#  ('Brazil', 'France', 'GRIFFITHS Benjamin (WAL)'),
#  ('France', 'Germany FR', 'BROZZI Juan (ARG)'),
#  ('Brazil', 'Sweden', 'GUIGUE Maurice (FRA)'),
#  ('Uruguay', 'Colombia', 'DOROGI Andor (HUN)'),
#  ('Brazil', 'Mexico', 'DIENST Gottfried (SUI)'),
#  ('Argentina', 'Bulgaria', 'GARDEAZABAL Juan (ESP)'),
#  ('Chile', 'Switzerland', 'ASTON Ken (ENG)'),
#  ('Soviet Union', 'Yugoslavia', 'DUSCH Albert (GER)'),
#  ('Czechoslovakia', 'Spain', 'STEINER Carl (AUT)'),
#  ('Hungary', 'England', 'HORN Leo (NED)'),
#  ('Germany FR', 'Italy', 'DAVIDSON Bob (SCO)'),
#  ('Yugoslavia', 'Uruguay', 'GALBA Karol (TCH)'),
#  ('Brazil', 'Czechoslovakia', 'SCHWINTE Pierre (FRA)'),
#  ('England', 'Argentina', 'LATYCHEV Nikolaj (URS)'),
#  ('Chile', 'Italy', 'ASTON Ken (ENG)'),
#  ('Soviet Union', 'Colombia', 'ETZEL FILHO Joao (BRA)'),
#  ('Spain', 'Mexico', 'TESANIC Branko (YUG)'),
#  ('Hungary', 'Bulgaria', 'GARDEAZABAL Juan (ESP)'),
#  ('Germany FR', 'Switzerland', 'HORN Leo (NED)'),
#  ('Soviet Union', 'Uruguay', 'JONNI Cesare (ITA)'),
#  ('Brazil', 'Spain', 'BUSTAMANTE Sergio (CHI)'),
#  ('Hungary', 'Argentina', 'YAMASAKI MALDONADO Arturo (MEX)'),
#  ('Germany FR', 'Chile', 'DAVIDSON Bob (SCO)'),
#  ('Yugoslavia', 'Colombia', 'ROBLES Carlos (CHI)'),
#  ('Mexico', 'Czechoslovakia', 'DIENST Gottfried (SUI)'),
#  ('England', 'Bulgaria', 'BLAVIER Arthur (BEL)'),
#  ('Italy', 'Switzerland', 'LATYCHEV Nikolaj (URS)'),
#  ('Chile', 'Soviet Union', 'HORN Leo (NED)'),
#  ('Brazil', 'England', 'SCHWINTE Pierre (FRA)'),
#  ('Czechoslovakia', 'Hungary', 'LATYCHEV Nikolaj (URS)'),
#  ('Yugoslavia', 'Germany FR', 'YAMASAKI MALDONADO Arturo (MEX)'),
#  ('Czechoslovakia', 'Yugoslavia', 'DIENST Gottfried (SUI)'),
#  ('Brazil', 'Chile', 'YAMASAKI MALDONADO Arturo (MEX)'),
#  ('Chile', 'Yugoslavia', 'GARDEAZABAL Juan (ESP)'),
#  ('Brazil', 'Czechoslovakia', 'LATYCHEV Nikolaj (URS)'),
#  ('England', 'Uruguay', 'ZSOLT Istvan (HUN)'),
#  ('Germany FR', 'Switzerland', 'PHILLIPS Hugh (SCO)'),
#  ('Brazil', 'Bulgaria', 'TSCHENSCHER Kurt (GER)'),
#  ('Soviet Union', 'Korea DPR', 'GARDEAZABAL Juan (ESP)'),
#  ('France', 'Mexico', 'ASHKENAZI Menachem (ISR)'),
#  ('Portugal', 'Hungary', 'CALLAGHAN Leo (WAL)'),
#  ('Argentina', 'Spain', 'RUMENTCHEV Dimitar (BUL)'),
#  ('Italy', 'Chile', 'DIENST Gottfried (SUI)'),
#  ('Uruguay', 'France', 'GALBA Karol (TCH)'),
#  ('Spain', 'Switzerland', 'BAKHRAMOV Tofik (URS)'),
#  ('Hungary', 'Brazil', 'DAGNALL Kenneth (ENG)'),
#  ('Korea DPR', 'Chile', 'KANDIL Aly Hussein (EGY)'),
#  ('Portugal', 'Bulgaria', 'CODESAL Jose Maria (URU)'),
#  ('Germany FR', 'Argentina', 'ZECEVIC Konstantin (YUG)'),
#  ('Soviet Union', 'Italy', 'KREITLEIN Rudolf (GER)'),
#  ('England', 'Mexico', 'LO BELLO Concetto (ITA)'),
#  ('Uruguay', 'Mexico', 'LOEOEW Bertil (SWE)'),
#  ('Argentina', 'Switzerland', 'FERNANDES CAMPOS Joaquim (POR)'),
#  ('Portugal', 'Brazil', 'McCABE George (ENG)'),
#  ('Korea DPR', 'Italy', 'SCHWINTE Pierre (FRA)'),
#  ('England', 'France', 'YAMASAKI MALDONADO Arturo (MEX)'),
#  ('Hungary', 'Bulgaria', 'GOICOECHEA Roberto (ARG)'),
#  ('Germany FR', 'Spain', 'MARQUES Armando (BRA)'),
#  ('Soviet Union', 'Chile', 'ADAIR John (NIR)'),
#  ('England', 'Argentina', 'KREITLEIN Rudolf (GER)'),
#  ('Germany FR', 'Uruguay', 'FINNEY Jim (ENG)'),
#  ('Soviet Union', 'Hungary', 'GARDEAZABAL Juan (ESP)'),
#  ('Portugal', 'Korea DPR', 'ASHKENAZI Menachem (ISR)'),
#  ('Germany FR', 'Soviet Union', 'LO BELLO Concetto (ITA)'),
#  ('England', 'Portugal', 'SCHWINTE Pierre (FRA)'),
#  ('Portugal', 'Soviet Union', 'DAGNALL Kenneth (ENG)'),
#  ('England', 'Germany FR', 'DIENST Gottfried (SUI)'),
#  ('Mexico', 'Soviet Union', 'TSCHENSCHER Kurt (GER)'),
#  ('Uruguay', 'Israel', 'DAVIDSON Bob (SCO)'),
#  ('Peru', 'Bulgaria', 'SBARDELLA Antonio (ITA)'),
#  ('England', 'Romania', 'LORAUX Vital (BEL)'),
#  ('Italy', 'Sweden', 'TAYLOR John (ENG)'),
#  ('Germany FR', 'Morocco', 'VAN RAVENS Laurens (NED)'),
#  ('Brazil', 'Czechoslovakia', 'BARRETO RUIZ Ramon (URU)'),
#  ('Belgium', 'El Salvador', 'RADULESCU Andrei (ROU)'),
#  ('Uruguay', 'Italy', 'GLOECKNER Rudolf (GDR)'),
#  ('Peru', 'Morocco', 'BAKHRAMOV Tofik (URS)'),
#  ('Romania', 'Czechoslovakia', 'DE LEO Diego (MEX)'),
#  ('Soviet Union', 'Belgium', 'SCHEURER Ruedi (SUI)'),
#  ('Sweden', 'Israel', 'TAREKEGN Seyoum (ETH)'),
#  ('Germany FR', 'Bulgaria', 'ORTIZ DE MENDIBIL Jose Maria (ESP)'),
#  ('Brazil', 'England', 'KLEIN Abraham (ISR)'),
#  ('Mexico', 'El Salvador', 'KANDIL Aly Hussein (EGY)'),
#  ('Sweden', 'Uruguay', 'LANDAUER Henry (USA)'),
#  ('Germany FR', 'Peru', 'AGUILAR ELIZALDE Abel (MEX)'),
#  ('Brazil', 'Romania', 'MARSCHALL Ferdinand (AUT)'),
#  ('Soviet Union', 'El Salvador', 'HORMAZABAL DIAZ Rafael (CHI)'),
#  ('Italy', 'Israel', 'DE MORAES Ayrton Vieira (BRA)'),
#  ('Bulgaria', 'Morocco', 'SALDANHA RIBEIRO Antonio (POR)'),
#  ('England', 'Czechoslovakia', 'MACHIN Roger (FRA)'),
#  ('Mexico', 'Belgium', 'COEREZZA Norberto Angel (ARG)'),
#  ('Italy', 'Mexico', 'SCHEURER Ruedi (SUI)'),
#  ('Germany FR', 'England', 'COEREZZA Norberto Angel (ARG)'),
#  ('Brazil', 'Peru', 'LORAUX Vital (BEL)'),
#  ('Uruguay', 'Soviet Union', 'VAN RAVENS Laurens (NED)'),
#  ('Brazil', 'Uruguay', 'ORTIZ DE MENDIBIL Jose Maria (ESP)'),
#  ('Italy', 'Germany FR', 'YAMASAKI MALDONADO Arturo (MEX)'),
#  ('Germany FR', 'Uruguay', 'SBARDELLA Antonio (ITA)'),
#  ('Brazil', 'Italy', 'GLOECKNER Rudolf (GDR)'),
#  ('Brazil', 'Yugoslavia', 'SCHEURER Ruedi (SUI)'),
#  ('Germany FR', 'Chile', 'BABACAN Dogan (TUR)'),
#  ('German DR', 'Australia', 'NDIAYE Youssou (SEN)'),
#  ('Zaire', 'Scotland', 'SCHULENBURG Gerhard (GER)'),
#  ('Uruguay', 'Netherlands', 'PALOTAI Karoly (HUN)'),
#  ('Sweden', 'Bulgaria', 'PEREZ NUNEZ Edison A. (PER)'),
#  ('Italy', 'Haiti', 'LLOBREGAT Vicente (VEN)'),
#  ('Poland', 'Argentina', 'THOMAS Clive (WAL)'),
#  ('Australia', 'Germany FR', 'KAMEL Mahmoud (EGY)'),
#  ('Scotland', 'Brazil', 'VAN GEMERT Arie (NED)'),
#  ('Chile', 'German DR', 'ANGONESE Aurelio (ITA)'),
#  ('Yugoslavia', 'Zaire', 'DELGADO Omar (COL)'),
#  ('Netherlands', 'Sweden', 'WINSEMANN Werner (CAN)'),
#  ('Bulgaria', 'Uruguay', 'TAYLOR John (ENG)'),
#  ('Haiti', 'Poland', 'SUPPIAH George (SIN)'),
#  ('Argentina', 'Italy', 'KAZAKOV Pavel (URS)'),
#  ('Scotland', 'Yugoslavia', 'GONZALEZ ARCHUNDIA Alfonso (MEX)'),
#  ('Australia', 'Chile', 'NAMDAR Jafar (IRN)'),
#  ('Zaire', 'Brazil', 'RAINEA Nicolae (ROU)'),
#  ('German DR', 'Germany FR', 'BARRETO RUIZ Ramon (URU)'),
#  ('Bulgaria', 'Netherlands', 'BOSKOVIC Tony (AUS)'),
#  ('Argentina', 'Haiti', 'SANCHEZ IBANEZ Pablo (ESP)'),
#  ('Sweden', 'Uruguay', 'LINEMAYR Erich (AUT)'),
#  ('Poland', 'Italy', 'WEYLAND Hans Joachim (FRG)'),
#  ('Yugoslavia', 'Germany FR', 'MARQUES Armando (BRA)'),
#  ('Brazil', 'German DR', 'THOMAS Clive (WAL)'),
#  ('Netherlands', 'Argentina', 'DAVIDSON Bob (SCO)'),
#  ('Sweden', 'Poland', 'BARRETO RUIZ Ramon (URU)'),
#  ('Argentina', 'Brazil', 'LORAUX Vital (BEL)'),
#  ('Poland', 'Yugoslavia', 'GLOECKNER Rudolf (GDR)'),
#  ('German DR', 'Netherlands', 'SCHEURER Ruedi (SUI)'),
#  ('Germany FR', 'Sweden', 'KAZAKOV Pavel (URS)'),
#  ('Poland', 'Germany FR', 'LINEMAYR Erich (AUT)'),
#  ('Netherlands', 'Brazil', 'TSCHENSCHER Kurt (GER)'),
#  ('Argentina', 'German DR', 'TAYLOR John (ENG)'),
#  ('Sweden', 'Yugoslavia', 'PESTARINO Luis (ARG)'),
#  ('Brazil', 'Poland', 'ANGONESE Aurelio (ITA)'),
#  ('Netherlands', 'Germany FR', 'TAYLOR John (ENG)'),
#  ('Germany FR', 'Poland', 'COEREZZA Norberto Angel (ARG)'),
#  ('Italy', 'France', 'RAINEA Nicolae (ROU)'),
#  ('Tunisia', 'Mexico', 'GORDON John (SCO)'),
#  ('Argentina', 'Hungary', 'GARRIDO Antonio (POR)'),
#  ('Sweden', 'Brazil', 'THOMAS Clive (WAL)'),
#  ('Austria', 'Spain', 'PALOTAI Karoly (HUN)'),
#  ('Peru', 'Scotland', 'ERIKSSON Ulf (SWE)'),
#  ('Netherlands', 'IR Iran', 'GONZALEZ ARCHUNDIA Alfonso (MEX)'),
#  ('Italy', 'Hungary', 'BARRETO RUIZ Ramon (URU)'),
#  ('Poland', 'Tunisia', 'MARTINEZ Angel (ESP)'),
#  ('Germany FR', 'Mexico', 'BOUZO Farouk (SYR)'),
#  ('Argentina', 'France', 'DUBACH Jean (SUI)'),
#  ('Brazil', 'Spain', 'GONELLA Sergio (ITA)'),
#  ('Austria', 'Sweden', 'CORVER Charles (NED)'),
#  ('Scotland', 'IR Iran', 'NDIAYE Youssou (SEN)'),
#  ('Netherlands', 'Peru', 'PROKOP Adolf (GDR)'),
#  ('France', 'Hungary', 'COELHO Arnaldo (BRA)'),
#  ('Poland', 'Mexico', 'NAMDAR Jafar (IRN)'),
#  ('Germany FR', 'Tunisia', 'OROZCO GUERRERO Cesar (PER)'),
#  ('Italy', 'Argentina', 'KLEIN Abraham (ISR)'),
#  ('Brazil', 'Austria', 'WURTZ Robert (FRA)'),
#  ('Spain', 'Sweden', 'BIWERSI Ferdinand (GER)'),
#  ('Peru', 'Iran', 'JARGUZ Alojzy (POL)'),
#  ('Scotland', 'Netherlands', 'LINEMAYR Erich (AUT)'),
#  ('Germany FR', 'Italy', 'MAKSIMOVIC Dusan (SCG)'),
#  ('Netherlands', 'Austria', 'GORDON John (SCO)'),
#  ('Brazil', 'Peru', 'RAINEA Nicolae (ROU)'),
#  ('Argentina', 'Poland', 'ERIKSSON Ulf (SWE)'),
#  ('Poland', 'Peru', 'PARTRIDGE Pat (ENG)'),
#  ('Italy', 'Austria', 'RION Francis (BEL)'),
#  ('Germany FR', 'Netherlands', 'BARRETO RUIZ Ramon (URU)'),
#  ('Argentina', 'Brazil', 'PALOTAI Karoly (HUN)'),
#  ('Netherlands', 'Italy', 'MARTINEZ Angel (ESP)'),
#  ('Austria', 'Germany FR', 'KLEIN Abraham (ISR)'),
#  ('Brazil', 'Poland', 'SILVAGNO CAVANNA Juan (CHI)'),
#  ('Argentina', 'Peru', 'WURTZ Robert (FRA)'),
#  ('Brazil', 'Italy', 'KLEIN Abraham (ISR)'),
#  ('Argentina', 'Netherlands', 'GONELLA Sergio (ITA)'),
#  ('Argentina', 'Belgium', 'CHRISTOV Vojtech (TCH)'),
#  ('Italy', 'Poland', 'VAUTROT Michel (FRA)'),
#  ('Brazil', 'Soviet Union', 'LAMO CASTILLO Augusto (ESP)'),
#  ('Peru', 'Cameroon', 'WOEHRER Franz (AUT)'),
#  ('Hungary', 'El Salvador', 'AL DOY Ebrahim (BHR)'),
#  ('Scotland', 'New Zealand', 'SOCHA David (USA)'),
#  ('Germany FR', 'Algeria', 'LABO REVOREDO Enrique (PER)'),
#  ('England', 'France', 'GARRIDO Antonio (POR)'),
#  ('Spain', 'Honduras', 'ITHURRALDE Arturo Andres (ARG)'),
#  ('Chile', 'Austria', 'CARDELLINO DE SAN VICENTE Juan (URU)'),
#  ('Czechoslovakia', 'Kuwait', 'DWOMOH Benjamin (GHA)'),
#  ('Yugoslavia', 'Northern Ireland', 'FREDRIKSSON Erik (SWE)'),
#  ('Italy', 'Peru', 'ESCHWEILER Walter (GER)'),
#  ('Argentina', 'Hungary', 'LACARNE Belaid (ALG)'),
#  ('Brazil', 'Scotland', 'SILES Jesus Paulino (CRC)'),
#  ('Poland', 'Cameroon', 'PONNET Alexis (BEL)'),
#  ('Belgium', 'El Salvador', 'MOFFATT Malcolm (NIR)'),
#  ('Soviet Union', 'New Zealand', 'EL GHOUL Yusef Mohamed (LBY)'),
#  ('Germany FR', 'Chile', 'GALLER Bruno (SUI)'),
#  ('England', 'Czechoslovakia', 'CORVER Charles (NED)'),
#  ('Spain', 'Yugoslavia', 'LUND-SORENSEN Henning (DEN)'),
#  ('Algeria', 'Austria', 'BOSKOVIC Tony (AUS)'),
#  ('France', 'Kuwait', 'STUPAR Miroslav (URS)'),
#  ('Honduras', 'Northern Ireland', 'CHAN Thomson Tam Sun (HKG)'),
#  ('Poland', 'Peru', 'RUBIO VAZQUEZ Mario (MEX)'),
#  ('Belgium', 'Hungary', 'WHITE Clive (ENG)'),
#  ('Soviet Union', 'Scotland', 'RAINEA Nicolae (ROU)'),
#  ('Italy', 'Cameroon', 'DOTCHEV Bogdan (BUL)'),
#  ('Argentina', 'El Salvador', 'BARRANCOS Luis (BOL)'),
#  ('Brazil', 'New Zealand', 'MATOVINOVIC Damir (CRO)'),
#  ('Algeria', 'Chile', 'MENDEZ MOLINA Romulo (GUA)'),
#  ('France', 'Czechoslovakia', 'CASARIN Paolo (ITA)'),
#  ('Honduras', 'Yugoslavia', 'CASTRO Gaston (CHI)'),
#  ('Germany FR', 'Austria', 'VALENTINE Robert (SCO)'),
#  ('England', 'Kuwait', 'ARISTIZABAL MURCIA Gilberto (COL)'),
#  ('Northern Ireland', 'Spain', 'ORTIZ Hector (PAR)'),
#  ('Austria', 'France', 'PALOTAI Karoly (HUN)'),
#  ('Poland', 'Belgium', 'SILES Jesus Paulino (CRC)'),
#  ('Italy', 'Argentina', 'RAINEA Nicolae (ROU)'),
#  ('Germany FR', 'England', 'COELHO Arnaldo (BRA)'),
#  ('Austria', 'Northern Ireland', 'PROKOP Adolf (GDR)'),
#  ('Belgium', 'Soviet Union', 'VAUTROT Michel (FRA)'),
#  ('Argentina', 'Brazil', 'RUBIO VAZQUEZ Mario (MEX)'),
#  ('Germany FR', 'Spain', 'CASARIN Paolo (ITA)'),
#  ('France', 'Northern Ireland', 'JARGUZ Alojzy (POL)'),
#  ('Poland', 'Soviet Union', 'VALENTINE Robert (SCO)'),
#  ('Italy', 'Brazil', 'KLEIN Abraham (ISR)'),
#  ('Spain', 'England', 'PONNET Alexis (BEL)'),
#  ('Poland', 'Italy', 'CARDELLINO DE SAN VICENTE Juan (URU)'),
#  ('Germany FR', 'France', 'CORVER Charles (NED)'),
#  ('Poland', 'France', 'GARRIDO Antonio (POR)'),
#  ('Italy', 'Germany FR', 'COELHO Arnaldo (BRA)'),
#  ('Bulgaria', 'Italy', 'FREDRIKSSON Erik (SWE)'),
#  ('Canada', 'France', 'SILVA ARCE Hernan (CHI)'),
#  ('Spain', 'Brazil', 'BAMBRIDGE Christopher (AUS)'),
#  ('Soviet Union', 'Hungary', 'AGNOLIN Luigi (ITA)'),
#  ('Argentina', 'Korea Republic', 'SANCHEZ ARMINIO Victoriano (ESP)'),
#  ('Morocco', 'Poland', 'MARTINEZ BAZAN Jose Luis (URU)'),
#  ('Algeria', 'Northern Ireland', 'BUTENKO Valeri (RUS)'),
#  ('Belgium', 'Mexico', 'ESPOSITO Carlos (ARG)'),
#  ('Portugal', 'England', 'ROTH Volker (GER)'),
#  ('Paraguay', 'Iraq', 'PICON-ACKONG Edwin (MRI)'),
#  ('Scotland', 'Denmark', 'NEMETH Lajos (HUN)'),
#  ('Uruguay', 'Germany FR', 'CHRISTOV Vojtech (TCH)'),
#  ('Italy', 'Argentina', 'KEIZER Jan (NED)'),
#  ('France', 'Soviet Union', 'ARPPI FILHO Romualdo (BRA)'),
#  ('Korea Republic', 'Bulgaria', 'AL SHANAR Fallaj Khuzam (KSA)'),
#  ('Hungary', 'Canada', 'AL SHARIF Jamal (SYR)'),
#  ('Brazil', 'Algeria', 'MENDEZ MOLINA Romulo (GUA)'),
#  ('England', 'Morocco', 'GONZALEZ ROA Gabriel (PAR)'),
#  ('Northern Ireland', 'Spain', 'BRUMMEIER Horst (AUT)'),
#  ('Mexico', 'Paraguay', 'COURTNEY George (ENG)'),
#  ('Poland', 'Portugal', 'BENNACEUR Ali (TUN)'),
#  ('Iraq', 'Belgium', 'DIAZ PALACIO Jesus (COL)'),
#  ('Denmark', 'Uruguay', 'MARQUEZ RAMIREZ Antonio (MEX)'),
#  ('Germany FR', 'Scotland', 'IGNA Ioan (ROU)'),
#  ('Hungary', 'France', 'SILVA VALENTE Carlos Alberto (POR)'),
#  ('Soviet Union', 'Canada', 'TRAORE Idrissa (MLI)'),
#  ('Korea Republic', 'Italy', 'SOCHA David (USA)'),
#  ('Argentina', 'Bulgaria', 'ULLOA MORERA Berny (CRC)'),
#  ('Paraguay', 'Belgium', 'DOTCHEV Bogdan (BUL)'),
#  ('Iraq', 'Mexico', 'PETROVIC Zoran (SRB)'),
#  ('Portugal', 'Morocco', 'SNODDY Alan (NIR)'),
#  ('England', 'Poland', 'DAINA Andre (SUI)'),
#  ('Northern Ireland', 'Brazil', 'KIRSCHEN Siegfried (GER)'),
#  ('Algeria', 'Spain', 'TAKADA Shizuo (JPN)'),
#  ('Scotland', 'Uruguay', 'QUINIOU Joel (FRA)'),
#  ('Denmark', 'Germany FR', 'PONNET Alexis (BEL)'),
#  ('Soviet Union', 'Belgium', 'FREDRIKSSON Erik (SWE)'),
#  ('Mexico', 'Bulgaria', 'ARPPI FILHO Romualdo (BRA)'),
#  ('Argentina', 'Uruguay', 'AGNOLIN Luigi (ITA)'),
#  ('Brazil', 'Poland', 'ROTH Volker (GER)'),
#  ('Italy', 'France', 'ESPOSITO Carlos (ARG)'),
#  ('Morocco', 'Germany FR', 'PETROVIC Zoran (SRB)'),
#  ('England', 'Paraguay', 'AL SHARIF Jamal (SYR)'),
#  ('Denmark', 'Spain', 'KEIZER Jan (NED)'),
#  ('Brazil', 'France', 'IGNA Ioan (ROU)'),
#  ('Germany FR', 'Mexico', 'DIAZ PALACIO Jesus (COL)'),
#  ('Spain', 'Belgium', 'KIRSCHEN Siegfried (GER)'),
#  ('Argentina', 'England', 'BENNACEUR Ali (TUN)'),
#  ('France', 'Germany FR', 'AGNOLIN Luigi (ITA)'),
#  ('Argentina', 'Belgium', 'MARQUEZ RAMIREZ Antonio (MEX)'),
#  ('France', 'Belgium', 'COURTNEY George (ENG)'),
#  ('Argentina', 'Germany FR', 'ARPPI FILHO Romualdo (BRA)'),
#  ('Argentina', 'Cameroon', 'VAUTROT Michel (FRA)'),
#  ('Soviet Union', 'Romania', 'CARDELLINO DE SAN VICENTE Juan (URU)'),
#  ('rn">United Arab Emirates', 'Colombia', 'COURTNEY George (ENG)'),
#  ('Italy', 'Austria', 'RAMIZ WRIGHT Jose (BRA)'),
#  ('USA', 'Czechoslovakia', 'ROETHLISBERGER Kurt (SUI)'),
#  ('Brazil', 'Sweden', 'LANESE Tullio (ITA)'),
#  ('Germany FR', 'Yugoslavia', 'MIKKELSEN Peter (DEN)'),
#  ('Costa Rica', 'Scotland', 'LOUSTAU Juan (ARG)'),
#  ('England', 'rn">Republic of Ireland', 'SCHMIDHUBER Aron (GER)'),
#  ('Belgium', 'Korea Republic', 'MAURO Vincent (USA)'),
#  ('Netherlands', 'Egypt', 'SORIANO ALADREN Emilio (ESP)'),
#  ('Uruguay', 'Spain', 'KOHL Helmut (AUT)'),
#  ('Argentina', 'Soviet Union', 'FREDRIKSSON Erik (SWE)'),
#  ('Cameroon', 'Romania', 'SILVA ARCE Hernan (CHI)'),
#  ('Yugoslavia', 'Colombia', 'AGNOLIN Luigi (ITA)'),
#  ('Italy', 'USA', 'CODESAL MENDEZ Edgardo (MEX)'),
#  ('Austria', 'Czechoslovakia', 'SMITH George (SCO)'),
#  ('Germany FR', 'rn">United Arab Emirates', 'SPIRIN Alexey (RUS)'),
#  ('Brazil', 'Costa Rica', 'JOUINI Neji (TUN)'),
#  ('Sweden', 'Scotland', 'MACIEL Carlos (PAR)'),
#  ('England', 'Netherlands', 'PETROVIC Zoran (SRB)'),
#  ('rn">Republic of Ireland', 'Egypt', 'VAN LANGENHOVE Marcel (BEL)'),
#  ('Korea Republic', 'Spain', 'JACOME GUERRERO Elias V. (ECU)'),
#  ('Belgium', 'Uruguay', 'KIRSCHEN Siegfried (GER)'),
#  ('Argentina', 'Romania', 'SILVA VALENTE Carlos Alberto (POR)'),
#  ('Cameroon', 'Soviet Union', 'RAMIZ WRIGHT Jose (BRA)'),
#  ('Germany FR', 'Colombia', 'SNODDY Alan (NIR)'),
#  ('Yugoslavia', 'rn">United Arab Emirates', 'TAKADA Shizuo (JPN)'),
#  ('Italy', 'Czechoslovakia', 'QUINIOU Joel (FRA)'),
#  ('Austria', 'USA', 'AL SHARIF Jamal (SYR)'),
#  ('Brazil', 'Scotland', 'KOHL Helmut (AUT)'),
#  ('Sweden', 'Costa Rica', 'PETROVIC Zoran (SRB)'),
#  ('Korea Republic', 'Uruguay', 'LANESE Tullio (ITA)'),
#  ('Belgium', 'Spain', 'LOUSTAU Juan (ARG)'),
#  ('rn">Republic of Ireland', 'Netherlands', 'VAUTROT Michel (FRA)'),
#  ('England', 'Egypt', 'ROETHLISBERGER Kurt (SUI)'),
#  ('Cameroon', 'Colombia', 'LANESE Tullio (ITA)'),
#  ('Czechoslovakia', 'Costa Rica', 'KIRSCHEN Siegfried (GER)'),
#  ('Brazil', 'Argentina', 'QUINIOU Joel (FRA)'),
#  ('Germany FR', 'Netherlands', 'LOUSTAU Juan (ARG)'),
#  ('rn">Republic of Ireland', 'Romania', 'RAMIZ WRIGHT Jose (BRA)'),
#  ('Italy', 'Uruguay', 'COURTNEY George (ENG)'),
#  ('Spain', 'Yugoslavia', 'SCHMIDHUBER Aron (GER)'),
#  ('England', 'Belgium', 'MIKKELSEN Peter (DEN)'),
#  ('Yugoslavia', 'Argentina', 'ROETHLISBERGER Kurt (SUI)'),
#  ('Italy', 'rn">Republic of Ireland', 'SILVA VALENTE Carlos Alberto (POR)'),
#  ('Germany FR', 'Czechoslovakia', 'KOHL Helmut (AUT)'),
#  ('England', 'Cameroon', 'CODESAL MENDEZ Edgardo (MEX)'),
#  ('Italy', 'Argentina', 'VAUTROT Michel (FRA)'),
#  ('Germany FR', 'England', 'RAMIZ WRIGHT Jose (BRA)'),
#  ('Italy', 'England', 'QUINIOU Joel (FRA)'),
#  ('Germany FR', 'Argentina', 'CODESAL MENDEZ Edgardo (MEX)'),
#  ('Spain', 'Korea Republic', 'MIKKELSEN Peter (DEN)'),
#  ('Germany', 'Bolivia', 'BRIZIO CARTER Arturo (MEX)'),
#  ('USA', 'Switzerland', 'LAMOLINA Francisco Oscar (ARG)'),
#  ('Italy', 'rn">Republic of Ireland', 'VAN DER ENDE Mario (NED)'),
#  ('Colombia', 'Romania', 'AL SHARIF Jamal (SYR)'),
#  ('Belgium', 'Morocco', 'TORRES CADENA Jose Joaquin (COL)'),
#  ('Norway', 'Mexico', 'PUHL Sandor (HUN)'),
#  ('Cameroon', 'Sweden', 'TEJADA NORIEGA Alberto (PER)'),
#  ('Netherlands', 'Saudi Arabia', 'DIAZ VEGA Manuel (ESP)'),
#  ('Brazil', 'Russia', 'LIM KEE CHONG An Yan (MRI)'),
#  ('Argentina', 'Greece', 'ANGELES Arturo (USA)'),
#  ('Nigeria', 'Bulgaria', 'BADILLA Rodrigo (CRC)'),
#  ('Germany', 'Spain', 'FILIPPI Ernesto (URU)'),
#  ('Romania', 'Switzerland', 'JOUINI Neji (TUN)'),
#  ('USA', 'Colombia', 'BALDAS Fabio (ITA)'),
#  ('Italy', 'Norway', 'KRUG Hellmut (GER)'),
#  ('Korea Republic', 'Bolivia', 'MOTTRAM Leslie (SCO)'),
#  ('Mexico', 'rn">Republic of Ireland', 'ROETHLISBERGER Kurt (SUI)'),
#  ('Sweden', 'Russia', 'QUINIOU Joel (FRA)'),
#  ('Brazil', 'Cameroon', 'BRIZIO CARTER Arturo (MEX)'),
#  ('Belgium', 'Netherlands', 'MARSIGLIA Renato (BRA)'),
#  ('Saudi Arabia', 'Morocco', 'DON Philip (ENG)'),
#  ('Argentina', 'Nigeria', 'KARLSSON Bo (SWE)'),
#  ('Bulgaria', 'Greece', 'BUJSAIM Ali (UAE)'),
#  ('USA', 'Romania', 'VAN DER ENDE Mario (NED)'),
#  ('Switzerland', 'Colombia', 'MIKKELSEN Peter (DEN)'),
#  ('Germany', 'Korea Republic', 'QUINIOU Joel (FRA)'),
#  ('Bolivia', 'Spain', 'BADILLA Rodrigo (CRC)'),
#  ('rn">Republic of Ireland', 'Norway', 'TORRES CADENA Jose Joaquin (COL)'),
#  ('Brazil', 'Sweden', 'PUHL Sandor (HUN)'),
#  ('Italy', 'Mexico', 'LAMOLINA Francisco Oscar (ARG)'),
#  ('Russia', 'Cameroon', 'AL SHARIF Jamal (SYR)'),
#  ('Morocco', 'Netherlands', 'TEJADA NORIEGA Alberto (PER)'),
#  ('Belgium', 'Saudi Arabia', 'KRUG Hellmut (GER)'),
#  ('Greece', 'Nigeria', 'MOTTRAM Leslie (SCO)'),
#  ('Argentina', 'Bulgaria', 'JOUINI Neji (TUN)'),
#  ('Germany', 'Belgium', 'ROETHLISBERGER Kurt (SUI)'),
#  ('Spain', 'Switzerland', 'VAN DER ENDE Mario (NED)'),
#  ('Saudi Arabia', 'Sweden', 'MARSIGLIA Renato (BRA)'),
#  ('Romania', 'Argentina', 'PAIRETTO Pierluigi (ITA)'),
#  ('Netherlands', 'rn">Republic of Ireland', 'MIKKELSEN Peter (DEN)'),
#  ('Brazil', 'USA', 'QUINIOU Joel (FRA)'),
#  ('Nigeria', 'Italy', 'BRIZIO CARTER Arturo (MEX)'),
#  ('Mexico', 'Bulgaria', 'AL SHARIF Jamal (SYR)'),
#  ('Italy', 'Spain', 'PUHL Sandor (HUN)'),
#  ('Netherlands', 'Brazil', 'BADILLA Rodrigo (CRC)'),
#  ('Bulgaria', 'Germany', 'TORRES CADENA Jose Joaquin (COL)'),
#  ('Romania', 'Sweden', 'DON Philip (ENG)'),
#  ('Bulgaria', 'Italy', 'QUINIOU Joel (FRA)'),
#  ('Sweden', 'Brazil', 'TORRES CADENA Jose Joaquin (COL)'),
#  ('Sweden', 'Bulgaria', 'BUJSAIM Ali (UAE)'),
#  ('Brazil', 'Italy', 'PUHL Sandor (HUN)'),
#  ('Brazil', 'Scotland', 'GARCIA ARANDA Jose Maria (ESP)'),
#  ('Morocco', 'Norway', 'ANPRASERT Pirom (THA)'),
#  ('Italy', 'Chile', 'BOUCHARDEAU Lucien (NIG)'),
#  ('Cameroon', 'Austria', 'GONZALEZ CHAVEZ Epifanio (PAR)'),
#  ('Paraguay', 'Bulgaria', 'ALZEID Abdulrahman (KSA)'),
#  ('Saudi Arabia', 'Denmark', 'CASTRILLI Javier (ARG)'),
#  ('France', 'South Africa', 'REZENDE Marcio (BRA)'),
#  ('Spain', 'Nigeria', 'BAHARMAST Esse (USA)'),
#  ('Korea Republic', 'Mexico', 'BENKO Gunter (AUT)'),
#  ('Netherlands', 'Belgium', 'COLLINA Pierluigi (ITA)'),
#  ('Argentina', 'Japan', 'VAN DER ENDE Mario (NED)'),
#  ('Yugoslavia', 'Iran', 'TEJADA NORIEGA Alberto (PER)'),
#  ('Jamaica', 'Croatia', 'MELO PEREIRA Vitor (POR)'),
#  ('England', 'Tunisia', 'OKADA Masayoshi (JPN)'),
#  ('Romania', 'Colombia', 'LIM KEE CHONG An Yan (MRI)'),
#  ('Germany', 'USA', 'BELQOLA Said (MAR)'),
#  ('Scotland', 'Norway', 'VAGNER Laszlo (HUN)'),
#  ('Brazil', 'Morocco', 'LEVNIKOV Nikolai (RUS)'),
#  ('Chile', 'Austria', 'EL GHANDOUR Gamal (EGY)'),
#  ('Italy', 'Cameroon', 'LENNIE Edward (AUS)'),
#  ('South Africa', 'Denmark', 'TORO RENDON John (COL)'),
#  ('France', 'Saudi Arabia', 'BRIZIO CARTER Arturo (MEX)'),
#  ('Nigeria', 'Bulgaria', 'SANCHEZ YANTEN Mario (CHI)'),
#  ('Spain', 'Paraguay', 'McLEOD Ian (RSA)'),
#  ('Japan', 'Croatia', 'RAMDHAN Ramesh (TRI)'),
#  ('Belgium', 'Mexico', 'DALLAS Hugh (SCO)'),
#  ('Netherlands', 'Korea Republic', 'WOJCIK Ryszard (POL)'),
#  ('Germany', 'Yugoslavia', 'NIELSEN Kim Milton (DEN)'),
#  ('Argentina', 'Jamaica', 'PEDERSEN Rune (NOR)'),
#  ('USA', 'Iran', 'MEIER Urs (SUI)'),
#  ('Colombia', 'Tunisia', 'HEYNEMANN Bernd (GER)'),
#  ('Romania', 'England', 'BATTA Marc (FRA)'),
#  ('Italy', 'Austria', 'DURKIN Paul (ENG)'),
#  ('Chile', 'Cameroon', 'VAGNER Laszlo (HUN)'),
#  ('Scotland', 'Morocco', 'BUJSAIM Ali (UAE)'),
#  ('Brazil', 'Norway', 'BAHARMAST Esse (USA)'),
#  ('France', 'Denmark', 'COLLINA Pierluigi (ITA)'),
#  ('South Africa', 'Saudi Arabia', 'SANCHEZ YANTEN Mario (CHI)'),
#  ('Spain', 'Bulgaria', 'VAN DER ENDE Mario (NED)'),
#  ('Nigeria', 'Paraguay', 'ANPRASERT Pirom (THA)'),
#  ('Belgium', 'Korea Republic', 'REZENDE Marcio (BRA)'),
#  ('Netherlands', 'Mexico', 'ALZEID Abdulrahman (KSA)'),
#  ('Germany', 'Iran', 'GONZALEZ CHAVEZ Epifanio (PAR)'),
#  ('USA', 'Yugoslavia', 'EL GHANDOUR Gamal (EGY)'),
#  ('Japan', 'Jamaica', 'BENKO Gunter (AUT)'),
#  ('Argentina', 'Croatia', 'BELQOLA Said (MAR)'),
#  ('Romania', 'Tunisia', 'LENNIE Edward (AUS)'),
#  ('Colombia', 'England', 'BRIZIO CARTER Arturo (MEX)'),
#  ('Italy', 'Norway', 'HEYNEMANN Bernd (GER)'),
#  ('Brazil', 'Chile', 'BATTA Marc (FRA)'),
#  ('France', 'Paraguay', 'BUJSAIM Ali (UAE)'),
#  ('Nigeria', 'Denmark', 'MEIER Urs (SUI)'),
#  ('Germany', 'Mexico', 'MELO PEREIRA Vitor (POR)'),
#  ('Netherlands', 'Yugoslavia', 'GARCIA ARANDA Jose Maria (ESP)'),
#  ('Romania', 'Croatia', 'CASTRILLI Javier (ARG)'),
#  ('Argentina', 'England', 'NIELSEN Kim Milton (DEN)'),
#  ('Italy', 'France', 'DALLAS Hugh (SCO)'),
#  ('Brazil', 'Denmark', 'EL GHANDOUR Gamal (EGY)'),
#  ('Netherlands', 'Argentina', 'BRIZIO CARTER Arturo (MEX)'),
#  ('Germany', 'Croatia', 'PEDERSEN Rune (NOR)'),
#  ('Brazil', 'Netherlands', 'BUJSAIM Ali (UAE)'),
#  ('France', 'Croatia', 'GARCIA ARANDA Jose Maria (ESP)'),
#  ('Netherlands', 'Croatia', 'GONZALEZ CHAVEZ Epifanio (PAR)'),
#  ('Brazil', 'France', 'BELQOLA Said (MAR)'),
#  ('France', 'Senegal', 'BUJSAIM Ali (UAE)'),
#  ('Uruguay', 'Denmark', 'MANE Saad (KUW)'),
#  ('rn">Republic of Ireland', 'Cameroon', 'KAMIKAWA Toru (JPN)'),
#  ('Germany', 'Saudi Arabia', 'AQUINO Ubaldo (PAR)'),
#  ('Argentina', 'Nigeria', 'VEISSIERE Gilles (FRA)'),
#  ('Paraguay', 'South Africa', 'MICHEL Lubos (SVK)'),
#  ('England', 'Sweden', 'SIMON Carlos (BRA)'),
#  ('Spain', 'Slovenia', 'GUEZZAZ Mohammed (MAR)'),
#  ('Brazil', 'Turkey', 'KIM Young Joo (KOR)'),
#  ('Italy', 'Ecuador', 'HALL Brian (USA)'),
#  ('Croatia', 'Mexico', 'JUN Lu (CHN)'),
#  ('China PR', 'Costa Rica', 'VASSARAS Kyros (GRE)'),
#  ('Japan', 'Belgium', 'MATTUS William (CRC)'),
#  ('Korea Republic', 'Poland', 'RUIZ Oscar (COL)'),
#  ('Russia', 'Tunisia', 'PRENDERGAST Peter (JAM)'),
#  ('USA', 'Portugal', 'MORENO Byron (ECU)'),
#  ('Germany', 'rn">Republic of Ireland', 'NIELSEN Kim Milton (DEN)'),
#  ('Denmark', 'Senegal', 'BATRES Carlos (GUA)'),
#  ('Cameroon', 'Saudi Arabia', 'HAUGE Terje (NOR)'),
#  ('France', 'Uruguay', 'RAMOS RIZO Felipe (MEX)'),
#  ('Sweden', 'Nigeria', 'ORTUBE Rene (BOL)'),
#  ('Argentina', 'England', 'COLLINA Pierluigi (ITA)'),
#  ('Spain', 'Paraguay', 'EL GHANDOUR Gamal (EGY)'),
#  ('South Africa', 'Slovenia', 'SANCHEZ Angel (ARG)'),
#  ('Brazil', 'China PR', 'FRISK Anders (SWE)'),
#  ('Italy', 'Croatia', 'POLL Graham (ENG)'),
#  ('Costa Rica', 'Turkey', 'CODJIA Coffi (BEN)'),
#  ('Japan', 'Russia', 'MERK Markus (GER)'),
#  ('Mexico', 'Ecuador', 'DAAMI Mourad (TUN)'),
#  ('Korea Republic', 'USA', 'MEIER Urs (SUI)'),
#  ('Portugal', 'Poland', 'DALLAS Hugh (SCO)'),
#  ('Tunisia', 'Belgium', 'SHIELD Mark (AUS)'),
#  ('Denmark', 'France', 'MELO PEREIRA Vitor (POR)'),
#  ('Senegal', 'Uruguay', 'WEGEREEF Jan (NED)'),
#  ('Saudi Arabia', 'rn">Republic of Ireland', 'NDOYE Falla (SEN)'),
#  ('Cameroon', 'Germany', 'LOPEZ NIETO Antonio (ESP)'),
#  ('Sweden', 'Argentina', 'BUJSAIM Ali (UAE)'),
#  ('Nigeria', 'England', 'HALL Brian (USA)'),
#  ('Slovenia', 'Paraguay', 'RAMOS RIZO Felipe (MEX)'),
#  ('South Africa', 'Spain', 'MANE Saad (KUW)'),
#  ('Costa Rica', 'Brazil', 'EL GHANDOUR Gamal (EGY)'),
#  ('Turkey', 'China PR', 'RUIZ Oscar (COL)'),
#  ('Ecuador', 'Croatia', 'MATTUS William (CRC)'),
#  ('Mexico', 'Italy', 'SIMON Carlos (BRA)'),
#  ('Tunisia', 'Japan', 'VEISSIERE Gilles (FRA)'),
#  ('Portugal', 'Korea Republic', 'SANCHEZ Angel (ARG)'),
#  ('Poland', 'USA', 'LU Jun (CHN)'),
#  ('Belgium', 'Russia', 'NIELSEN Kim Milton (DEN)'),
#  ('Denmark', 'England', 'MERK Markus (GER)'),
#  ('Germany', 'Paraguay', 'BATRES Carlos (GUA)'),
#  ('Spain', 'rn">Republic of Ireland', 'FRISK Anders (SWE)'),
#  ('Sweden', 'Senegal', 'AQUINO Ubaldo (PAR)'),
#  ('Brazil', 'Belgium', 'PRENDERGAST Peter (JAM)'),
#  ('Mexico', 'USA', 'MELO PEREIRA Vitor (POR)'),
#  ('Japan', 'Turkey', 'COLLINA Pierluigi (ITA)'),
#  ('Korea Republic', 'Italy', 'MORENO Byron (ECU)'),
#  ('England', 'Brazil', 'RAMOS RIZO Felipe (MEX)'),
#  ('Germany', 'USA', 'DALLAS Hugh (SCO)'),
#  ('Senegal', 'Turkey', 'RUIZ Oscar (COL)'),
#  ('Spain', 'Korea Republic', 'EL GHANDOUR Gamal (EGY)'),
#  ('Germany', 'Korea Republic', 'MEIER Urs (SUI)'),
#  ('Brazil', 'Turkey', 'NIELSEN Kim Milton (DEN)'),
#  ('Korea Republic', 'Turkey', 'MANE Saad (KUW)'),
#  ('Germany', 'Brazil', 'COLLINA Pierluigi (ITA)'),
#  ('Germany', 'Costa Rica', 'ELIZONDO Horacio (ARG)'),
#  ('Poland', 'Ecuador', 'KAMIKAWA Toru (JPN)'),
#  ('England', 'Paraguay', 'RODRIGUEZ Marco (MEX)'),
#  ('rn">Trinidad and Tobago', 'Sweden', 'MAIDIN Shamsul (SIN)'),
#  ('Argentina', "C�te d'Ivoire", 'DE BLEECKERE Frank (BEL)'),
#  ('rn">Serbia and Montenegro', 'Netherlands', 'MERK Markus (GER)'),
#  ('Mexico', 'Iran', 'ROSETTI Roberto (ITA)'),
#  ('Angola', 'Portugal', 'LARRIONDA Jorge (URU)'),
#  ('Australia', 'Japan', 'ABD EL FATAH Essam (EGY)'),
#  ('USA', 'Czech Republic', 'AMARILLA Carlos (PAR)'),
#  ('Italy', 'Ghana', 'SIMON Carlos (BRA)'),
#  ('Korea Republic', 'Togo', 'POLL Graham (ENG)'),
#  ('France', 'Switzerland', 'IVANOV Valentin (RUS)'),
#  ('Brazil', 'Croatia', 'ARCHUNDIA Benito (MEX)'),
#  ('Spain', 'Ukraine', 'BUSACCA Massimo (SUI)'),
#  ('Tunisia', 'Saudi Arabia', 'SHIELD Mark (AUS)'),
#  ('Germany', 'Poland', 'MEDINA CANTALEJO Luis (ESP)'),
#  ('Ecuador', 'Costa Rica', 'CODJIA Coffi (BEN)'),
#  ('England', 'rn">Trinidad and Tobago', 'KAMIKAWA Toru (JPN)'),
#  ('Sweden', 'Paraguay', 'MICHEL Lubos (SVK)'),
#  ('Argentina', 'rn">Serbia and Montenegro', 'ROSETTI Roberto (ITA)'),
#  ('Netherlands', "C�te d'Ivoire", 'RUIZ Oscar (COL)'),
#  ('Mexico', 'Angola', 'MAIDIN Shamsul (SIN)'),
#  ('Portugal', 'IR Iran', 'POULAT Eric (FRA)'),
#  ('Czech Republic', 'Ghana', 'ELIZONDO Horacio (ARG)'),
#  ('Italy', 'USA', 'LARRIONDA Jorge (URU)'),
#  ('Japan', 'Croatia', 'DE BLEECKERE Frank (BEL)'),
#  ('Brazil', 'Australia', 'MERK Markus (GER)'),
#  ('France', 'Korea Republic', 'ARCHUNDIA Benito (MEX)'),
#  ('Togo', 'Switzerland', 'AMARILLA Carlos (PAR)'),
#  ('Saudi Arabia', 'Ukraine', 'POLL Graham (ENG)'),
#  ('Spain', 'Tunisia', 'SIMON Carlos (BRA)'),
#  ('Ecuador', 'Germany', 'IVANOV Valentin (RUS)'),
#  ('Costa Rica', 'Poland', 'MAIDIN Shamsul (SIN)'),
#  ('Sweden', 'England', 'BUSACCA Massimo (SUI)'),
#  ('Paraguay', 'rn">Trinidad and Tobago', 'ROSETTI Roberto (ITA)'),
#  ('Iran', 'Angola', 'SHIELD Mark (AUS)'),
#  ('Portugal', 'Mexico', 'MICHEL Lubos (SVK)'),
#  ('Netherlands', 'Argentina', 'MEDINA CANTALEJO Luis (ESP)'),
#  ("C�te d'Ivoire", 'rn">Serbia and Montenegro', 'RODRIGUEZ Marco (MEX)'),
#  ('Czech Republic', 'Italy', 'ARCHUNDIA Benito (MEX)'),
#  ('Ghana', 'USA', 'MERK Markus (GER)'),
#  ('Japan', 'Brazil', 'POULAT Eric (FRA)'),
#  ('Croatia', 'Australia', 'POLL Graham (ENG)'),
#  ('Ukraine', 'Tunisia', 'AMARILLA Carlos (PAR)'),
#  ('Saudi Arabia', 'Spain', 'CODJIA Coffi (BEN)'),
#  ('Togo', 'France', 'LARRIONDA Jorge (URU)'),
#  ('Switzerland', 'Korea Republic', 'ELIZONDO Horacio (ARG)'),
#  ('Germany', 'Sweden', 'SIMON Carlos (BRA)'),
#  ('Argentina', 'Mexico', 'BUSACCA Massimo (SUI)'),
#  ('England', 'Ecuador', 'DE BLEECKERE Frank (BEL)'),
#  ('Portugal', 'Netherlands', 'IVANOV Valentin (RUS)'),
#  ('Italy', 'Australia', 'MEDINA CANTALEJO Luis (ESP)'),
#  ('Switzerland', 'Ukraine', 'ARCHUNDIA Benito (MEX)'),
#  ('Brazil', 'Ghana', 'MICHEL Lubos (SVK)'),
#  ('Spain', 'France', 'ROSETTI Roberto (ITA)'),
#  ('Germany', 'Argentina', 'MICHEL Lubos (SVK)'),
#  ('Italy', 'Ukraine', 'DE BLEECKERE Frank (BEL)'),
#  ('England', 'Portugal', 'ELIZONDO Horacio (ARG)'),
#  ('Brazil', 'France', 'MEDINA CANTALEJO Luis (ESP)'),
#  ('Germany', 'Italy', 'ARCHUNDIA Benito (MEX)'),
#  ('Portugal', 'France', 'LARRIONDA Jorge (URU)'),
#  ('Germany', 'Portugal', 'KAMIKAWA Toru (JPN)'),
#  ('Italy', 'France', 'ELIZONDO Horacio (ARG)'),
#  ('South Africa', 'Mexico', 'Ravshan IRMATOV (UZB)'),
#  ('Uruguay', 'France', 'NISHIMURA Yuichi (JPN)'),
#  ('Korea Republic', 'Greece', 'HESTER Michael (NZL)'),
#  ('Argentina', 'Nigeria', 'Wolfgang STARK (GER)'),
#  ('England', 'USA', 'SIMON Carlos (BRA)'),
#  ('Algeria', 'Slovenia', 'BATRES Carlos (GUA)'),
#  ('Serbia', 'Ghana', 'BALDASSI Hector (ARG)'),
#  ('Germany', 'Australia', 'RODRIGUEZ Marco (MEX)'),
#  ('Netherlands', 'Denmark', 'St�phane LANNOY (FRA)'),
#  ('Japan', 'Cameroon', 'Oleg�rio BENQUEREN�A (POR)'),
#  ('Italy', 'Paraguay', 'ARCHUNDIA Benito (MEX)'),
#  ('New Zealand', 'Slovakia', 'DAMON Jerome (RSA)'),
#  ("C�te d'Ivoire", 'Portugal', 'LARRIONDA Jorge (URU)'),
#  ('Brazil', 'Korea DPR', 'KASSAI Viktor (HUN)'),
#  ('Honduras', 'Chile', 'MAILLET Eddy (SEY)'),
#  ('Spain', 'Switzerland', 'WEBB Howard (ENG)'),
#  ('South Africa', 'Uruguay', 'BUSACCA Massimo (SUI)'),
#  ('Argentina', 'Korea Republic', 'DE BLEECKERE Frank (BEL)'),
#  ('Greece', 'Nigeria', 'RUIZ Oscar (COL)'),
#  ('France', 'Mexico', 'AL GHAMDI Khalil (KSA)'),
#  ('Germany', 'Serbia', 'Alberto UNDIANO MALLENCO (ESP)'),
#  ('Slovenia', 'USA', 'Koman COULIBALY (MLI)'),
#  ('England', 'Algeria', 'Ravshan IRMATOV (UZB)'),
#  ('Netherlands', 'Japan', 'BALDASSI Hector (ARG)'),
#  ('Ghana', 'Australia', 'ROSETTI Roberto (ITA)'),
#  ('Cameroon', 'Denmark', 'LARRIONDA Jorge (URU)'),
#  ('Slovakia', 'Paraguay', 'MAILLET Eddy (SEY)'),
#  ('Italy', 'New Zealand', 'BATRES Carlos (GUA)'),
#  ('Brazil', "C�te d'Ivoire", 'St�phane LANNOY (FRA)'),
#  ('Portugal', 'Korea DPR', 'POZO Pablo (CHI)'),
#  ('Chile', 'Switzerland', 'AL GHAMDI Khalil (KSA)'),
#  ('Spain', 'Honduras', 'NISHIMURA Yuichi (JPN)'),
#  ('Mexico', 'Uruguay', 'KASSAI Viktor (HUN)'),
#  ('France', 'South Africa', 'RUIZ Oscar (COL)'),
#  ('Nigeria', 'Korea Republic', 'Oleg�rio BENQUEREN�A (POR)'),
#  ('Greece', 'Argentina', 'Ravshan IRMATOV (UZB)'),
#  ('Slovenia', 'England', 'Wolfgang STARK (GER)'),
#  ('USA', 'Algeria', 'DE BLEECKERE Frank (BEL)'),
#  ('Ghana', 'Germany', 'SIMON Carlos (BRA)'),
#  ('Australia', 'Serbia', 'LARRIONDA Jorge (URU)'),
#  ('Slovakia', 'Italy', 'WEBB Howard (ENG)'),
#  ('Paraguay', 'New Zealand', 'NISHIMURA Yuichi (JPN)'),
#  ('Denmark', 'Japan', 'DAMON Jerome (RSA)'),
#  ('Cameroon', 'Netherlands', 'POZO Pablo (CHI)'),
#  ('Portugal', 'Brazil', 'ARCHUNDIA Benito (MEX)'),
#  ('Korea DPR', "C�te d'Ivoire", 'Alberto UNDIANO MALLENCO (ESP)'),
#  ('Chile', 'Spain', 'RODRIGUEZ Marco (MEX)'),
#  ('Switzerland', 'Honduras', 'BALDASSI Hector (ARG)'),
#  ('Uruguay', 'Korea Republic', 'Wolfgang STARK (GER)'),
#  ('USA', 'Ghana', 'KASSAI Viktor (HUN)'),
#  ('Germany', 'England', 'LARRIONDA Jorge (URU)'),
#  ('Argentina', 'Mexico', 'ROSETTI Roberto (ITA)'),
#  ('Netherlands', 'Slovakia', 'Alberto UNDIANO MALLENCO (ESP)'),
#  ('Brazil', 'Chile', 'WEBB Howard (ENG)'),
#  ('Paraguay', 'Japan', 'DE BLEECKERE Frank (BEL)'),
#  ('Spain', 'Portugal', 'BALDASSI Hector (ARG)'),
#  ('Netherlands', 'Brazil', 'NISHIMURA Yuichi (JPN)'),
#  ('Uruguay', 'Ghana', 'Oleg�rio BENQUEREN�A (POR)'),
#  ('Argentina', 'Germany', 'Ravshan IRMATOV (UZB)'),
#  ('Paraguay', 'Spain', 'BATRES Carlos (GUA)'),
#  ('Uruguay', 'Netherlands', 'Ravshan IRMATOV (UZB)'),
#  ('Germany', 'Spain', 'KASSAI Viktor (HUN)'),
#  ('Uruguay', 'Germany', 'ARCHUNDIA Benito (MEX)'),
#  ('Netherlands', 'Spain', 'WEBB Howard (ENG)'),
#  ('Brazil', 'Croatia', 'NISHIMURA Yuichi (JPN)'),
#  ('Mexico', 'Cameroon', 'ROLDAN Wilmar (COL)'),
#  ('Spain', 'Netherlands', 'Nicola RIZZOLI (ITA)'),
#  ('Chile', 'Australia', 'Noumandiez DOUE (CIV)'),
#  ('Colombia', 'Greece', 'GEIGER Mark (USA)'),
#  ('Uruguay', 'Costa Rica', 'BRYCH Felix (GER)'),
#  ('England', 'Italy', 'Bj�rn KUIPERS (NED)'),
#  ("C�te d'Ivoire", 'Japan', 'OSSES Enrique (CHI)'),
#  ('Switzerland', 'Ecuador', 'Ravshan IRMATOV (UZB)'),
#  ('France', 'Honduras', 'RICCI Sandro (BRA)'),
#  ('Argentina', 'rn">Bosnia and Herzegovina', 'AGUILAR Joel (SLV)'),
#  ('Germany', 'Portugal', 'MAZIC Milorad (SRB)'),
#  ('IR Iran', 'Nigeria', 'VERA Carlos (ECU)'),
#  ('Ghana', 'USA', 'ERIKSSON Jonas (SWE)'),
#  ('Belgium', 'Algeria', 'RODRIGUEZ Marco (MEX)'),
#  ('Brazil', 'Mexico', 'C�neyt �AKIR (TUR)'),
#  ('Russia', 'Korea Republic', 'PITANA Nestor (ARG)'),
#  ('Australia', 'Netherlands', 'HAIMOUDI Djamel (ALG)'),
#  ('Spain', 'Chile', 'GEIGER Mark (USA)'),
#  ('Cameroon', 'Croatia', 'PROENCA Pedro (POR)'),
#  ('Colombia', "C�te d'Ivoire", 'WEBB Howard (ENG)'),
#  ('Uruguay', 'England', 'Carlos VELASCO CARBALLO (ESP)'),
#  ('Japan', 'Greece', 'AGUILAR Joel (SLV)'),
#  ('Italy', 'Costa Rica', 'OSSES Enrique (CHI)'),
#  ('Switzerland', 'France', 'Bj�rn KUIPERS (NED)'),
#  ('Honduras', 'Ecuador', 'Ben WILLIAMS (AUS)'),
#  ('Argentina', 'IR Iran', 'MAZIC Milorad (SRB)'),
#  ('Germany', 'Ghana', 'RICCI Sandro (BRA)'),
#  ('Nigeria', 'rn">Bosnia and Herzegovina', "Peter O'LEARY (NZL)"),
#  ('Belgium', 'Russia', 'BRYCH Felix (GER)'),
#  ('Korea Republic', 'Algeria', 'ROLDAN Wilmar (COL)'),
#  ('USA', 'Portugal', 'PITANA Nestor (ARG)'),
#  ('Australia', 'Spain', 'SHUKRALLA Nawaf (BHR)'),
#  ('Netherlands', 'Chile', 'Bakary GASSAMA (GAM)'),
#  ('Cameroon', 'Brazil', 'ERIKSSON Jonas (SWE)'),
#  ('Croatia', 'Mexico', 'Ravshan IRMATOV (UZB)'),
#  ('Italy', 'Uruguay', 'RODRIGUEZ Marco (MEX)'),
#  ('Costa Rica', 'England', 'HAIMOUDI Djamel (ALG)'),
#  ('Japan', 'Colombia', 'PROENCA Pedro (POR)'),
#  ('Greece', "C�te d'Ivoire", 'VERA Carlos (ECU)'),
#  ('Nigeria', 'Argentina', 'Nicola RIZZOLI (ITA)'),
#  ('rn">Bosnia and Herzegovina', 'IR Iran', 'Carlos VELASCO CARBALLO (ESP)'),
#  ('Honduras', 'Switzerland', 'PITANA Nestor (ARG)'),
#  ('Ecuador', 'France', 'Noumandiez DOUE (CIV)'),
#  ('USA', 'Germany', 'Ravshan IRMATOV (UZB)'),
#  ('Portugal', 'Ghana', 'SHUKRALLA Nawaf (BHR)'),
#  ('Korea Republic', 'Belgium', 'Ben WILLIAMS (AUS)'),
#  ('Algeria', 'Russia', 'C�neyt �AKIR (TUR)'),
#  ('Brazil', 'Chile', 'WEBB Howard (ENG)'),
#  ('Colombia', 'Uruguay', 'Bj�rn KUIPERS (NED)'),
#  ('France', 'Nigeria', 'GEIGER Mark (USA)'),
#  ('Germany', 'Algeria', 'RICCI Sandro (BRA)'),
#  ('Brazil', 'Colombia', 'Carlos VELASCO CARBALLO (ESP)'),
#  ('France', 'Germany', 'PITANA Nestor (ARG)'),
#  ('Brazil', 'Germany', 'RODRIGUEZ Marco (MEX)'),
#  ('Brazil', 'Netherlands', 'HAIMOUDI Djamel (ALG)'),
#  ('Germany', 'Argentina', 'Nicola RIZZOLI (ITA)'),
#  ('Netherlands', 'Argentina', 'C�neyt �AKIR (TUR)'),
#  ('Netherlands', 'Costa Rica', 'Ravshan IRMATOV (UZB)'),
#  ('Argentina', 'Belgium', 'Nicola RIZZOLI (ITA)'),
#  ('Netherlands', 'Mexico', 'PROENCA Pedro (POR)'),
#  ('Costa Rica', 'Greece', 'Ben WILLIAMS (AUS)'),
#  ('Argentina', 'Switzerland', 'ERIKSSON Jonas (SWE)'),
#  ('Belgium', 'USA', 'HAIMOUDI Djamel (ALG)'),
#  ('Brazil', 'Chile', 'WEBB Howard (ENG)'),
#  ('Colombia', 'Uruguay', 'Bj�rn KUIPERS (NED)'),
#  ('Netherlands', 'Mexico', 'PROENCA Pedro (POR)'),
#  ('Costa Rica', 'Greece', 'Ben WILLIAMS (AUS)'),
#  ('France', 'Nigeria', 'GEIGER Mark (USA)'),
#  ('Germany', 'Algeria', 'RICCI Sandro (BRA)'),
#  ('Argentina', 'Switzerland', 'ERIKSSON Jonas (SWE)'),
#  ('Belgium', 'USA', 'HAIMOUDI Djamel (ALG)'),
#  ('France', 'Germany', 'PITANA Nestor (ARG)'),
#  ('Brazil', 'Colombia', 'Carlos VELASCO CARBALLO (ESP)'),
#  ('Argentina', 'Belgium', 'Nicola RIZZOLI (ITA)'),
#  ('Netherlands', 'Costa Rica', 'Ravshan IRMATOV (UZB)'),
#  ('Brazil', 'Germany', 'RODRIGUEZ Marco (MEX)'),
#  ('Netherlands', 'Argentina', 'C�neyt �AKIR (TUR)'),
#  ('Brazil', 'Netherlands', 'HAIMOUDI Djamel (ALG)'),
#  ('Germany', 'Argentina', 'Nicola RIZZOLI (ITA)')]

# %%
# Example 3
# Find out any three matches that have had 5 away goals  
#
# %%sql
SELECT * FROM WorldCup Where "Away_Team_Goals" = 5 LIMIT 3
# Out:
#  * sqlite://
# Done.
# [(1938, '05 Jun 1938 - 17:30 ', 'First round', 'Stade de la Meinau', 'Strasbourg ', 'Brazil', 6, 5, 'Poland', 'Brazil win after extra time ', 13452.0, 0, 0, 'EKLIND Ivan (SWE)', 'POISSANT Louis (FRA)', 'KISSENBERGER Ernest (FRA)', 206, 1150, 'BRA', 'POL'),
#  (1954, '26 Jun 1954 - 17:00 ', 'Quarter-finals', 'La Pontaise', 'Lausanne ', 'Austria', 7, 5, 'Switzerland', ' ', 35000.0, 5, 4, 'FAULTLESS Charlie (SCO)', 'ASENSI Manuel (ESP)', 'SCHMETZER Emil (FRG)', 212, 1237, 'AUT', 'SUI'),
#  (1986, '18 Jun 1986 - 16:00 ', 'Round of 16', 'Estadio Corregidora', 'Queretaro ', 'Denmark', 1, 5, 'Spain', ' ', 38500.0, 1, 1, 'KEIZER Jan (NED)', 'BENNACEUR Ali (TUN)', 'DOTCHEV Bogdan (BUL)', 309, 511, 'DEN', 'ESP')]

# %% [markdown]
# ### <font color="green"> 1.4 Challenges</font>

# %%
# Challenge 1
# From the Interpol dataset, let's get countries with their respective 
# No. of National fugitives and Wanted fugitives
# 
# %%sql
--SELECT * FROM Interpol;
SELECT "Country","National Fugitives","Wanted Fugitives" FROM Interpol;
# Out:
#  * sqlite://
# Done.
# [('Albania', 3, 3),
#  ('Angola', 0, 0),
#  ('Argentina', 2, 2),
#  ('Australia', 1, 1),
#  ('Austria', 1, 1),
#  ('Bangladesh', 2, 1),
#  ('Belarus', 1, 1),
#  ('Belgium', 0, 2),
#  ('Belize', 1, 1),
#  ('Bolivia', 0, 0),
#  ('Botswana', 0, 1),
#  ('Brazil', 2, 4),
#  ('Cambodia', 0, 0),
#  ('Canada', 3, 4),
#  ('Cayman Islands', 0, 0),
#  ('Chile', 1, 1),
#  ('Colombia', 3, 0),
#  ('Congo', 0, 0),
#  ('Costa Rica', 0, 1),
#  ('Croatia', 1, 1),
#  ('Curaçao', 0, 1),
#  ('Czech Republic', 3, 3),
#  ('Denmark', 0, 2),
#  ('Dominican Republic', 1, 1),
#  ('Ecuador', 0, 0),
#  ('El Salvador', 2, 2),
#  ('Estonia', 1, 2),
#  ('Finland', 2, 2),
#  ('France', 0, 0),
#  ('Georgia, Asia', 2, 2),
#  ('Germany', 1, 0),
#  ('Greece', 1, 1),
#  ('Honduras', 1, 0),
#  ('Hungary', 2, 2),
#  ('India', 0, 0),
#  ('Indonesia', 1, 1),
#  ('Iraq', 1, 0),
#  ('Ireland', 2, 1),
#  ('Italy', 1, 1),
#  ('Kenya', 1, 1),
#  ('Lesotho', 0, 0),
#  ('Lithuania', 1, 1),
#  ('Macedonia', 0, 0),
#  ('Mali', 0, 1),
#  ('Malta', 0, 0),
#  ('Mexico', 3, 0),
#  ('Montenegro', 3, 2),
#  ('Morocco', 2, 0),
#  ('Mozambique', 0, 0),
#  ('Namibia', 0, 0),
#  ('New Zealand', 0, 0),
#  ('Nicaragua', 1, 1),
#  ('Norway', 0, 1),
#  ('Pakistan', 1, 0),
#  ('Panama', 0, 0),
#  ('Paraguay', 1, 1),
#  ('Peru', 2, 1),
#  ('Poland', 4, 4),
#  ('Qatar', 0, 0),
#  ('Romania', 4, 4),
#  ('Russia', 2, 1),
#  ('Serbia', 0, 0),
#  ('Slovakia', 2, 2),
#  ('Somalia', 1, 0),
#  ('South Africa', 3, 2),
#  ('Spain', 1, 2),
#  ('Swaziland', 1, 1),
#  ('Sweden', 2, 3),
#  ('Tanzania', 0, 1),
#  ('The Netherlands', 6, 3),
#  ('Turkey', 0, 0),
#  ('Ukraine', 1, 1),
#  ('United Kingdom', 6, 4),
#  ('United States', 8, 11),
#  ('Uruguay', 1, 1),
#  ('Venezuela', 0, 1),
#  ('Zambia', 1, 0),
#  ('Zimbabwe', 0, 0)]

# %%
# Challenge 2
# Using WorldCup dataset, find out which group 4 world cup matches 
# that were played in the city of Montevideo 
#
# %%sql
SELECT "MatchID","Home_Team_Name","Away_Team_Name" FROM WorldCup WHERE City="Montevideo " AND Stage="Group 4";
# Out:
#  * sqlite://
# Done.
# [(1090, 'USA', 'Belgium'),
#  (1097, 'USA', 'Paraguay'),
#  (1089, 'Paraguay', 'Belgium')]

# %%
# Challenge 3
# Answering the same question as challenge 2, we would like to get only one match
# 
# OUR CODE GOES HERE
# %%sql
SELECT "MatchID","Home_Team_Name","Away_Team_Name" FROM WorldCup WHERE City="Montevideo " AND Stage="Group 4" LIMIT 1;
# Out:
#  * sqlite://
# Done.
# [(1090, 'USA', 'Belgium')]

# %%
WorldCup.columns.values
# Out:
# array(['Datetime', 'Stage', 'Stadium', 'City', 'Home_Team_Name',
#        'Home_Team_Goals', 'Away_Team_Goals', 'Away_Team_Name',
#        'Win_conditions', 'Attendance', 'Halftime_Home_Goals',
#        'Halftime_Away_Goals', 'Referee', 'Assistant1', 'Assistant2',
#        'RoundID', 'MatchID', 'Home_Team_Initials', 'Away_Team_Initials'],
#       dtype=object)

# %%
WorldCup["City"].value_counts()
# Out:
# Mexico City        23
# Rio De Janeiro     18
# Montevideo         18
# Guadalajara        17
# Johannesburg       15
#                    ..
# Strasbourg          1
# Lille               1
# Udevalla            1
# Reims               1
# Le Havre            1
# Name: City, Length: 151, dtype: int64

# %%
# %%sql
# SELECT * FROM WorldCup
# WHERE City="Montevideo " AND Stage="Group 1";
# Out:
#  * sqlite://
# Done.
# [(1930, '13 Jul 1930 - 15:00 ', 'Group 1', 'Pocitos', 'Montevideo ', 'France', 4, 1, 'Mexico', ' ', 4444.0, 3, 0, 'LOMBARDI Domingo (URU)', 'CRISTOPHE Henry (BEL)', 'REGO Gilberto (BRA)', 201, 1096, 'FRA', 'MEX'),
#  (1930, '15 Jul 1930 - 16:00 ', 'Group 1', 'Parque Central', 'Montevideo ', 'Argentina', 1, 0, 'France', ' ', 23409.0, 0, 0, 'REGO Gilberto (BRA)', 'SAUCEDO Ulises (BOL)', 'RADULESCU Constantin (ROU)', 201, 1085, 'ARG', 'FRA'),
#  (1930, '16 Jul 1930 - 14:45 ', 'Group 1', 'Parque Central', 'Montevideo ', 'Chile', 3, 0, 'Mexico', ' ', 9249.0, 1, 0, 'CRISTOPHE Henry (BEL)', 'APHESTEGUY Martin (URU)', 'LANGENUS Jean (BEL)', 201, 1095, 'CHI', 'MEX'),
#  (1930, '19 Jul 1930 - 12:50 ', 'Group 1', 'Estadio Centenario', 'Montevideo ', 'Chile', 1, 0, 'France', ' ', 2000.0, 0, 0, 'TEJADA Anibal (URU)', 'LOMBARDI Domingo (URU)', 'REGO Gilberto (BRA)', 201, 1094, 'CHI', 'FRA'),
#  (1930, '19 Jul 1930 - 15:00 ', 'Group 1', 'Estadio Centenario', 'Montevideo ', 'Argentina', 6, 3, 'Mexico', ' ', 42100.0, 3, 1, 'SAUCEDO Ulises (BOL)', 'ALONSO Gualberto (URU)', 'RADULESCU Constantin (ROU)', 201, 1086, 'ARG', 'MEX'),
#  (1930, '22 Jul 1930 - 14:45 ', 'Group 1', 'Estadio Centenario', 'Montevideo ', 'Argentina', 3, 1, 'Chile', ' ', 41459.0, 2, 1, 'LANGENUS Jean (BEL)', 'CRISTOPHE Henry (BEL)', 'SAUCEDO Ulises (BOL)', 201, 1084, 'ARG', 'CHI')]

# %%
# %%sql
# SELECT * FROM Interpol LIMIT 10;
# Out:
#  * sqlite://
# Done.
# [('Albania', 3, 3, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/al.gif'),
#  ('Angola', 0, 0, 1, 'Northern Africa', 'http://www.crwflags.com/fotw/images/a/ao.gif'),
#  ('Argentina', 2, 2, 1, 'South America', 'http://www.crwflags.com/fotw/images/a/ar.gif'),
#  ('Australia', 1, 1, 2, 'Oceania', 'http://www.crwflags.com/fotw/images/a/au.gif'),
#  ('Austria', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/at.gif'),
#  ('Bangladesh', 2, 1, 1, 'Asia', 'http://www.crwflags.com/fotw/images/b/bd.gif'),
#  ('Belarus', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/b/by.gif'),
#  ('Belgium', 0, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/b/be.gif'),
#  ('Belize', 1, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/b/bz.gif'),
#  ('Bolivia', 0, 0, 2, 'South America', 'http://www.crwflags.com/fotw/images/b/bo.gif')]

# %%
# SELECT Country FROM Interpol LIMIT 10;
Interpol.columns.values
# Out:
# array(['National Fugitives', 'Wanted Fugitives',
#        'Possible Hosted Fugitives / Captured Fugitives', 'Region', 'Flag'],
#       dtype=object)

# %% [markdown]
# ## 1.5 Orderby

# %%
# Example 1
# Using the Interpol dataset, let's get all our records ordering 
# them by the region in ascending order
#
# %%sql
SELECT * FROM Interpol
ORDER BY Region ASC;
# Out:
#  * sqlite://
# Done.
# [('Bangladesh', 2, 1, 1, 'Asia', 'http://www.crwflags.com/fotw/images/b/bd.gif'),
#  ('Cambodia', 0, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/k/kh.gif'),
#  ('Georgia, Asia', 2, 2, 0, 'Asia', 'http://www.crwflags.com/fotw/images/g/ge.gif'),
#  ('India', 0, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/i/in.gif'),
#  ('Indonesia', 1, 1, 0, 'Asia', 'http://www.crwflags.com/fotw/images/i/id.gif'),
#  ('Iraq', 1, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/i/iq.gif'),
#  ('Pakistan', 1, 0, 2, 'Asia', 'http://www.crwflags.com/fotw/images/p/pk.gif'),
#  ('Qatar', 0, 0, 1, 'Asia', 'http://upload.wikimedia.org/wikipedia/commons/6/65/Flag_of_Qatar.svg'),
#  ('Belize', 1, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/b/bz.gif'),
#  ('Cayman Islands', 0, 0, 1, 'Central America', 'http://www.crwflags.com/fotw/images/k/ky.gif'),
#  ('Costa Rica', 0, 1, 2, 'Central America', 'http://www.crwflags.com/fotw/images/c/cr.gif'),
#  ('Curaçao', 0, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/c/cw.gif'),
#  ('Dominican Republic', 1, 1, 2, 'Central America', 'http://www.crwflags.com/fotw/images/d/do.gif'),
#  ('El Salvador', 2, 2, 0, 'Central America', 'http://www.crwflags.com/fotw/images/s/sv.gif'),
#  ('Honduras', 1, 0, 1, 'Central America', 'http://www.crwflags.com/fotw/images/h/hn.gif'),
#  ('Mexico', 3, 0, 6, 'Central America', 'http://www.crwflags.com/fotw/images/m/mx.gif'),
#  ('Nicaragua', 1, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/n/ni.gif'),
#  ('Panama', 0, 0, 2, 'Central America', 'http://www.crwflags.com/fotw/images/p/pa.gif'),
#  ('Albania', 3, 3, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/al.gif'),
#  ('Austria', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/at.gif'),
#  ('Belarus', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/b/by.gif'),
#  ('Belgium', 0, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/b/be.gif'),
#  ('Croatia', 1, 1, 1, 'Europe', 'http://www.crwflags.com/fotw/images/h/hr.gif'),
#  ('Czech Republic', 3, 3, 0, 'Europe', 'http://www.crwflags.com/fotw/images/c/cz.gif'),
#  ('Denmark', 0, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/d/dk.gif'),
#  ('Estonia', 1, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/e/ee.gif'),
#  ('Finland', 2, 2, 3, 'Europe', 'http://www.crwflags.com/fotw/images/f/fi.gif'),
#  ('France', 0, 0, 7, 'Europe', 'http://www.crwflags.com/fotw/images/f/fr.gif'),
#  ('Germany', 1, 0, 3, 'Europe', 'http://www.crwflags.com/fotw/images/d/de.gif'),
#  ('Greece', 1, 1, 3, 'Europe', 'http://www.crwflags.com/fotw/images/g/gr.gif'),
#  ('Hungary', 2, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/h/hu.gif'),
#  ('Ireland', 2, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/i/ie.gif'),
#  ('Italy', 1, 1, 3, 'Europe', 'http://www.crwflags.com/fotw/images/i/it.gif'),
#  ('Lithuania', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/l/lt.gif'),
#  ('Macedonia', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/mk.gif'),
#  ('Malta', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/mt.gif'),
#  ('Montenegro', 3, 2, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/me.gif'),
#  ('Norway', 0, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/n/no.gif'),
#  ('Poland', 4, 4, 3, 'Europe', 'http://www.crwflags.com/fotw/images/p/pl.gif'),
#  ('Romania', 4, 4, 0, 'Europe', 'http://www.crwflags.com/fotw/images/r/ro.gif'),
#  ('Serbia', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/r/rs.gif'),
#  ('Slovakia', 2, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/s/sk.gif'),
#  ('Spain', 1, 2, 13, 'Europe', 'http://www.crwflags.com/fotw/images/e/es.gif'),
#  ('Sweden', 2, 3, 1, 'Europe', 'http://www.crwflags.com/fotw/images/s/se.gif'),
#  ('The Netherlands', 6, 3, 8, 'Europe', 'http://www.crwflags.com/fotw/images/n/nl.gif'),
#  ('Turkey', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/t/tr.gif'),
#  ('Ukraine', 1, 1, 1, 'Europe', 'http://www.crwflags.com/fotw/images/u/ua.gif'),
#  ('United Kingdom', 6, 4, 7, 'Europe', 'http://www.crwflags.com/fotw/images/g/gb.gif'),
#  ('Russia', 2, 1, 3, 'Europe, Asia', 'http://www.crwflags.com/fotw/images/r/ru.gif'),
#  ('Canada', 3, 4, 2, 'North America', 'http://www.crwflags.com/fotw/images/c/ca.gif'),
#  ('United States', 8, 11, 6, 'North America', 'http://www.crwflags.com/fotw/images/u/us.gif'),
#  ('Angola', 0, 0, 1, 'Northern Africa', 'http://www.crwflags.com/fotw/images/a/ao.gif'),
#  ('Morocco', 2, 0, 3, 'Northern Africa', 'http://www.crwflags.com/fotw/images/m/ma.gif'),
#  ('Australia', 1, 1, 2, 'Oceania', 'http://www.crwflags.com/fotw/images/a/au.gif'),
#  ('New Zealand', 0, 0, 1, 'Oceania', 'http://www.crwflags.com/fotw/images/n/nz.gif'),
#  ('Argentina', 2, 2, 1, 'South America', 'http://www.crwflags.com/fotw/images/a/ar.gif'),
#  ('Bolivia', 0, 0, 2, 'South America', 'http://www.crwflags.com/fotw/images/b/bo.gif'),
#  ('Brazil', 2, 4, 3, 'South America', 'http://www.crwflags.com/fotw/images/b/br.gif'),
#  ('Chile', 1, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/c/cl.gif'),
#  ('Colombia', 3, 0, 1, 'South America', 'http://www.crwflags.com/fotw/images/c/co.gif'),
#  ('Ecuador', 0, 0, 1, 'South America', 'http://www.worldatlas.com/webimage/flags/countrys/zzzflags/eclarge.jpg'),
#  ('Paraguay', 1, 1, 1, 'South America', 'http://www.crwflags.com/fotw/images/p/py.gif'),
#  ('Peru', 2, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/p/pe.gif'),
#  ('Uruguay', 1, 1, 1, 'South America', 'http://www.crwflags.com/fotw/images/u/uy.gif'),
#  ('Venezuela', 0, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/v/ve.gif'),
#  ('Botswana', 0, 1, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/b/bw.gif'),
#  ('Lesotho', 0, 0, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/l/ls.gif'),
#  ('Mozambique', 0, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/m/mz.gif'),
#  ('Namibia', 0, 0, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/n/na.gif'),
#  ('South Africa', 3, 2, 4, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/za.gif'),
#  ('Swaziland', 1, 1, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/s/sz.gif'),
#  ('Zambia', 1, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/zm.gif'),
#  ('Zimbabwe', 0, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/zw.gif'),
#  ('Congo', 0, 0, 1, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/c/cg.gif'),
#  ('Kenya', 1, 1, 2, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/k/ke.gif'),
#  ('Mali', 0, 1, 0, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/m/ml.gif'),
#  ('Somalia', 1, 0, 0, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/s/so.gif'),
#  ('Tanzania', 0, 1, 2, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/t/tz.gif')]

# %%
# Example 2
# We can do the same as in example 1 but now having the records in descending order 
# as shown below
#
# %%sql
SELECT * FROM Interpol
ORDER BY Country DESC;
# Out:
#  * sqlite://
# Done.
# [('Zimbabwe', 0, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/zw.gif'),
#  ('Zambia', 1, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/zm.gif'),
#  ('Venezuela', 0, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/v/ve.gif'),
#  ('Uruguay', 1, 1, 1, 'South America', 'http://www.crwflags.com/fotw/images/u/uy.gif'),
#  ('United States', 8, 11, 6, 'North America', 'http://www.crwflags.com/fotw/images/u/us.gif'),
#  ('United Kingdom', 6, 4, 7, 'Europe', 'http://www.crwflags.com/fotw/images/g/gb.gif'),
#  ('Ukraine', 1, 1, 1, 'Europe', 'http://www.crwflags.com/fotw/images/u/ua.gif'),
#  ('Turkey', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/t/tr.gif'),
#  ('The Netherlands', 6, 3, 8, 'Europe', 'http://www.crwflags.com/fotw/images/n/nl.gif'),
#  ('Tanzania', 0, 1, 2, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/t/tz.gif'),
#  ('Sweden', 2, 3, 1, 'Europe', 'http://www.crwflags.com/fotw/images/s/se.gif'),
#  ('Swaziland', 1, 1, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/s/sz.gif'),
#  ('Spain', 1, 2, 13, 'Europe', 'http://www.crwflags.com/fotw/images/e/es.gif'),
#  ('South Africa', 3, 2, 4, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/za.gif'),
#  ('Somalia', 1, 0, 0, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/s/so.gif'),
#  ('Slovakia', 2, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/s/sk.gif'),
#  ('Serbia', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/r/rs.gif'),
#  ('Russia', 2, 1, 3, 'Europe, Asia', 'http://www.crwflags.com/fotw/images/r/ru.gif'),
#  ('Romania', 4, 4, 0, 'Europe', 'http://www.crwflags.com/fotw/images/r/ro.gif'),
#  ('Qatar', 0, 0, 1, 'Asia', 'http://upload.wikimedia.org/wikipedia/commons/6/65/Flag_of_Qatar.svg'),
#  ('Poland', 4, 4, 3, 'Europe', 'http://www.crwflags.com/fotw/images/p/pl.gif'),
#  ('Peru', 2, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/p/pe.gif'),
#  ('Paraguay', 1, 1, 1, 'South America', 'http://www.crwflags.com/fotw/images/p/py.gif'),
#  ('Panama', 0, 0, 2, 'Central America', 'http://www.crwflags.com/fotw/images/p/pa.gif'),
#  ('Pakistan', 1, 0, 2, 'Asia', 'http://www.crwflags.com/fotw/images/p/pk.gif'),
#  ('Norway', 0, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/n/no.gif'),
#  ('Nicaragua', 1, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/n/ni.gif'),
#  ('New Zealand', 0, 0, 1, 'Oceania', 'http://www.crwflags.com/fotw/images/n/nz.gif'),
#  ('Namibia', 0, 0, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/n/na.gif'),
#  ('Mozambique', 0, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/m/mz.gif'),
#  ('Morocco', 2, 0, 3, 'Northern Africa', 'http://www.crwflags.com/fotw/images/m/ma.gif'),
#  ('Montenegro', 3, 2, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/me.gif'),
#  ('Mexico', 3, 0, 6, 'Central America', 'http://www.crwflags.com/fotw/images/m/mx.gif'),
#  ('Malta', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/mt.gif'),
#  ('Mali', 0, 1, 0, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/m/ml.gif'),
#  ('Macedonia', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/mk.gif'),
#  ('Lithuania', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/l/lt.gif'),
#  ('Lesotho', 0, 0, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/l/ls.gif'),
#  ('Kenya', 1, 1, 2, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/k/ke.gif'),
#  ('Italy', 1, 1, 3, 'Europe', 'http://www.crwflags.com/fotw/images/i/it.gif'),
#  ('Ireland', 2, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/i/ie.gif'),
#  ('Iraq', 1, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/i/iq.gif'),
#  ('Indonesia', 1, 1, 0, 'Asia', 'http://www.crwflags.com/fotw/images/i/id.gif'),
#  ('India', 0, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/i/in.gif'),
#  ('Hungary', 2, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/h/hu.gif'),
#  ('Honduras', 1, 0, 1, 'Central America', 'http://www.crwflags.com/fotw/images/h/hn.gif'),
#  ('Greece', 1, 1, 3, 'Europe', 'http://www.crwflags.com/fotw/images/g/gr.gif'),
#  ('Germany', 1, 0, 3, 'Europe', 'http://www.crwflags.com/fotw/images/d/de.gif'),
#  ('Georgia, Asia', 2, 2, 0, 'Asia', 'http://www.crwflags.com/fotw/images/g/ge.gif'),
#  ('France', 0, 0, 7, 'Europe', 'http://www.crwflags.com/fotw/images/f/fr.gif'),
#  ('Finland', 2, 2, 3, 'Europe', 'http://www.crwflags.com/fotw/images/f/fi.gif'),
#  ('Estonia', 1, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/e/ee.gif'),
#  ('El Salvador', 2, 2, 0, 'Central America', 'http://www.crwflags.com/fotw/images/s/sv.gif'),
#  ('Ecuador', 0, 0, 1, 'South America', 'http://www.worldatlas.com/webimage/flags/countrys/zzzflags/eclarge.jpg'),
#  ('Dominican Republic', 1, 1, 2, 'Central America', 'http://www.crwflags.com/fotw/images/d/do.gif'),
#  ('Denmark', 0, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/d/dk.gif'),
#  ('Czech Republic', 3, 3, 0, 'Europe', 'http://www.crwflags.com/fotw/images/c/cz.gif'),
#  ('Curaçao', 0, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/c/cw.gif'),
#  ('Croatia', 1, 1, 1, 'Europe', 'http://www.crwflags.com/fotw/images/h/hr.gif'),
#  ('Costa Rica', 0, 1, 2, 'Central America', 'http://www.crwflags.com/fotw/images/c/cr.gif'),
#  ('Congo', 0, 0, 1, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/c/cg.gif'),
#  ('Colombia', 3, 0, 1, 'South America', 'http://www.crwflags.com/fotw/images/c/co.gif'),
#  ('Chile', 1, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/c/cl.gif'),
#  ('Cayman Islands', 0, 0, 1, 'Central America', 'http://www.crwflags.com/fotw/images/k/ky.gif'),
#  ('Canada', 3, 4, 2, 'North America', 'http://www.crwflags.com/fotw/images/c/ca.gif'),
#  ('Cambodia', 0, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/k/kh.gif'),
#  ('Brazil', 2, 4, 3, 'South America', 'http://www.crwflags.com/fotw/images/b/br.gif'),
#  ('Botswana', 0, 1, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/b/bw.gif'),
#  ('Bolivia', 0, 0, 2, 'South America', 'http://www.crwflags.com/fotw/images/b/bo.gif'),
#  ('Belize', 1, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/b/bz.gif'),
#  ('Belgium', 0, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/b/be.gif'),
#  ('Belarus', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/b/by.gif'),
#  ('Bangladesh', 2, 1, 1, 'Asia', 'http://www.crwflags.com/fotw/images/b/bd.gif'),
#  ('Austria', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/at.gif'),
#  ('Australia', 1, 1, 2, 'Oceania', 'http://www.crwflags.com/fotw/images/a/au.gif'),
#  ('Argentina', 2, 2, 1, 'South America', 'http://www.crwflags.com/fotw/images/a/ar.gif'),
#  ('Angola', 0, 0, 1, 'Northern Africa', 'http://www.crwflags.com/fotw/images/a/ao.gif'),
#  ('Albania', 3, 3, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/al.gif')]

# %%
# Example 3 
# Using the Worldcup dataset, we can select 5 World Cup Group 1 matches played 
# after 1950 and having them ordered by city in ascending order as shown below
#
# %%sql
SELECT * FROM WorldCup
WHERE Stage='Group 1' AND Year > 1950
ORDER BY City ASC
LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [(1962, '30 May 1962 - 15:00 ', 'Group 1', 'Carlos Dittborn', 'Arica ', 'Uruguay', 2, 1, 'Colombia', ' ', 7908.0, 0, 1, 'DOROGI Andor (HUN)', 'ETZEL FILHO Joao (BRA)', 'GALBA Karol (TCH)', 231, 1479, 'URU', 'COL'),
#  (1962, '31 May 1962 - 15:00 ', 'Group 1', 'Carlos Dittborn', 'Arica ', 'Soviet Union', 2, 0, 'Yugoslavia', ' ', 9622.0, 0, 0, 'DUSCH Albert (GER)', 'ETZEL FILHO Joao (BRA)', 'ROBLES Carlos (CHI)', 231, 1563, 'URS', 'YUG'),
#  (1962, '02 Jun 1962 - 15:00 ', 'Group 1', 'Carlos Dittborn', 'Arica ', 'Yugoslavia', 3, 1, 'Uruguay', ' ', 8829.0, 2, 1, 'GALBA Karol (TCH)', 'DUSCH Albert (GER)', 'JONNI Cesare (ITA)', 231, 1564, 'YUG', 'URU'),
#  (1962, '03 Jun 1962 - 15:00 ', 'Group 1', 'Carlos Dittborn', 'Arica ', 'Soviet Union', 4, 4, 'Colombia', ' ', 8040.0, 3, 1, 'ETZEL FILHO Joao (BRA)', 'DOROGI Andor (HUN)', 'ROBLES Carlos (CHI)', 231, 1478, 'URS', 'COL'),
#  (1962, '06 Jun 1962 - 15:00 ', 'Group 1', 'Carlos Dittborn', 'Arica ', 'Soviet Union', 2, 1, 'Uruguay', ' ', 9973.0, 1, 0, 'JONNI Cesare (ITA)', 'DOROGI Andor (HUN)', 'DUSCH Albert (GER)', 231, 1562, 'URS', 'URU')]

# %% [markdown]
# ### <font color="green"> 1.5 Challenges</font>

# %%
# Challenge 1
# Using Interpol Dataset, select all the records and order them by National Fugitives in ascending order
# 
# %%sql
SELECT * FROM Interpol ORDER BY "National Fugitives" ASC;
# Out:
#  * sqlite://
# Done.
# [('Angola', 0, 0, 1, 'Northern Africa', 'http://www.crwflags.com/fotw/images/a/ao.gif'),
#  ('Belgium', 0, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/b/be.gif'),
#  ('Bolivia', 0, 0, 2, 'South America', 'http://www.crwflags.com/fotw/images/b/bo.gif'),
#  ('Botswana', 0, 1, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/b/bw.gif'),
#  ('Cambodia', 0, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/k/kh.gif'),
#  ('Cayman Islands', 0, 0, 1, 'Central America', 'http://www.crwflags.com/fotw/images/k/ky.gif'),
#  ('Congo', 0, 0, 1, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/c/cg.gif'),
#  ('Costa Rica', 0, 1, 2, 'Central America', 'http://www.crwflags.com/fotw/images/c/cr.gif'),
#  ('Curaçao', 0, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/c/cw.gif'),
#  ('Denmark', 0, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/d/dk.gif'),
#  ('Ecuador', 0, 0, 1, 'South America', 'http://www.worldatlas.com/webimage/flags/countrys/zzzflags/eclarge.jpg'),
#  ('France', 0, 0, 7, 'Europe', 'http://www.crwflags.com/fotw/images/f/fr.gif'),
#  ('India', 0, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/i/in.gif'),
#  ('Lesotho', 0, 0, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/l/ls.gif'),
#  ('Macedonia', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/mk.gif'),
#  ('Mali', 0, 1, 0, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/m/ml.gif'),
#  ('Malta', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/mt.gif'),
#  ('Mozambique', 0, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/m/mz.gif'),
#  ('Namibia', 0, 0, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/n/na.gif'),
#  ('New Zealand', 0, 0, 1, 'Oceania', 'http://www.crwflags.com/fotw/images/n/nz.gif'),
#  ('Norway', 0, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/n/no.gif'),
#  ('Panama', 0, 0, 2, 'Central America', 'http://www.crwflags.com/fotw/images/p/pa.gif'),
#  ('Qatar', 0, 0, 1, 'Asia', 'http://upload.wikimedia.org/wikipedia/commons/6/65/Flag_of_Qatar.svg'),
#  ('Serbia', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/r/rs.gif'),
#  ('Tanzania', 0, 1, 2, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/t/tz.gif'),
#  ('Turkey', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/t/tr.gif'),
#  ('Venezuela', 0, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/v/ve.gif'),
#  ('Zimbabwe', 0, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/zw.gif'),
#  ('Australia', 1, 1, 2, 'Oceania', 'http://www.crwflags.com/fotw/images/a/au.gif'),
#  ('Austria', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/at.gif'),
#  ('Belarus', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/b/by.gif'),
#  ('Belize', 1, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/b/bz.gif'),
#  ('Chile', 1, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/c/cl.gif'),
#  ('Croatia', 1, 1, 1, 'Europe', 'http://www.crwflags.com/fotw/images/h/hr.gif'),
#  ('Dominican Republic', 1, 1, 2, 'Central America', 'http://www.crwflags.com/fotw/images/d/do.gif'),
#  ('Estonia', 1, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/e/ee.gif'),
#  ('Germany', 1, 0, 3, 'Europe', 'http://www.crwflags.com/fotw/images/d/de.gif'),
#  ('Greece', 1, 1, 3, 'Europe', 'http://www.crwflags.com/fotw/images/g/gr.gif'),
#  ('Honduras', 1, 0, 1, 'Central America', 'http://www.crwflags.com/fotw/images/h/hn.gif'),
#  ('Indonesia', 1, 1, 0, 'Asia', 'http://www.crwflags.com/fotw/images/i/id.gif'),
#  ('Iraq', 1, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/i/iq.gif'),
#  ('Italy', 1, 1, 3, 'Europe', 'http://www.crwflags.com/fotw/images/i/it.gif'),
#  ('Kenya', 1, 1, 2, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/k/ke.gif'),
#  ('Lithuania', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/l/lt.gif'),
#  ('Nicaragua', 1, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/n/ni.gif'),
#  ('Pakistan', 1, 0, 2, 'Asia', 'http://www.crwflags.com/fotw/images/p/pk.gif'),
#  ('Paraguay', 1, 1, 1, 'South America', 'http://www.crwflags.com/fotw/images/p/py.gif'),
#  ('Somalia', 1, 0, 0, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/s/so.gif'),
#  ('Spain', 1, 2, 13, 'Europe', 'http://www.crwflags.com/fotw/images/e/es.gif'),
#  ('Swaziland', 1, 1, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/s/sz.gif'),
#  ('Ukraine', 1, 1, 1, 'Europe', 'http://www.crwflags.com/fotw/images/u/ua.gif'),
#  ('Uruguay', 1, 1, 1, 'South America', 'http://www.crwflags.com/fotw/images/u/uy.gif'),
#  ('Zambia', 1, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/zm.gif'),
#  ('Argentina', 2, 2, 1, 'South America', 'http://www.crwflags.com/fotw/images/a/ar.gif'),
#  ('Bangladesh', 2, 1, 1, 'Asia', 'http://www.crwflags.com/fotw/images/b/bd.gif'),
#  ('Brazil', 2, 4, 3, 'South America', 'http://www.crwflags.com/fotw/images/b/br.gif'),
#  ('El Salvador', 2, 2, 0, 'Central America', 'http://www.crwflags.com/fotw/images/s/sv.gif'),
#  ('Finland', 2, 2, 3, 'Europe', 'http://www.crwflags.com/fotw/images/f/fi.gif'),
#  ('Georgia, Asia', 2, 2, 0, 'Asia', 'http://www.crwflags.com/fotw/images/g/ge.gif'),
#  ('Hungary', 2, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/h/hu.gif'),
#  ('Ireland', 2, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/i/ie.gif'),
#  ('Morocco', 2, 0, 3, 'Northern Africa', 'http://www.crwflags.com/fotw/images/m/ma.gif'),
#  ('Peru', 2, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/p/pe.gif'),
#  ('Russia', 2, 1, 3, 'Europe, Asia', 'http://www.crwflags.com/fotw/images/r/ru.gif'),
#  ('Slovakia', 2, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/s/sk.gif'),
#  ('Sweden', 2, 3, 1, 'Europe', 'http://www.crwflags.com/fotw/images/s/se.gif'),
#  ('Albania', 3, 3, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/al.gif'),
#  ('Canada', 3, 4, 2, 'North America', 'http://www.crwflags.com/fotw/images/c/ca.gif'),
#  ('Colombia', 3, 0, 1, 'South America', 'http://www.crwflags.com/fotw/images/c/co.gif'),
#  ('Czech Republic', 3, 3, 0, 'Europe', 'http://www.crwflags.com/fotw/images/c/cz.gif'),
#  ('Mexico', 3, 0, 6, 'Central America', 'http://www.crwflags.com/fotw/images/m/mx.gif'),
#  ('Montenegro', 3, 2, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/me.gif'),
#  ('South Africa', 3, 2, 4, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/za.gif'),
#  ('Poland', 4, 4, 3, 'Europe', 'http://www.crwflags.com/fotw/images/p/pl.gif'),
#  ('Romania', 4, 4, 0, 'Europe', 'http://www.crwflags.com/fotw/images/r/ro.gif'),
#  ('The Netherlands', 6, 3, 8, 'Europe', 'http://www.crwflags.com/fotw/images/n/nl.gif'),
#  ('United Kingdom', 6, 4, 7, 'Europe', 'http://www.crwflags.com/fotw/images/g/gb.gif'),
#  ('United States', 8, 11, 6, 'North America', 'http://www.crwflags.com/fotw/images/u/us.gif')]

# %%
# Challenge 2
# Using WorldCup Dataset, get the matches played in the Pocitos stadium and their attendance 
# later than 1950 and ordering them by attendance in descending order
#
# %%sql 
SELECT "MatchID","Attendance" WHERE "Stadium"="Pocitos " AND "Year"> 1950 ORDER BY "Attendance" ASC;
# Out:
#  * sqlite://
# Done.
# []

# %%
# Challenge 3
# Get the World Cup Matches played in France after 1970 ordered by years in descending order 
#
# %%sql
SELECT "Year","MatchID","City","Home_Team_Name","Away_Team_Name" FROM WorldCup WHERE Year BETWEEN 1970 AND 2000 ORDER BY "Year" ASC;
# Out:
#  * sqlite://
# Done.
# [(1970, 1902, 'Mexico City ', 'Mexico', 'Soviet Union'),
#  (1970, 1881, 'Puebla ', 'Uruguay', 'Israel'),
#  (1970, 1780, 'Leon ', 'Peru', 'Bulgaria'),
#  (1970, 1812, 'Guadalajara ', 'England', 'Romania'),
#  (1970, 1883, 'Toluca ', 'Italy', 'Sweden'),
#  (1970, 1839, 'Leon ', 'Germany FR', 'Morocco'),
#  (1970, 1770, 'Guadalajara ', 'Brazil', 'Czechoslovakia'),
#  (1970, 1747, 'Mexico City ', 'Belgium', 'El Salvador'),
#  (1970, 1884, 'Puebla ', 'Uruguay', 'Italy'),
#  (1970, 1893, 'Leon ', 'Peru', 'Morocco'),
#  (1970, 1919, 'Guadalajara ', 'Romania', 'Czechoslovakia'),
#  (1970, 1753, 'Mexico City ', 'Soviet Union', 'Belgium'),
#  (1970, 1880, 'Toluca ', 'Sweden', 'Israel'),
#  (1970, 1774, 'Leon ', 'Germany FR', 'Bulgaria'),
#  (1970, 1764, 'Guadalajara ', 'Brazil', 'England'),
#  (1970, 1820, 'Mexico City ', 'Mexico', 'El Salvador'),
#  (1970, 1922, 'Puebla ', 'Sweden', 'Uruguay'),
#  (1970, 1840, 'Leon ', 'Germany FR', 'Peru'),
#  (1970, 1769, 'Guadalajara ', 'Brazil', 'Romania'),
#  (1970, 1823, 'Mexico City ', 'Soviet Union', 'El Salvador'),
#  (1970, 1877, 'Toluca ', 'Italy', 'Israel'),
#  (1970, 1779, 'Leon ', 'Bulgaria', 'Morocco'),
#  (1970, 1813, 'Guadalajara ', 'England', 'Czechoslovakia'),
#  (1970, 1752, 'Mexico City ', 'Mexico', 'Belgium'),
#  (1970, 1882, 'Toluca ', 'Italy', 'Mexico'),
#  (1970, 1811, 'Leon ', 'Germany FR', 'England'),
#  (1970, 1768, 'Guadalajara ', 'Brazil', 'Peru'),
#  (1970, 1925, 'Mexico City ', 'Uruguay', 'Soviet Union'),
#  (1970, 1771, 'Guadalajara ', 'Brazil', 'Uruguay'),
#  (1970, 1838, 'Mexico City ', 'Italy', 'Germany FR'),
#  (1970, 1843, 'Mexico City ', 'Germany FR', 'Uruguay'),
#  (1970, 1765, 'Mexico City ', 'Brazil', 'Italy'),
#  (1974, 1986, 'Frankfurt/Main ', 'Brazil', 'Yugoslavia'),
#  (1974, 2003, 'Berlin West ', 'Germany FR', 'Chile'),
#  (1974, 1955, 'Hamburg ', 'German DR', 'Australia'),
#  (1974, 2176, 'Dortmund ', 'Zaire', 'Scotland'),
#  (1974, 2098, 'Hanover ', 'Uruguay', 'Netherlands'),
#  (1974, 1995, 'D�Sseldorf ', 'Sweden', 'Bulgaria'),
#  (1974, 2083, 'Munich ', 'Italy', 'Haiti'),
#  (1974, 1952, 'Stuttgart ', 'Poland', 'Argentina'),
#  (1974, 1954, 'Hamburg ', 'Australia', 'Germany FR'),
#  (1974, 1985, 'Frankfurt/Main ', 'Scotland', 'Brazil'),
#  (1974, 2004, 'Berlin West ', 'Chile', 'German DR'),
#  (1974, 2186, 'Gelsenkirchen ', 'Yugoslavia', 'Zaire'),
#  (1974, 2097, 'Dortmund ', 'Netherlands', 'Sweden'),
#  (1974, 1996, 'Hanover ', 'Bulgaria', 'Uruguay'),
#  (1974, 2085, 'Munich ', 'Haiti', 'Poland'),
#  (1974, 1949, 'Stuttgart ', 'Argentina', 'Italy'),
#  (1974, 2175, 'Frankfurt/Main ', 'Scotland', 'Yugoslavia'),
#  (1974, 1953, 'Berlin West ', 'Australia', 'Chile'),
#  (1974, 1987, 'Gelsenkirchen ', 'Zaire', 'Brazil'),
#  (1974, 2062, 'Hamburg ', 'German DR', 'Germany FR'),
#  (1974, 1990, 'Dortmund ', 'Bulgaria', 'Netherlands'),
#  (1974, 1947, 'Munich ', 'Argentina', 'Haiti'),
#  (1974, 2181, 'D�Sseldorf ', 'Sweden', 'Uruguay'),
#  (1974, 2129, 'Stuttgart ', 'Poland', 'Italy'),
#  (1974, 2066, 'D�Sseldorf ', 'Yugoslavia', 'Germany FR'),
#  (1974, 1982, 'Hanover ', 'Brazil', 'German DR'),
#  (1974, 1948, 'Gelsenkirchen ', 'Netherlands', 'Argentina'),
#  (1974, 2167, 'Stuttgart ', 'Sweden', 'Poland'),
#  (1974, 1945, 'Hanover ', 'Argentina', 'Brazil'),
#  (1974, 2170, 'Frankfurt/Main ', 'Poland', 'Yugoslavia'),
#  (1974, 2067, 'Gelsenkirchen ', 'German DR', 'Netherlands'),
#  (1974, 2065, 'D�Sseldorf ', 'Germany FR', 'Sweden'),
#  (1974, 2064, 'Frankfurt/Main ', 'Poland', 'Germany FR'),
#  (1974, 1983, 'Dortmund ', 'Netherlands', 'Brazil'),
#  (1974, 1946, 'Gelsenkirchen ', 'Argentina', 'German DR'),
#  (1974, 2182, 'D�Sseldorf ', 'Sweden', 'Yugoslavia'),
#  (1974, 1984, 'Munich ', 'Brazil', 'Poland'),
#  (1974, 2063, 'Munich ', 'Netherlands', 'Germany FR'),
#  (1978, 2351, 'Buenos Aires ', 'Germany FR', 'Poland'),
#  (1978, 2347, 'Mar Del Plata ', 'Italy', 'France'),
#  (1978, 2433, 'Rosario ', 'Tunisia', 'Mexico'),
#  (1978, 2199, 'Buenos Aires ', 'Argentina', 'Hungary'),
#  (1978, 2253, 'Mar Del Plata ', 'Sweden', 'Brazil'),
#  (1978, 2216, 'Buenos Aires ', 'Austria', 'Spain'),
#  (1978, 2451, 'Cordoba ', 'Peru', 'Scotland'),
#  (1978, 2388, 'Mendoza ', 'Netherlands', 'IR Iran'),
#  (1978, 2396, 'Mar Del Plata ', 'Italy', 'Hungary'),
#  (1978, 2454, 'Rosario ', 'Poland', 'Tunisia'),
#  (1978, 2350, 'Cordoba ', 'Germany FR', 'Mexico'),
#  (1978, 2197, 'Buenos Aires ', 'Argentina', 'France'),
#  (1978, 2246, 'Mar Del Plata ', 'Brazil', 'Spain'),
#  (1978, 2224, 'Buenos Aires ', 'Austria', 'Sweden'),
#  (1978, 2408, 'Cordoba ', 'Scotland', 'IR Iran'),
#  (1978, 2394, 'Mendoza ', 'Netherlands', 'Peru'),
#  (1978, 2344, 'Mar Del Plata ', 'France', 'Hungary'),
#  (1978, 2431, 'Rosario ', 'Poland', 'Mexico'),
#  (1978, 2352, 'Cordoba ', 'Germany FR', 'Tunisia'),
#  (1978, 2200, 'Buenos Aires ', 'Italy', 'Argentina'),
#  (1978, 2215, 'Mar Del Plata ', 'Brazil', 'Austria'),
#  (1978, 2337, 'Buenos Aires ', 'Spain', 'Sweden'),
#  (1978, 2405, 'Cordoba ', 'Peru', 'Iran'),
#  (1978, 2395, 'Mendoza ', 'Scotland', 'Netherlands'),
#  (1978, 2349, 'Buenos Aires ', 'Germany FR', 'Italy'),
#  (1978, 2220, 'Cordoba ', 'Netherlands', 'Austria'),
#  (1978, 2251, 'Mendoza ', 'Brazil', 'Peru'),
#  (1978, 2202, 'Rosario ', 'Argentina', 'Poland'),
#  (1978, 2450, 'Mendoza ', 'Poland', 'Peru'),
#  (1978, 2221, 'Buenos Aires ', 'Italy', 'Austria'),
#  (1978, 2348, 'Cordoba ', 'Germany FR', 'Netherlands'),
#  (1978, 2196, 'Rosario ', 'Argentina', 'Brazil'),
#  (1978, 2391, 'Buenos Aires ', 'Netherlands', 'Italy'),
#  (1978, 2217, 'Cordoba ', 'Austria', 'Germany FR'),
#  (1978, 2252, 'Mendoza ', 'Brazil', 'Poland'),
#  (1978, 2201, 'Rosario ', 'Argentina', 'Peru'),
#  (1978, 2247, 'Buenos Aires ', 'Brazil', 'Italy'),
#  (1978, 2198, 'Buenos Aires ', 'Argentina', 'Netherlands'),
#  (1982, 749, 'Barcelona ', 'Argentina', 'Belgium'),
#  (1982, 995, 'Vigo ', 'Italy', 'Poland'),
#  (1982, 791, 'Seville ', 'Brazil', 'Soviet Union'),
#  (1982, 833, 'La Coru�A ', 'Peru', 'Cameroon'),
#  (1982, 896, 'Elche ', 'Hungary', 'El Salvador'),
#  (1982, 1051, 'Malaga ', 'Scotland', 'New Zealand'),
#  (1982, 741, 'Gijon ', 'Germany FR', 'Algeria'),
#  (1982, 878, 'Bilbao ', 'England', 'France'),
#  (1982, 901, 'Valencia ', 'Spain', 'Honduras'),
#  (1982, 764, 'Oviedo ', 'Chile', 'Austria'),
#  (1982, 1012, 'Valladolid ', 'Czechoslovakia', 'Kuwait'),
#  (1982, 1044, 'Zaragoza ', 'Yugoslavia', 'Northern Ireland'),
#  (1982, 994, 'Vigo ', 'Italy', 'Peru'),
#  (1982, 752, 'Alicante ', 'Argentina', 'Hungary'),
#  (1982, 790, 'Seville ', 'Brazil', 'Scotland'),
#  (1982, 834, 'La Coru�A ', 'Poland', 'Cameroon'),
#  (1982, 774, 'Elche ', 'Belgium', 'El Salvador'),
#  (1982, 1054, 'Malaga ', 'Soviet Union', 'New Zealand'),
#  (1982, 813, 'Gijon ', 'Germany FR', 'Chile'),
#  (1982, 889, 'Bilbao ', 'England', 'Czechoslovakia'),
#  (1982, 903, 'Valencia ', 'Spain', 'Yugoslavia'),
#  (1982, 739, 'Oviedo ', 'Algeria', 'Austria'),
#  (1982, 919, 'Valladolid ', 'France', 'Kuwait'),
#  (1982, 959, 'Zaragoza ', 'Honduras', 'Northern Ireland'),
#  (1982, 1055, 'La Coru�A ', 'Poland', 'Peru'),
#  (1982, 779, 'Elche ', 'Belgium', 'Hungary'),
#  (1982, 1071, 'Malaga ', 'Soviet Union', 'Scotland'),
#  (1982, 828, 'Vigo ', 'Italy', 'Cameroon'),
#  (1982, 751, 'Alicante ', 'Argentina', 'El Salvador'),
#  (1982, 789, 'Seville ', 'Brazil', 'New Zealand'),
#  (1982, 740, 'Oviedo ', 'Algeria', 'Chile'),
#  (1982, 922, 'Valladolid ', 'France', 'Czechoslovakia'),
#  (1982, 962, 'Zaragoza ', 'Honduras', 'Yugoslavia'),
#  (1982, 770, 'Gijon ', 'Germany FR', 'Austria'),
#  (1982, 882, 'Bilbao ', 'England', 'Kuwait'),
#  (1982, 902, 'Valencia ', 'Northern Ireland', 'Spain'),
#  (1982, 767, 'Madrid ', 'Austria', 'France'),
#  (1982, 782, 'Barcelona ', 'Poland', 'Belgium'),
#  (1982, 753, 'Barcelona ', 'Italy', 'Argentina'),
#  (1982, 879, 'Madrid ', 'Germany FR', 'England'),
#  (1982, 771, 'Madrid ', 'Austria', 'Northern Ireland'),
#  (1982, 783, 'Barcelona ', 'Belgium', 'Soviet Union'),
#  (1982, 750, 'Barcelona ', 'Argentina', 'Brazil'),
#  (1982, 900, 'Madrid ', 'Germany FR', 'Spain'),
#  (1982, 920, 'Madrid ', 'France', 'Northern Ireland'),
#  (1982, 1058, 'Barcelona ', 'Poland', 'Soviet Union'),
#  (1982, 788, 'Barcelona ', 'Italy', 'Brazil'),
#  (1982, 877, 'Madrid ', 'Spain', 'England'),
#  (1982, 996, 'Barcelona ', 'Poland', 'Italy'),
#  (1982, 914, 'Seville ', 'Germany FR', 'France'),
#  (1982, 921, 'Alicante ', 'Poland', 'France'),
#  (1982, 923, 'Madrid ', 'Italy', 'Germany FR'),
#  (1986, 459, 'Mexico City ', 'Bulgaria', 'Italy'),
#  (1986, 468, 'Leon ', 'Canada', 'France'),
#  (1986, 439, 'Guadalajara ', 'Spain', 'Brazil'),
#  (1986, 610, 'Irapuato ', 'Soviet Union', 'Hungary'),
#  (1986, 395, 'Mexico City ', 'Argentina', 'Korea Republic'),
#  (1986, 674, 'Monterrey ', 'Morocco', 'Poland'),
#  (1986, 379, 'Guadalajara ', 'Algeria', 'Northern Ireland'),
#  (1986, 428, 'Mexico City ', 'Belgium', 'Mexico'),
#  (1986, 538, 'Monterrey ', 'Portugal', 'England'),
#  (1986, 628, 'Toluca ', 'Paraguay', 'Iraq'),
#  (1986, 517, 'Nezahualcoyotl ', 'Scotland', 'Denmark'),
#  (1986, 585, 'Queretaro ', 'Uruguay', 'Germany FR'),
#  (1986, 394, 'Puebla ', 'Italy', 'Argentina'),
#  (1986, 571, 'Leon ', 'France', 'Soviet Union'),
#  (1986, 460, 'Mexico City ', 'Korea Republic', 'Bulgaria'),
#  (1986, 475, 'Irapuato ', 'Hungary', 'Canada'),
#  (1986, 377, 'Guadalajara ', 'Brazil', 'Algeria'),
#  (1986, 533, 'Monterrey ', 'England', 'Morocco'),
#  (1986, 551, 'Guadalajara ', 'Northern Ireland', 'Spain'),
#  (1986, 680, 'Mexico City ', 'Mexico', 'Paraguay'),
#  (1986, 701, 'Monterrey ', 'Poland', 'Portugal'),
#  (1986, 427, 'Toluca ', 'Iraq', 'Belgium'),
#  (1986, 522, 'Nezahualcoyotl ', 'Denmark', 'Uruguay'),
#  (1986, 580, 'Queretaro ', 'Germany FR', 'Scotland'),
#  (1986, 567, 'Leon ', 'Hungary', 'France'),
#  (1986, 476, 'Irapuato ', 'Soviet Union', 'Canada'),
#  (1986, 643, 'Puebla ', 'Korea Republic', 'Italy'),
#  (1986, 389, 'Mexico City ', 'Argentina', 'Bulgaria'),
#  (1986, 429, 'Toluca ', 'Paraguay', 'Belgium'),
#  (1986, 627, 'Mexico City ', 'Iraq', 'Mexico'),
#  (1986, 675, 'Guadalajara ', 'Portugal', 'Morocco'),
#  (1986, 537, 'Monterrey ', 'England', 'Poland'),
#  (1986, 441, 'Guadalajara ', 'Northern Ireland', 'Brazil'),
#  (1986, 378, 'Monterrey ', 'Algeria', 'Spain'),
#  (1986, 712, 'Nezahualcoyotl ', 'Scotland', 'Uruguay'),
#  (1986, 512, 'Queretaro ', 'Denmark', 'Germany FR'),
#  (1986, 432, 'Leon ', 'Soviet Union', 'Belgium'),
#  (1986, 463, 'Mexico City ', 'Mexico', 'Bulgaria'),
#  (1986, 398, 'Puebla ', 'Argentina', 'Uruguay'),
#  (1986, 444, 'Guadalajara ', 'Brazil', 'Poland'),
#  (1986, 568, 'Mexico City ', 'Italy', 'France'),
#  (1986, 574, 'Monterrey ', 'Morocco', 'Germany FR'),
#  (1986, 536, 'Mexico City ', 'England', 'Paraguay'),
#  (1986, 511, 'Queretaro ', 'Denmark', 'Spain'),
#  (1986, 440, 'Guadalajara ', 'Brazil', 'France'),
#  (1986, 575, 'Monterrey ', 'Germany FR', 'Mexico'),
#  (1986, 421, 'Puebla ', 'Spain', 'Belgium'),
#  (1986, 392, 'Mexico City ', 'Argentina', 'England'),
#  (1986, 564, 'Guadalajara ', 'France', 'Germany FR'),
#  (1986, 388, 'Mexico City ', 'Argentina', 'Belgium'),
#  (1986, 422, 'Puebla ', 'France', 'Belgium'),
#  (1986, 393, 'Mexico City ', 'Argentina', 'Germany FR'),
#  (1990, 26, 'Milan ', 'Argentina', 'Cameroon'),
#  (1990, 342, 'Bari ', 'Soviet Union', 'Romania'),
#  (1990, 119, 'Bologna ', 'rn">United Arab Emirates', 'Colombia'),
#  (1990, 42, 'Rome ', 'Italy', 'Austria'),
#  (1990, 355, 'Florence ', 'USA', 'Czechoslovakia'),
#  (1990, 75, 'Turin ', 'Brazil', 'Sweden'),
#  (1990, 201, 'Milan ', 'Germany FR', 'Yugoslavia'),
#  (1990, 127, 'Genoa ', 'Costa Rica', 'Scotland'),
#  (1990, 161, 'Cagliari ', 'England', 'rn">Republic of Ireland'),
#  (1990, 57, 'Verona ', 'Belgium', 'Korea Republic'),
#  (1990, 151, 'Palermo ', 'Netherlands', 'Egypt'),
#  (1990, 180, 'Udine ', 'Uruguay', 'Spain'),
#  (1990, 30, 'Naples ', 'Argentina', 'Soviet Union'),
#  (1990, 108, 'Bari ', 'Cameroon', 'Romania'),
#  (1990, 120, 'Bologna ', 'Yugoslavia', 'Colombia'),
#  (1990, 265, 'Rome ', 'Italy', 'USA'),
#  (1990, 43, 'Florence ', 'Austria', 'Czechoslovakia'),
#  (1990, 198, 'Milan ', 'Germany FR', 'rn">United Arab Emirates'),
#  (1990, 73, 'Turin ', 'Brazil', 'Costa Rica'),
#  (1990, 348, 'Genoa ', 'Sweden', 'Scotland'),
#  (1990, 160, 'Cagliari ', 'England', 'Netherlands'),
#  (1990, 152, 'Palermo ', 'rn">Republic of Ireland', 'Egypt'),
#  (1990, 175, 'Udine ', 'Korea Republic', 'Spain'),
#  (1990, 66, 'Verona ', 'Belgium', 'Uruguay'),
#  (1990, 29, 'Naples ', 'Argentina', 'Romania'),
#  (1990, 111, 'Bari ', 'Cameroon', 'Soviet Union'),
#  (1990, 114, 'Milan ', 'Germany FR', 'Colombia'),
#  (1990, 364, 'Bologna ', 'Yugoslavia', 'rn">United Arab Emirates'),
#  (1990, 263, 'Rome ', 'Italy', 'Czechoslovakia'),
#  (1990, 48, 'Florence ', 'Austria', 'USA'),
#  (1990, 74, 'Turin ', 'Brazil', 'Scotland'),
#  (1990, 128, 'Genoa ', 'Sweden', 'Costa Rica'),
#  (1990, 290, 'Udine ', 'Korea Republic', 'Uruguay'),
#  (1990, 56, 'Verona ', 'Belgium', 'Spain'),
#  (1990, 228, 'Palermo ', 'rn">Republic of Ireland', 'Netherlands'),
#  (1990, 150, 'Cagliari ', 'England', 'Egypt'),
#  (1990, 102, 'Naples ', 'Cameroon', 'Colombia'),
#  (1990, 129, 'Bari ', 'Czechoslovakia', 'Costa Rica'),
#  (1990, 25, 'Turin ', 'Brazil', 'Argentina'),
#  (1990, 196, 'Milan ', 'Germany FR', 'Netherlands'),
#  (1990, 248, 'Genoa ', 'rn">Republic of Ireland', 'Romania'),
#  (1990, 264, 'Rome ', 'Italy', 'Uruguay'),
#  (1990, 181, 'Verona ', 'Spain', 'Yugoslavia'),
#  (1990, 55, 'Bologna ', 'England', 'Belgium'),
#  (1990, 31, 'Florence ', 'Yugoslavia', 'Argentina'),
#  (1990, 243, 'Rome ', 'Italy', 'rn">Republic of Ireland'),
#  (1990, 197, 'Milan ', 'Germany FR', 'Czechoslovakia'),
#  (1990, 103, 'Naples ', 'England', 'Cameroon'),
#  (1990, 28, 'Naples ', 'Italy', 'Argentina'),
#  (1990, 159, 'Turin ', 'Germany FR', 'England'),
#  (1990, 162, 'Bari ', 'Italy', 'England'),
#  (1990, 27, 'Rome ', 'Germany FR', 'Argentina'),
#  (1994, 3050, 'Dallas ', 'Spain', 'Korea Republic'),
#  (1994, 3049, 'Chicago ', 'Germany', 'Bolivia'),
#  (1994, 3051, 'Detroit ', 'USA', 'Switzerland'),
#  (1994, 3052, 'New York/New Jersey ', 'Italy', 'rn">Republic of Ireland'),
#  (1994, 3053, 'Los Angeles ', 'Colombia', 'Romania'),
#  (1994, 3054, 'Orlando ', 'Belgium', 'Morocco'),
#  (1994, 3055, 'Washington Dc ', 'Norway', 'Mexico'),
#  (1994, 3056, 'Los Angeles ', 'Cameroon', 'Sweden'),
#  (1994, 3058, 'Washington Dc ', 'Netherlands', 'Saudi Arabia'),
#  (1994, 3057, 'San Francisco ', 'Brazil', 'Russia'),
#  (1994, 3059, 'Boston ', 'Argentina', 'Greece'),
#  (1994, 3061, 'Dallas ', 'Nigeria', 'Bulgaria'),
#  (1994, 3060, 'Chicago ', 'Germany', 'Spain'),
#  (1994, 3062, 'Detroit ', 'Romania', 'Switzerland'),
#  (1994, 3063, 'Los Angeles ', 'USA', 'Colombia'),
#  (1994, 3064, 'New York/New Jersey ', 'Italy', 'Norway'),
#  (1994, 3065, 'Boston ', 'Korea Republic', 'Bolivia'),
#  (1994, 3066, 'Orlando ', 'Mexico', 'rn">Republic of Ireland'),
#  (1994, 3068, 'Detroit ', 'Sweden', 'Russia'),
#  (1994, 3067, 'San Francisco ', 'Brazil', 'Cameroon'),
#  (1994, 3069, 'Orlando ', 'Belgium', 'Netherlands'),
#  (1994, 3070, 'New York/New Jersey ', 'Saudi Arabia', 'Morocco'),
#  (1994, 3071, 'Boston ', 'Argentina', 'Nigeria'),
#  (1994, 3072, 'Chicago ', 'Bulgaria', 'Greece'),
#  (1994, 3073, 'Los Angeles ', 'USA', 'Romania'),
#  (1994, 3074, 'San Francisco ', 'Switzerland', 'Colombia'),
#  (1994, 3076, 'Dallas ', 'Germany', 'Korea Republic'),
#  (1994, 3075, 'Chicago ', 'Bolivia', 'Spain'),
#  (1994, 3077, 'New York/New Jersey ', 'rn">Republic of Ireland', 'Norway'),
#  (1994, 3080, 'Detroit ', 'Brazil', 'Sweden'),
#  (1994, 3078, 'Washington Dc ', 'Italy', 'Mexico'),
#  (1994, 3079, 'San Francisco ', 'Russia', 'Cameroon'),
#  (1994, 3081, 'Orlando ', 'Morocco', 'Netherlands'),
#  (1994, 3082, 'Washington Dc ', 'Belgium', 'Saudi Arabia'),
#  (1994, 3083, 'Boston ', 'Greece', 'Nigeria'),
#  (1994, 3084, 'Dallas ', 'Argentina', 'Bulgaria'),
#  (1994, 3085, 'Chicago ', 'Germany', 'Belgium'),
#  (1994, 3086, 'Washington Dc ', 'Spain', 'Switzerland'),
#  (1994, 3087, 'Dallas ', 'Saudi Arabia', 'Sweden'),
#  (1994, 3088, 'Los Angeles ', 'Romania', 'Argentina'),
#  (1994, 3089, 'Orlando ', 'Netherlands', 'rn">Republic of Ireland'),
#  (1994, 3090, 'San Francisco ', 'Brazil', 'USA'),
#  (1994, 3091, 'Boston ', 'Nigeria', 'Italy'),
#  (1994, 3092, 'New York/New Jersey ', 'Mexico', 'Bulgaria'),
#  (1994, 3097, 'Boston ', 'Italy', 'Spain'),
#  (1994, 3098, 'Dallas ', 'Netherlands', 'Brazil'),
#  (1994, 3096, 'New York/New Jersey ', 'Bulgaria', 'Germany'),
#  (1994, 3095, 'San Francisco ', 'Romania', 'Sweden'),
#  (1994, 3100, 'New York/New Jersey ', 'Bulgaria', 'Italy'),
#  (1994, 3099, 'Los Angeles ', 'Sweden', 'Brazil'),
#  (1994, 3103, 'Los Angeles ', 'Sweden', 'Bulgaria'),
#  (1994, 3104, 'Los Angeles ', 'Brazil', 'Italy'),
#  (1998, 4000, 'Saint-Denis ', 'Brazil', 'Scotland'),
#  (1998, 8725, 'Montpellier ', 'Morocco', 'Norway'),
#  (1998, 8726, 'Bordeaux ', 'Italy', 'Chile'),
#  (1998, 8727, 'Toulouse ', 'Cameroon', 'Austria'),
#  (1998, 8728, 'Montpellier ', 'Paraguay', 'Bulgaria'),
#  (1998, 8729, 'Lens ', 'Saudi Arabia', 'Denmark'),
#  (1998, 8730, 'Marseilles ', 'France', 'South Africa'),
#  (1998, 8731, 'Nantes ', 'Spain', 'Nigeria'),
#  (1998, 8732, 'Lyon ', 'Korea Republic', 'Mexico'),
#  (1998, 8733, 'Saint-Denis ', 'Netherlands', 'Belgium'),
#  (1998, 8734, 'Toulouse ', 'Argentina', 'Japan'),
#  (1998, 8735, 'Saint-Etienne ', 'Yugoslavia', 'Iran'),
#  (1998, 8736, 'Lens ', 'Jamaica', 'Croatia'),
#  (1998, 8740, 'Marseilles ', 'England', 'Tunisia'),
#  (1998, 8739, 'Lyon ', 'Romania', 'Colombia'),
#  (1998, 8738, 'Paris ', 'Germany', 'USA'),
#  (1998, 8741, 'Bordeaux ', 'Scotland', 'Norway'),
#  (1998, 8742, 'Nantes ', 'Brazil', 'Morocco'),
#  (1998, 8743, 'Saint-Etienne ', 'Chile', 'Austria'),
#  (1998, 8744, 'Montpellier ', 'Italy', 'Cameroon'),
#  (1998, 8746, 'Toulouse ', 'South Africa', 'Denmark'),
#  (1998, 8745, 'Saint-Denis ', 'France', 'Saudi Arabia'),
#  (1998, 8747, 'Paris ', 'Nigeria', 'Bulgaria'),
#  (1998, 8748, 'Saint-Etienne ', 'Spain', 'Paraguay'),
#  (1998, 8751, 'Nantes ', 'Japan', 'Croatia'),
#  (1998, 8750, 'Bordeaux ', 'Belgium', 'Mexico'),
#  (1998, 8749, 'Marseilles ', 'Netherlands', 'Korea Republic'),
#  (1998, 8753, 'Lens ', 'Germany', 'Yugoslavia'),
#  (1998, 8752, 'Paris ', 'Argentina', 'Jamaica'),
#  (1998, 8754, 'Lyon ', 'USA', 'Iran'),
#  (1998, 8755, 'Montpellier ', 'Colombia', 'Tunisia'),
#  (1998, 8756, 'Toulouse ', 'Romania', 'England'),
#  (1998, 8757, 'Saint-Denis ', 'Italy', 'Austria'),
#  (1998, 8760, 'Nantes ', 'Chile', 'Cameroon'),
#  (1998, 8758, 'Saint-Etienne ', 'Scotland', 'Morocco'),
#  (1998, 8759, 'Marseilles ', 'Brazil', 'Norway'),
#  (1998, 8762, 'Lyon ', 'France', 'Denmark'),
#  (1998, 8764, 'Bordeaux ', 'South Africa', 'Saudi Arabia'),
#  (1998, 8761, 'Lens ', 'Spain', 'Bulgaria'),
#  (1998, 8763, 'Toulouse ', 'Nigeria', 'Paraguay'),
#  (1998, 8765, 'Paris ', 'Belgium', 'Korea Republic'),
#  (1998, 8766, 'Saint-Etienne ', 'Netherlands', 'Mexico'),
#  (1998, 8767, 'Montpellier ', 'Germany', 'Iran'),
#  (1998, 8768, 'Nantes ', 'USA', 'Yugoslavia'),
#  (1998, 8771, 'Lyon ', 'Japan', 'Jamaica'),
#  (1998, 8772, 'Bordeaux ', 'Argentina', 'Croatia'),
#  (1998, 8769, 'Saint-Denis ', 'Romania', 'Tunisia'),
#  (1998, 8770, 'Lens ', 'Colombia', 'England'),
#  (1998, 8774, 'Marseilles ', 'Italy', 'Norway'),
#  (1998, 8773, 'Paris ', 'Brazil', 'Chile'),
#  (1998, 8776, 'Lens ', 'France', 'Paraguay'),
#  (1998, 8775, 'Saint-Denis ', 'Nigeria', 'Denmark'),
#  (1998, 8777, 'Montpellier ', 'Germany', 'Mexico'),
#  (1998, 8778, 'Toulouse ', 'Netherlands', 'Yugoslavia'),
#  (1998, 8780, 'Bordeaux ', 'Romania', 'Croatia'),
#  (1998, 8779, 'Saint-Etienne ', 'Argentina', 'England'),
#  (1998, 8781, 'Saint-Denis ', 'Italy', 'France'),
#  (1998, 8782, 'Nantes ', 'Brazil', 'Denmark'),
#  (1998, 8784, 'Marseilles ', 'Netherlands', 'Argentina'),
#  (1998, 8783, 'Lyon ', 'Germany', 'Croatia'),
#  (1998, 8785, 'Marseilles ', 'Brazil', 'Netherlands'),
#  (1998, 8786, 'Saint-Denis ', 'France', 'Croatia'),
#  (1998, 8787, 'Paris ', 'Netherlands', 'Croatia'),
#  (1998, 8788, 'Saint-Denis ', 'Brazil', 'France')]

# %% [markdown]
# ## 1.6 Where

# %%
# Example 1
# From our Interpol dataset, let's find out which Countries have had three or more than three National Fugitives.
#
# %%sql
SELECT "Country","National Fugitives" FROM Interpol WHERE "National Fugitives" >=3;
# Out:
#  * sqlite://
# Done.
# [('Albania', 3),
#  ('Canada', 3),
#  ('Colombia', 3),
#  ('Czech Republic', 3),
#  ('Mexico', 3),
#  ('Montenegro', 3),
#  ('Poland', 4),
#  ('Romania', 4),
#  ('South Africa', 3),
#  ('The Netherlands', 6),
#  ('United Kingdom', 6),
#  ('United States', 8)]

# %%
# Example 2
# From our Interpol dataset, let's get the European countries and the no of Wanted fugitives they have
#
# %%sql
SELECT Country, "Wanted Fugitives" FROM Interpol
WHERE Region = 'Europe';
# Out:
#  * sqlite://
# Done.
# [('Albania', 3),
#  ('Austria', 1),
#  ('Belarus', 1),
#  ('Belgium', 2),
#  ('Croatia', 1),
#  ('Czech Republic', 3),
#  ('Denmark', 2),
#  ('Estonia', 2),
#  ('Finland', 2),
#  ('France', 0),
#  ('Germany', 0),
#  ('Greece', 1),
#  ('Hungary', 2),
#  ('Ireland', 1),
#  ('Italy', 1),
#  ('Lithuania', 1),
#  ('Macedonia', 0),
#  ('Malta', 0),
#  ('Montenegro', 2),
#  ('Norway', 1),
#  ('Poland', 4),
#  ('Romania', 4),
#  ('Serbia', 0),
#  ('Slovakia', 2),
#  ('Spain', 2),
#  ('Sweden', 3),
#  ('The Netherlands', 3),
#  ('Turkey', 0),
#  ('Ukraine', 1),
#  ('United Kingdom', 4)]

# %%
# Example 3
# From our WorldCup dataset, Let us select the home teams, away teams 
# and the respective no. of home team goals, no. of away team goals
# for the years after 1950
#
# %%sql
SELECT Year, Stage, Home_Team_Name, Home_Team_Goals, Away_Team_Name, Away_Team_Goals FROM WorldCup
WHERE Year > 1930
LIMIT 7;
# Out:
#  * sqlite://
# Done.
# [(1934, 'Preliminary round', 'Austria', 3, 'France', 2),
#  (1934, 'Preliminary round', 'Hungary', 4, 'Egypt', 2),
#  (1934, 'Preliminary round', 'Switzerland', 3, 'Netherlands', 2),
#  (1934, 'Preliminary round', 'Sweden', 3, 'Argentina', 2),
#  (1934, 'Preliminary round', 'Germany', 5, 'Belgium', 2),
#  (1934, 'Preliminary round', 'Spain', 3, 'Brazil', 1),
#  (1934, 'Preliminary round', 'Italy', 7, 'USA', 1)]

# %% [markdown]
# ### <font color="green"> 1.6 Challenges</font>

# %%
# Challenge 1
# From our Interpol dataset, find out which  country had the most Captured Fugitives 
#
# %%sql
SELECT "Country","Possible Hosted Fugitives / Captured Fugitives" FROM Interpol WHERE "Possible Hosted Fugitives / Captured Fugitives"=(SELECT MAX("Possible Hosted Fugitives / Captured Fugitives") FROM Interpol);
# Out:
#  * sqlite://
# Done.
# [('Spain', 13)]

# %%
# Challenge 2
# Using our Interpol dataset, get the european and asian countries;
#
# %%sql
SELECT "Country","Region" FROM Interpol WHERE (Region="Europe" OR Region="Asia");
# Out:
#  * sqlite://
# Done.
# [('Albania', 'Europe'),
#  ('Austria', 'Europe'),
#  ('Bangladesh', 'Asia'),
#  ('Belarus', 'Europe'),
#  ('Belgium', 'Europe'),
#  ('Cambodia', 'Asia'),
#  ('Croatia', 'Europe'),
#  ('Czech Republic', 'Europe'),
#  ('Denmark', 'Europe'),
#  ('Estonia', 'Europe'),
#  ('Finland', 'Europe'),
#  ('France', 'Europe'),
#  ('Georgia, Asia', 'Asia'),
#  ('Germany', 'Europe'),
#  ('Greece', 'Europe'),
#  ('Hungary', 'Europe'),
#  ('India', 'Asia'),
#  ('Indonesia', 'Asia'),
#  ('Iraq', 'Asia'),
#  ('Ireland', 'Europe'),
#  ('Italy', 'Europe'),
#  ('Lithuania', 'Europe'),
#  ('Macedonia', 'Europe'),
#  ('Malta', 'Europe'),
#  ('Montenegro', 'Europe'),
#  ('Norway', 'Europe'),
#  ('Pakistan', 'Asia'),
#  ('Poland', 'Europe'),
#  ('Qatar', 'Asia'),
#  ('Romania', 'Europe'),
#  ('Serbia', 'Europe'),
#  ('Slovakia', 'Europe'),
#  ('Spain', 'Europe'),
#  ('Sweden', 'Europe'),
#  ('The Netherlands', 'Europe'),
#  ('Turkey', 'Europe'),
#  ('Ukraine', 'Europe'),
#  ('United Kingdom', 'Europe')]

# %%
# Challenge 3 
# From our Interpol dataset, find out which top countries had the least National fugities
#
# %%sql
SELECT "Country", "National Fugitives" FROM Interpol WHERE "National Fugitives"=(SELECT MIN("National Fugitives") FROM Interpol);
# Out:
#  * sqlite://
# Done.
# [('Angola', 0),
#  ('Belgium', 0),
#  ('Bolivia', 0),
#  ('Botswana', 0),
#  ('Cambodia', 0),
#  ('Cayman Islands', 0),
#  ('Congo', 0),
#  ('Costa Rica', 0),
#  ('Curaçao', 0),
#  ('Denmark', 0),
#  ('Ecuador', 0),
#  ('France', 0),
#  ('India', 0),
#  ('Lesotho', 0),
#  ('Macedonia', 0),
#  ('Mali', 0),
#  ('Malta', 0),
#  ('Mozambique', 0),
#  ('Namibia', 0),
#  ('New Zealand', 0),
#  ('Norway', 0),
#  ('Panama', 0),
#  ('Qatar', 0),
#  ('Serbia', 0),
#  ('Tanzania', 0),
#  ('Turkey', 0),
#  ('Venezuela', 0),
#  ('Zimbabwe', 0)]

# %% [markdown]
# ## 1.7 Between

# %%
# Example 1
# Select the countries with national fugitives between 0 and 3 ordered by nationnal fugitives ascending order
#
# %%sql
SELECT Country, "National Fugitives" FROM Interpol
WHERE "National Fugitives" BETWEEN 0 AND 3 ORDER BY "National Fugitives" ASC;
# Out:
#  * sqlite://
# Done.
# [('Angola', 0),
#  ('Belgium', 0),
#  ('Bolivia', 0),
#  ('Botswana', 0),
#  ('Cambodia', 0),
#  ('Cayman Islands', 0),
#  ('Congo', 0),
#  ('Costa Rica', 0),
#  ('Curaçao', 0),
#  ('Denmark', 0),
#  ('Ecuador', 0),
#  ('France', 0),
#  ('India', 0),
#  ('Lesotho', 0),
#  ('Macedonia', 0),
#  ('Mali', 0),
#  ('Malta', 0),
#  ('Mozambique', 0),
#  ('Namibia', 0),
#  ('New Zealand', 0),
#  ('Norway', 0),
#  ('Panama', 0),
#  ('Qatar', 0),
#  ('Serbia', 0),
#  ('Tanzania', 0),
#  ('Turkey', 0),
#  ('Venezuela', 0),
#  ('Zimbabwe', 0),
#  ('Australia', 1),
#  ('Austria', 1),
#  ('Belarus', 1),
#  ('Belize', 1),
#  ('Chile', 1),
#  ('Croatia', 1),
#  ('Dominican Republic', 1),
#  ('Estonia', 1),
#  ('Germany', 1),
#  ('Greece', 1),
#  ('Honduras', 1),
#  ('Indonesia', 1),
#  ('Iraq', 1),
#  ('Italy', 1),
#  ('Kenya', 1),
#  ('Lithuania', 1),
#  ('Nicaragua', 1),
#  ('Pakistan', 1),
#  ('Paraguay', 1),
#  ('Somalia', 1),
#  ('Spain', 1),
#  ('Swaziland', 1),
#  ('Ukraine', 1),
#  ('Uruguay', 1),
#  ('Zambia', 1),
#  ('Argentina', 2),
#  ('Bangladesh', 2),
#  ('Brazil', 2),
#  ('El Salvador', 2),
#  ('Finland', 2),
#  ('Georgia, Asia', 2),
#  ('Hungary', 2),
#  ('Ireland', 2),
#  ('Morocco', 2),
#  ('Peru', 2),
#  ('Russia', 2),
#  ('Slovakia', 2),
#  ('Sweden', 2),
#  ('Albania', 3),
#  ('Canada', 3),
#  ('Colombia', 3),
#  ('Czech Republic', 3),
#  ('Mexico', 3),
#  ('Montenegro', 3),
#  ('South Africa', 3)]

# %%
# Example 2
# Select the countries with national fugitives not between 0 and 4 ordered by nationnal fugitives ascending order
#
# %%sql
SELECT Country, "National Fugitives" FROM Interpol
WHERE "National Fugitives" NOT BETWEEN 0 AND 4 ORDER BY "National Fugitives" ASC;
# Out:
#  * sqlite://
# Done.
# [('The Netherlands', 6), ('United Kingdom', 6), ('United States', 8)]

# %%
# Example 3
# Select any 5 matches played after 1950 which did not have the home team as Germany
#
# %%sql
SELECT * FROM WorldCup
WHERE NOT "Home Team Name" = 'Germany' AND NOT Year < 1950
LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [(1950, '24 Jun 1950 - 15:00 ', 'Group 1', 'Maracan� - Est�dio Jornalista M�rio Filho', 'Rio De Janeiro ', 'Brazil', 4, 0, 'Mexico', ' ', 81649.0, 1, 0, 'READER George (ENG)', 'GRIFFITHS Benjamin (WAL)', 'MITCHELL George (SCO)', 208, 1187, 'BRA', 'MEX'),
#  (1950, '25 Jun 1950 - 15:00 ', 'Group 2', 'Maracan� - Est�dio Jornalista M�rio Filho', 'Rio De Janeiro ', 'England', 2, 0, 'Chile', ' ', 29703.0, 1, 0, 'VAN DER MEER Karel (NED)', 'GARDELLI Mario (BRA)', 'DAHLNER Gunnar (SWE)', 208, 1192, 'ENG', 'CHI'),
#  (1950, '25 Jun 1950 - 15:00 ', 'Group 2', 'Durival de Brito', 'Curitiba ', 'Spain', 3, 1, 'USA', ' ', 9511.0, 0, 1, 'VIANA Mario (BRA)', 'DA COSTA VIEIRA Jose (POR)', 'DE LA SALLE Charles (FRA)', 208, 1208, 'ESP', 'USA'),
#  (1950, '25 Jun 1950 - 15:00 ', 'Group 3', 'Pacaembu', 'Sao Paulo ', 'Sweden', 3, 2, 'Italy', ' ', 36502.0, 2, 1, 'LUTZ Jean (SUI)', 'BERANEK Alois (AUT)', 'TEJADA Carlos (MEX)', 208, 1219, 'SWE', 'ITA'),
#  (1950, '25 Jun 1950 - 15:00 ', 'Group 1', 'Independencia', 'Belo Horizonte ', 'Yugoslavia', 3, 0, 'Switzerland', ' ', 7336.0, 0, 0, 'GALEATI Giovanni (ITA)', 'EKLIND Ivan (SWE)', 'DATTILO Generoso (ITA)', 208, 1230, 'YUG', 'SUI')]

# %% [markdown]
# ### <font color="green"> 1.7 Challenges</font>

# %%
# Challenge 1
# From the Interpol dataset, get all asian countries with wanted fugitives between 0 and 2
#
# %%sql
SELECT "Country","Region","Wanted Fugitives" FROM Interpol WHERE "Region"="Asia" AND "Wanted Fugitives" BETWEEN 0 AND 2;
# Out:
#  * sqlite://
# Done.
# [('Bangladesh', 'Asia', 1),
#  ('Cambodia', 'Asia', 0),
#  ('Georgia, Asia', 'Asia', 2),
#  ('India', 'Asia', 0),
#  ('Indonesia', 'Asia', 1),
#  ('Iraq', 'Asia', 0),
#  ('Pakistan', 'Asia', 0),
#  ('Qatar', 'Asia', 0)]

# %%
# Challenge 2
# From the World cup dataset, get all the matches that were played later than 1980 with an attendance less than 5000 
# 
# %%sql
SELECT "MatchID","Home_Team_Name","Away_Team_Name" FROM WorldCup WHERE "Year">1980 AND "Attendance"<5000;
# Out:
#  * sqlite://
# Done.
# []

# %%
# Challenge 3 
# Which matches were played between the year 1990 and 2000?
# 
# %%sql
SELECT "MatchID","Home_Team_Name","Away_Team_Name" FROM WorldCup WHERE "Year" BETWEEN 1990 AND 2000;
# Out:
#  * sqlite://
# Done.
# [(26, 'Argentina', 'Cameroon'),
#  (342, 'Soviet Union', 'Romania'),
#  (119, 'rn">United Arab Emirates', 'Colombia'),
#  (42, 'Italy', 'Austria'),
#  (355, 'USA', 'Czechoslovakia'),
#  (75, 'Brazil', 'Sweden'),
#  (201, 'Germany FR', 'Yugoslavia'),
#  (127, 'Costa Rica', 'Scotland'),
#  (161, 'England', 'rn">Republic of Ireland'),
#  (57, 'Belgium', 'Korea Republic'),
#  (151, 'Netherlands', 'Egypt'),
#  (180, 'Uruguay', 'Spain'),
#  (30, 'Argentina', 'Soviet Union'),
#  (108, 'Cameroon', 'Romania'),
#  (120, 'Yugoslavia', 'Colombia'),
#  (265, 'Italy', 'USA'),
#  (43, 'Austria', 'Czechoslovakia'),
#  (198, 'Germany FR', 'rn">United Arab Emirates'),
#  (73, 'Brazil', 'Costa Rica'),
#  (348, 'Sweden', 'Scotland'),
#  (160, 'England', 'Netherlands'),
#  (152, 'rn">Republic of Ireland', 'Egypt'),
#  (175, 'Korea Republic', 'Spain'),
#  (66, 'Belgium', 'Uruguay'),
#  (29, 'Argentina', 'Romania'),
#  (111, 'Cameroon', 'Soviet Union'),
#  (114, 'Germany FR', 'Colombia'),
#  (364, 'Yugoslavia', 'rn">United Arab Emirates'),
#  (263, 'Italy', 'Czechoslovakia'),
#  (48, 'Austria', 'USA'),
#  (74, 'Brazil', 'Scotland'),
#  (128, 'Sweden', 'Costa Rica'),
#  (290, 'Korea Republic', 'Uruguay'),
#  (56, 'Belgium', 'Spain'),
#  (228, 'rn">Republic of Ireland', 'Netherlands'),
#  (150, 'England', 'Egypt'),
#  (102, 'Cameroon', 'Colombia'),
#  (129, 'Czechoslovakia', 'Costa Rica'),
#  (25, 'Brazil', 'Argentina'),
#  (196, 'Germany FR', 'Netherlands'),
#  (248, 'rn">Republic of Ireland', 'Romania'),
#  (264, 'Italy', 'Uruguay'),
#  (181, 'Spain', 'Yugoslavia'),
#  (55, 'England', 'Belgium'),
#  (31, 'Yugoslavia', 'Argentina'),
#  (243, 'Italy', 'rn">Republic of Ireland'),
#  (197, 'Germany FR', 'Czechoslovakia'),
#  (103, 'England', 'Cameroon'),
#  (28, 'Italy', 'Argentina'),
#  (159, 'Germany FR', 'England'),
#  (162, 'Italy', 'England'),
#  (27, 'Germany FR', 'Argentina'),
#  (3050, 'Spain', 'Korea Republic'),
#  (3049, 'Germany', 'Bolivia'),
#  (3051, 'USA', 'Switzerland'),
#  (3052, 'Italy', 'rn">Republic of Ireland'),
#  (3053, 'Colombia', 'Romania'),
#  (3054, 'Belgium', 'Morocco'),
#  (3055, 'Norway', 'Mexico'),
#  (3056, 'Cameroon', 'Sweden'),
#  (3058, 'Netherlands', 'Saudi Arabia'),
#  (3057, 'Brazil', 'Russia'),
#  (3059, 'Argentina', 'Greece'),
#  (3061, 'Nigeria', 'Bulgaria'),
#  (3060, 'Germany', 'Spain'),
#  (3062, 'Romania', 'Switzerland'),
#  (3063, 'USA', 'Colombia'),
#  (3064, 'Italy', 'Norway'),
#  (3065, 'Korea Republic', 'Bolivia'),
#  (3066, 'Mexico', 'rn">Republic of Ireland'),
#  (3068, 'Sweden', 'Russia'),
#  (3067, 'Brazil', 'Cameroon'),
#  (3069, 'Belgium', 'Netherlands'),
#  (3070, 'Saudi Arabia', 'Morocco'),
#  (3071, 'Argentina', 'Nigeria'),
#  (3072, 'Bulgaria', 'Greece'),
#  (3073, 'USA', 'Romania'),
#  (3074, 'Switzerland', 'Colombia'),
#  (3076, 'Germany', 'Korea Republic'),
#  (3075, 'Bolivia', 'Spain'),
#  (3077, 'rn">Republic of Ireland', 'Norway'),
#  (3080, 'Brazil', 'Sweden'),
#  (3078, 'Italy', 'Mexico'),
#  (3079, 'Russia', 'Cameroon'),
#  (3081, 'Morocco', 'Netherlands'),
#  (3082, 'Belgium', 'Saudi Arabia'),
#  (3083, 'Greece', 'Nigeria'),
#  (3084, 'Argentina', 'Bulgaria'),
#  (3085, 'Germany', 'Belgium'),
#  (3086, 'Spain', 'Switzerland'),
#  (3087, 'Saudi Arabia', 'Sweden'),
#  (3088, 'Romania', 'Argentina'),
#  (3089, 'Netherlands', 'rn">Republic of Ireland'),
#  (3090, 'Brazil', 'USA'),
#  (3091, 'Nigeria', 'Italy'),
#  (3092, 'Mexico', 'Bulgaria'),
#  (3097, 'Italy', 'Spain'),
#  (3098, 'Netherlands', 'Brazil'),
#  (3096, 'Bulgaria', 'Germany'),
#  (3095, 'Romania', 'Sweden'),
#  (3100, 'Bulgaria', 'Italy'),
#  (3099, 'Sweden', 'Brazil'),
#  (3103, 'Sweden', 'Bulgaria'),
#  (3104, 'Brazil', 'Italy'),
#  (4000, 'Brazil', 'Scotland'),
#  (8725, 'Morocco', 'Norway'),
#  (8726, 'Italy', 'Chile'),
#  (8727, 'Cameroon', 'Austria'),
#  (8728, 'Paraguay', 'Bulgaria'),
#  (8729, 'Saudi Arabia', 'Denmark'),
#  (8730, 'France', 'South Africa'),
#  (8731, 'Spain', 'Nigeria'),
#  (8732, 'Korea Republic', 'Mexico'),
#  (8733, 'Netherlands', 'Belgium'),
#  (8734, 'Argentina', 'Japan'),
#  (8735, 'Yugoslavia', 'Iran'),
#  (8736, 'Jamaica', 'Croatia'),
#  (8740, 'England', 'Tunisia'),
#  (8739, 'Romania', 'Colombia'),
#  (8738, 'Germany', 'USA'),
#  (8741, 'Scotland', 'Norway'),
#  (8742, 'Brazil', 'Morocco'),
#  (8743, 'Chile', 'Austria'),
#  (8744, 'Italy', 'Cameroon'),
#  (8746, 'South Africa', 'Denmark'),
#  (8745, 'France', 'Saudi Arabia'),
#  (8747, 'Nigeria', 'Bulgaria'),
#  (8748, 'Spain', 'Paraguay'),
#  (8751, 'Japan', 'Croatia'),
#  (8750, 'Belgium', 'Mexico'),
#  (8749, 'Netherlands', 'Korea Republic'),
#  (8753, 'Germany', 'Yugoslavia'),
#  (8752, 'Argentina', 'Jamaica'),
#  (8754, 'USA', 'Iran'),
#  (8755, 'Colombia', 'Tunisia'),
#  (8756, 'Romania', 'England'),
#  (8757, 'Italy', 'Austria'),
#  (8760, 'Chile', 'Cameroon'),
#  (8758, 'Scotland', 'Morocco'),
#  (8759, 'Brazil', 'Norway'),
#  (8762, 'France', 'Denmark'),
#  (8764, 'South Africa', 'Saudi Arabia'),
#  (8761, 'Spain', 'Bulgaria'),
#  (8763, 'Nigeria', 'Paraguay'),
#  (8765, 'Belgium', 'Korea Republic'),
#  (8766, 'Netherlands', 'Mexico'),
#  (8767, 'Germany', 'Iran'),
#  (8768, 'USA', 'Yugoslavia'),
#  (8771, 'Japan', 'Jamaica'),
#  (8772, 'Argentina', 'Croatia'),
#  (8769, 'Romania', 'Tunisia'),
#  (8770, 'Colombia', 'England'),
#  (8774, 'Italy', 'Norway'),
#  (8773, 'Brazil', 'Chile'),
#  (8776, 'France', 'Paraguay'),
#  (8775, 'Nigeria', 'Denmark'),
#  (8777, 'Germany', 'Mexico'),
#  (8778, 'Netherlands', 'Yugoslavia'),
#  (8780, 'Romania', 'Croatia'),
#  (8779, 'Argentina', 'England'),
#  (8781, 'Italy', 'France'),
#  (8782, 'Brazil', 'Denmark'),
#  (8784, 'Netherlands', 'Argentina'),
#  (8783, 'Germany', 'Croatia'),
#  (8785, 'Brazil', 'Netherlands'),
#  (8786, 'France', 'Croatia'),
#  (8787, 'Netherlands', 'Croatia'),
#  (8788, 'Brazil', 'France')]

# %% [markdown]
# ## 1.8 Distinct

# %%
# Example 1
# Let's find out which stadiums have hosted world cup matches
# %%sql
SELECT DISTINCT Stadium FROM WorldCup;
# Out:
#  * sqlite://
# Done.
# [('Pocitos',),
#  ('Parque Central',),
#  ('Estadio Centenario',),
#  ('Stadio Benito Mussolini',),
#  ('Giorgio Ascarelli',),
#  ('San Siro',),
#  ('Littorale',),
#  ('Giovanni Berta',),
#  ('Luigi Ferraris',),
#  ('Nazionale PNF',),
#  ('Littorio',),
#  ('Parc des Princes',),
#  ('Velodrome Municipale',),
#  ('Stade Olympique',),
#  ('Stade Municipal',),
#  ('Stade V�lodrome',),
#  ('Stade de la Meinau',),
#  ('Cavee Verte',),
#  ('Stade du Parc Lescure',),
#  ('Victor Boucquey',),
#  ('Fort Carree',),
#  ('Maracan� - Est�dio Jornalista M�rio Filho',),
#  ('Durival de Brito',),
#  ('Pacaembu',),
#  ('Independencia',),
#  ('Eucaliptos',),
#  ('Ilha do Retiro',),
#  ('Wankdorf Stadium',),
#  ('Hardturm',),
#  ('Charmilles',),
#  ('La Pontaise',),
#  ('St. Jakob',),
#  ('Comunale di Cornaredo',),
#  ('Rasunda Stadium',),
#  ('Nya Ullevi',),
#  ('Malmo Stadion',),
#  ('Jarnvallen',),
#  ('Idrottsparken',),
#  ('Arosvallen',),
#  ('Rimnersvallen',),
#  ('Orjans Vall',),
#  ('Ryavallen',),
#  ('Olympia Stadium',),
#  ('Tunavallen',),
#  ('Eyravallen',),
#  ('Carlos Dittborn',),
#  ('Estadio Sausalito',),
#  ('Estadio El Teniente-Codelco',),
#  ('Nacional',),
#  ('Wembley Stadium',),
#  ('Hillsborough',),
#  ('Goodison Park',),
#  ('Ayresome Park',),
#  ('Old Trafford Stadium',),
#  ('Villa Park',),
#  ('Roker Park Ground',),
#  ('White City',),
#  ('Estadio Azteca',),
#  ('Cuauhtemoc',),
#  ('Nou Camp - Estadio Le�n',),
#  ('Jalisco',),
#  ('Luis Dosal',),
#  ('Waldstadion',),
#  ('Olympiastadion',),
#  ('Volksparkstadion',),
#  ('Westfalenstadion',),
#  ('Niedersachsenstadion',),
#  ('Rheinstadion',),
#  ('Neckarstadion',),
#  ('Parkstadion',),
#  ('El Monumental - Estadio Monumental Antonio Vespuci',),
#  ('Estadio Jos� Mar�a Minella',),
#  ('Arroyito - Estadio Dr. Lisandro de la Torre',),
#  ('Jose Amalfitani',),
#  ('Estadio Ol�mpico Chateau Carreras',),
#  ('San Martin',),
#  ('Camp Nou',),
#  ('Estadio Municipal de Bala�dos',),
#  ('Ramon Sanchez Pizjuan',),
#  ('Riazor',),
#  ('Nuevo Estadio',),
#  ('La Rosaleda',),
#  ('El Molinon',),
#  ('San Mames',),
#  ('Luis Casanova',),
#  ('Carlos Tartiere',),
#  ('Jose Zorrilla',),
#  ('La Romareda',),
#  ('Jose Rico Perez',),
#  ('Benito Villamarin',),
#  ('Vicente Calderon',),
#  ('Sarria',),
#  ('Santiago Bernabeu',),
#  ('Estadio Irapuato',),
#  ('Estadio Ol�mpico Universitario',),
#  ('Estadio Universitario',),
#  ('Tres de Marzo',),
#  ('Tecnologico',),
#  ('Bombonera - Estadio Nemesio Diez',),
#  ('Neza',),
#  ('Estadio Corregidora',),
#  ('Giuseppe Meazza',),
#  ('Stadio San Nicola',),
#  ('Renato Dall Ara',),
#  ('Stadio Olimpico',),
#  ('Comunale',),
#  ('Stadio delle Alpi',),
#  ('Sant Elia',),
#  ('Marc Antonio Bentegodi',),
#  ('Della Favorita',),
#  ('Dacia Arena',),
#  ('San Paolo',),
#  ('Friuli',),
#  ('Cotton Bowl',),
#  ('Soldier Field',),
#  ('Pontiac Silverdome',),
#  ('Giants Stadium',),
#  ('Rose Bowl',),
#  ('Citrus Bowl',),
#  ('RFK Stadium',),
#  ('Stanford Stadium',),
#  ('Foxboro Stadium',),
#  ('Stade de France',),
#  ('La Mosson',),
#  ('Stade Felix Bollaert',),
#  ('La Beaujoire',),
#  ('Stade de Gerland',),
#  ('Stade Geoffroy Guichard',),
#  ('Seoul World Cup Stadium',),
#  ('Munsu Football Stadium',),
#  ('Niigata Stadium Big Swan',),
#  ('Sapporo Dome',),
#  ('Kashima Stadium',),
#  ('Busan Asiad Main Stadium',),
#  ('Saitama Stadium 2002',),
#  ('Gwangju World Cup Stadium',),
#  ('Kobe Wing Stadium',),
#  ('Suwon World Cup Stadium',),
#  ('Daegu World Cup Stadium',),
#  ('Jeonju World Cup Stadium',),
#  ('Jeju World Cup Stadium',),
#  ('Incheon Football Stadium',),
#  ('International Stadium Yokohama',),
#  ('Miyagi Stadium',),
#  ('Oita Stadium Big Eye',),
#  ('Shizuoka Stadium Ecopa',),
#  ('Osaka Nagai Stadium',),
#  ('Daejeon World Cup Stadium',),
#  ('FIFA World Cup Stadium, Munich',),
#  ('FIFA World Cup Stadium, Gelsenkirchen',),
#  ('FIFA World Cup Stadium, Frankfurt',),
#  ('FIFA World Cup Stadium, Dortmund',),
#  ('FIFA World Cup Stadium, Hamburg',),
#  ('Zentralstadion',),
#  ('Franken-Stadion',),
#  ('FIFA World Cup Stadium, Cologne',),
#  ('Fritz-Walter-Stadion',),
#  ('FIFA World Cup Stadium, Hanover',),
#  ('Gottlieb-Daimler-Stadion',),
#  ('Soccer City Stadium',),
#  ('Cape Town Stadium',),
#  ('Port Elizabeth Stadium',),
#  ('Ellis Park Stadium',),
#  ('Royal Bafokeng Sports Palace',),
#  ('Peter Mokaba Stadium',),
#  ('Loftus Versfeld Stadium',),
#  ('Durban Stadium',),
#  ('Free State Stadium',),
#  ('Mbombela Stadium',),
#  ('Arena de Sao Paulo',),
#  ('Estadio das Dunas',),
#  ('Arena Fonte Nova',),
#  ('Arena Pantanal',),
#  ('Estadio Mineirao',),
#  ('Estadio Castelao',),
#  ('Arena Amazonia',),
#  ('Arena Pernambuco',),
#  ('Estadio Nacional',),
#  ('Estadio Beira-Rio',),
#  ('Estadio do Maracana',),
#  ('Arena da Baixada',)]

# %%
# Example 2
# Let's find out which world cup cities have hosted world cup matches after 2000
#
# %%sql
SELECT DISTINCT City FROM WorldCup WHERE Year > 2000;
# Out:
#  * sqlite://
# Done.
# [('Seoul ',),
#  ('Ulsan ',),
#  ('Niigata ',),
#  ('Sapporo ',),
#  ('Ibaraki ',),
#  ('Busan ',),
#  ('Saitama ',),
#  ('Gwangju ',),
#  ('Kobe ',),
#  ('Suwon ',),
#  ('Daegu ',),
#  ('Jeonju ',),
#  ('Jeju ',),
#  ('Incheon ',),
#  ('Yokohama ',),
#  ('Rifu ',),
#  ('Oita ',),
#  ('Shizuoka ',),
#  ('Osaka ',),
#  ('Daejeon ',),
#  ('Munich ',),
#  ('Gelsenkirchen ',),
#  ('Frankfurt/Main ',),
#  ('Dortmund ',),
#  ('Hamburg ',),
#  ('Leipzig ',),
#  ('Nuremberg ',),
#  ('Cologne ',),
#  ('Kaiserslautern ',),
#  ('Hanover ',),
#  ('Stuttgart ',),
#  ('Berlin ',),
#  ('Johannesburg ',),
#  ('Cape Town ',),
#  ('Nelson Mandela Bay/Port Elizabeth ',),
#  ('Phokeng ',),
#  ('Polokwane ',),
#  ('Tshwane/Pretoria ',),
#  ('Durban ',),
#  ('Mangaung/Bloemfontein ',),
#  ('Nelspruit ',),
#  ('Sao Paulo ',),
#  ('Natal ',),
#  ('Salvador ',),
#  ('Cuiaba ',),
#  ('Belo Horizonte ',),
#  ('Fortaleza ',),
#  ('Manaus ',),
#  ('Recife ',),
#  ('Brasilia ',),
#  ('Porto Alegre ',),
#  ('Rio De Janeiro ',),
#  ('Curitiba ',)]

# %% [markdown]
# ### <font color="green"> 1.8 Challenges</font>

# %%
# Challenge 1
# Name the stages in the world cup and order them alphabetically by stage.
# 
# %%sql
SELECT DISTINCT Stage FROM WorldCup ORDER BY Stage ASC;
# Out:
#  * sqlite://
# Done.
# [('Final',),
#  ('First round',),
#  ('Group 1',),
#  ('Group 2',),
#  ('Group 3',),
#  ('Group 4',),
#  ('Group 5',),
#  ('Group 6',),
#  ('Group A',),
#  ('Group B',),
#  ('Group C',),
#  ('Group D',),
#  ('Group E',),
#  ('Group F',),
#  ('Group G',),
#  ('Group H',),
#  ('Match for third place',),
#  ('Play-off for third place',),
#  ('Preliminary round',),
#  ('Quarter-finals',),
#  ('Round of 16',),
#  ('Semi-finals',),
#  ('Third place',)]

# %%
# Challenge 2
# Which cities hosted the world cup between 1950 and 2000?
#
# %%sql
SELECT DISTINCT "City","Year" FROM WorldCup WHERE "Year" BETWEEN 1950 AND 2000;
# Out:
#  * sqlite://
# Done.
# [('Rio De Janeiro ', 1950),
#  ('Curitiba ', 1950),
#  ('Sao Paulo ', 1950),
#  ('Belo Horizonte ', 1950),
#  ('Porto Alegre ', 1950),
#  ('Recife ', 1950),
#  ('Berne ', 1954),
#  ('Zurich ', 1954),
#  ('Geneva ', 1954),
#  ('Lausanne ', 1954),
#  ('Basel ', 1954),
#  ('Lugano ', 1954),
#  ('Solna ', 1958),
#  ('Gothenburg ', 1958),
#  ('Malm� ', 1958),
#  ('Sandviken ', 1958),
#  ('Norrk�Ping ', 1958),
#  ('Vasteras ', 1958),
#  ('Udevalla ', 1958),
#  ('Halmstad ', 1958),
#  ('Boras ', 1958),
#  ('Helsingborg ', 1958),
#  ('Eskilstuna ', 1958),
#  ('Orebro ', 1958),
#  ('Arica ', 1962),
#  ('Vina Del Mar ', 1962),
#  ('Rancagua ', 1962),
#  ('Santiago De Chile ', 1962),
#  ('London ', 1966),
#  ('Sheffield ', 1966),
#  ('Liverpool ', 1966),
#  ('Middlesbrough ', 1966),
#  ('Manchester ', 1966),
#  ('Birmingham ', 1966),
#  ('Sunderland ', 1966),
#  ('Mexico City ', 1970),
#  ('Puebla ', 1970),
#  ('Leon ', 1970),
#  ('Guadalajara ', 1970),
#  ('Toluca ', 1970),
#  ('Frankfurt/Main ', 1974),
#  ('Berlin West ', 1974),
#  ('Hamburg ', 1974),
#  ('Dortmund ', 1974),
#  ('Hanover ', 1974),
#  ('D�Sseldorf ', 1974),
#  ('Munich ', 1974),
#  ('Stuttgart ', 1974),
#  ('Gelsenkirchen ', 1974),
#  ('Buenos Aires ', 1978),
#  ('Mar Del Plata ', 1978),
#  ('Rosario ', 1978),
#  ('Cordoba ', 1978),
#  ('Mendoza ', 1978),
#  ('Barcelona ', 1982),
#  ('Vigo ', 1982),
#  ('Seville ', 1982),
#  ('La Coru�A ', 1982),
#  ('Elche ', 1982),
#  ('Malaga ', 1982),
#  ('Gijon ', 1982),
#  ('Bilbao ', 1982),
#  ('Valencia ', 1982),
#  ('Oviedo ', 1982),
#  ('Valladolid ', 1982),
#  ('Zaragoza ', 1982),
#  ('Alicante ', 1982),
#  ('Madrid ', 1982),
#  ('Mexico City ', 1986),
#  ('Leon ', 1986),
#  ('Guadalajara ', 1986),
#  ('Irapuato ', 1986),
#  ('Monterrey ', 1986),
#  ('Toluca ', 1986),
#  ('Nezahualcoyotl ', 1986),
#  ('Queretaro ', 1986),
#  ('Puebla ', 1986),
#  ('Milan ', 1990),
#  ('Bari ', 1990),
#  ('Bologna ', 1990),
#  ('Rome ', 1990),
#  ('Florence ', 1990),
#  ('Turin ', 1990),
#  ('Genoa ', 1990),
#  ('Cagliari ', 1990),
#  ('Verona ', 1990),
#  ('Palermo ', 1990),
#  ('Udine ', 1990),
#  ('Naples ', 1990),
#  ('Dallas ', 1994),
#  ('Chicago ', 1994),
#  ('Detroit ', 1994),
#  ('New York/New Jersey ', 1994),
#  ('Los Angeles ', 1994),
#  ('Orlando ', 1994),
#  ('Washington Dc ', 1994),
#  ('San Francisco ', 1994),
#  ('Boston ', 1994),
#  ('Saint-Denis ', 1998),
#  ('Montpellier ', 1998),
#  ('Bordeaux ', 1998),
#  ('Toulouse ', 1998),
#  ('Lens ', 1998),
#  ('Marseilles ', 1998),
#  ('Nantes ', 1998),
#  ('Lyon ', 1998),
#  ('Saint-Etienne ', 1998),
#  ('Paris ', 1998)]

# %%
# Challenge 3
# During which years was the world cup hosted in?
#
# %%sql
SELECT DISTINCT "Country","Year" FROM WorldCup WHERE "Year"=(SELECT MAX('Year') in Worldcup);
# Out:
#  * sqlite://
# (sqlite3.OperationalError) sub-select returns 20 columns - expected 1
# [SQL: SELECT DISTINCT "Country","Year" FROM WorldCup WHERE "Year"=(SELECT MAX('Year') in Worldcup);]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ## 1.9 Count

# %%
# Example 1
# How many countries were listed in interpol's data? 
#
# %%sql
SELECT COUNT(Country) FROM Interpol;
# Out:
#  * sqlite://
# Done.
# [(78,)]

# %%
# Example 2
# How many times has Brazil played home during world cup matches?
#
# %%sql
SELECT COUNT("Home_Team_Name") FROM WorldCup where Home_Team_Name = 'Brazil';
# Out:
#  * sqlite://
# Done.
# [(82,)]

# %%
# Example 3
# Find out the number of times that stadiums have hosted matches in the World Cup? 
# 
# %%sql
SELECT COUNT(Stadium)
FROM WorldCup;
# Out:
#  * sqlite://
# Done.
# [(852,)]

# %% [markdown]
# ### <font color="green"> 1.9 Challenges</font>

# %%
# Challenge 1
# Using Interpol Dataset, find out how many wanted fugitives there are in Northern Africa.
# 
# %%sql
SELECT COUNT("Wanted Fugitives") FROM Interpol WHERE Region='Northern Africa';
# Out:
#  * sqlite://
# Done.
# [(2,)]

# %%
# Challenge 2
# Using WorldCup Dataset, find out how many Possible Hosted Fugitives / Captured Fugitives 
# there are in Europe and Northern Africa.
# 
# %%sql
SELECT COUNT("Possible Hosted Fugitives / Captured Fugitives") FROM Interpol WHERE (Region="Europe" OR Region="Northern Africa");
# Out:
#  * sqlite://
# Done.
# [(32,)]

# %%
# Challenge 3
# Using WorldCup dataset, find out how many away teams were played where a team scored more than 3 goals.
# 
# %%sql
SELECT COUNT("Away_Team_Name") FROM WorldCup WHERE "Away_Team_Goals">3;
# Out:
#  * sqlite://
# Done.
# [(24,)]

# %%
WorldCup.head(2)
# Out:
#                   Datetime    Stage  ... Home_Team_Initials Away_Team_Initials
# Year                                 ...
# 1930  13 Jul 1930 - 15:00   Group 1  ...                FRA                MEX
# 1930  13 Jul 1930 - 15:00   Group 4  ...                USA                BEL
#
# [2 rows x 19 columns]

# %% [markdown]
# ## 1.10 Groupby

# %%
# Example 1
# Which three stadiums have hosted the most world cup games?
#
# %%sql
SELECT Stadium, COUNT(Stadium)
FROM WorldCup
GROUP BY Stadium 
ORDER BY COUNT(Stadium) DESC LIMIT 3;
# Out:
#  * sqlite://
# Done.
# [('Estadio Azteca', 19), ('Jalisco', 14), ('Olympiastadion', 14)]

# %%
# Example 2
# Which three stadiums have hosted the least world cup games?
#
# %%sql
SELECT City, COUNT(Stadium)
FROM WorldCup
GROUP BY Stadium 
ORDER BY COUNT(Stadium) ASC LIMIT 3;
# Out:
#  * sqlite://
# Done.
# [('Le Havre ', 1), ('Lugano ', 1), ('Orebro ', 1)]

# %% [markdown]
# ### <font color="green"> 1.10 Challenges</font>

# %%
# Challenge 1
# What has been the largest no. of home goals scored by three home teams? 
# 
# %%sql
SELECT MatchID,Home_Team_Name,Away_Team_Name, COUNT(Home_Team_Goals) FROM WorldCup GROUP BY Home_Team_Goals
ORDER BY COUNT(Home_Team_Goals) DESC LIMIT 3;
# Out:
#  * sqlite://
# Done.
# [(300186501, 'Germany', 'Argentina', 246),
#  (300186461, 'Brazil', 'Colombia', 205),
#  (300186502, 'Brazil', 'Netherlands', 177)]

# %%
WorldCup.columns.values
# Out:
# array(['Datetime', 'Stage', 'Stadium', 'City', 'Home_Team_Name',
#        'Home_Team_Goals', 'Away_Team_Goals', 'Away_Team_Name',
#        'Win_conditions', 'Attendance', 'Halftime_Home_Goals',
#        'Halftime_Away_Goals', 'Referee', 'Assistant1', 'Assistant2',
#        'RoundID', 'MatchID', 'Home_Team_Initials', 'Away_Team_Initials'],
#       dtype=object)

# %%
# Challenge 2
# Which away teams have scored the lowest no. of away goals?
# 
# %%sql
SELECT Away_Team_Name, COUNT(Away_Team_Goals) FROM WorldCup GROUP BY Away_Team_Goals
ORDER BY COUNT(Away_Team_Goals) ASC LIMIT 3;
# Out:
#  * sqlite://
# Done.
# [('Germany', 3), ('France', 7), ('Colombia', 14)]

# %%
# Challenge 3
# Select records from the World Cup Dataset grouping by City 
# 
# %%sql
SELECT * FROM WorldCup 
GROUP BY City;
# Out:
#  * sqlite://
# Done.
# [(1982, '10 Jul 1982 - 20:00 ', 'Match for third place', 'Jose Rico Perez', 'Alicante ', 'Poland', 3, 2, 'France', ' ', 28000.0, 2, 1, 'GARRIDO Antonio (POR)', 'RUBIO VAZQUEZ Mario (MEX)', 'LACARNE Belaid (ALG)', 676, 921, 'POL', 'FRA'),
#  (1938, '12 Jun 1938 - 17:00 ', 'Quarter-finals', 'Fort Carree', 'Antibes ', 'Sweden', 8, 0, 'Cuba', ' ', 7000.0, 4, 0, 'KRIST Gustav (TCH)', 'WEINGARTNER Karl (AUT)', 'SDEZ Victor (FRA)', 429, 1158, 'SWE', 'CUB'),
#  (1962, '10 Jun 1962 - 14:30 ', 'Quarter-finals', 'Carlos Dittborn', 'Arica ', 'Chile', 2, 1, 'Soviet Union', ' ', 17268.0, 2, 1, 'HORN Leo (NED)', 'ETZEL FILHO Joao (BRA)', 'GALBA Karol (TCH)', 232, 1474, 'CHI', 'URS'),
#  (1982, '08 Jul 1982 - 17:15 ', 'Semi-finals', 'Camp Nou', 'Barcelona ', 'Poland', 0, 2, 'Italy', ' ', 50000.0, 0, 1, 'CARDELLINO DE SAN VICENTE Juan (URU)', 'SOCHA David (USA)', 'ARISTIZABAL MURCIA Gilberto (COL)', 295, 996, 'POL', 'ITA'),
#  (1990, '07 Jul 1990 - 20:00 ', 'Match for third place', 'Stadio San Nicola', 'Bari ', 'Italy', 2, 1, 'England', ' ', 51426.0, 0, 0, 'QUINIOU Joel (FRA)', 'HANSAL Mohamed (ALG)', 'ROETHLISBERGER Kurt (SUI)', 3463, 162, 'ITA', 'ENG'),
#  (1954, '30 Jun 1954 - 18:00 ', 'Semi-finals', 'St. Jakob', 'Basel ', 'Germany FR', 6, 1, 'Austria', ' ', 58000.0, 1, 0, 'ORLANDINI Vincenzo (ITA)', 'ELLIS Arthur (ENG)', 'BUCHMUELLER Fritz (SUI)', 462, 1233, 'FRG', 'AUT'),
#  (2014, '08 Jul 2014 - 17:00 ', 'Semi-finals', 'Estadio Mineirao', 'Belo Horizonte ', 'Brazil', 1, 7, 'Germany', ' ', 58141.0, 0, 5, 'RODRIGUEZ Marco (MEX)', 'TORRENTERA Marvin (MEX)', 'QUINTERO Marcos (MEX)', 255955, 300186474, 'BRA', 'GER'),
#  (2006, '09 Jul 2006 - 20:00 ', 'Final', 'Olympiastadion', 'Berlin ', 'Italy', 1, 1, 'France', 'Italy win on penalties (5 - 3) ', 69000.0, 0, 0, 'ELIZONDO Horacio (ARG)', 'GARCIA Dario (ARG)', 'OTERO Rodolfo (ARG)', 97410600, 97410064, 'ITA', 'FRA'),
#  (1974, '22 Jun 1974 - 16:00 ', 'Group 1', 'Olympiastadion', 'Berlin West ', 'Australia', 0, 0, 'Chile', ' ', 17400.0, 0, 0, 'NAMDAR Jafar (IRN)', 'LORAUX Vital (BEL)', 'VAN GEMERT Arie (NED)', 262, 1953, 'AUS', 'CHI'),
#  (1954, '04 Jul 1954 - 17:00 ', 'Final', 'Wankdorf Stadium', 'Berne ', 'Germany FR', 3, 2, 'Hungary', ' ', 62500.0, 2, 2, 'LING William (ENG)', 'ORLANDINI Vincenzo (ITA)', 'GRIFFITHS Benjamin (WAL)', 3484, 1278, 'FRG', 'HUN'),
#  (1982, '25 Jun 1982 - 17:15 ', 'Group 4', 'San Mames', 'Bilbao ', 'England', 1, 0, 'Kuwait', ' ', 39700.0, 1, 0, 'ARISTIZABAL MURCIA Gilberto (COL)', 'LUND-SORENSEN Henning (DEN)', 'GARCIA CARRION Jose L. (ESP)', 293, 882, 'ENG', 'KUW'),
#  (1966, '20 Jul 1966 - 19:30 ', 'Group 2', 'Villa Park', 'Birmingham ', 'Germany FR', 2, 1, 'Spain', ' ', 42187.0, 1, 1, 'MARQUES Armando (BRA)', 'VICUNA Claudio (CHI)', 'CHOI Duk Ryong (PRK)', 238, 1637, 'FRG', 'ESP'),
#  (1990, '26 Jun 1990 - 21:00 ', 'Round of 16', 'Renato Dall Ara', 'Bologna ', 'England', 1, 0, 'Belgium', 'England win after extra time ', 34520.0, 0, 0, 'MIKKELSEN Peter (DEN)', 'KOHL Helmut (AUT)', 'TAKADA Shizuo (JPN)', 323, 55, 'ENG', 'BEL'),
#  (1958, '15 Jun 1958 - 19:00 ', 'Group 4', 'Ryavallen', 'Boras ', 'England', 2, 2, 'Austria', ' ', 15872.0, 0, 1, 'BRONKHORST Jan (NED)', 'DUSCH Albert (GER)', 'ZSOLT Istvan (HUN)', 220, 1327, 'ENG', 'AUT'),
#  (1998, '30 Jun 1998 - 16:30 ', 'Round of 16', 'Stade du Parc Lescure', 'Bordeaux ', 'Romania', 0, 1, 'Croatia', ' ', 31800.0, 0, 1, 'CASTRILLI Javier (ARG)', 'ROSSI Claudio (ARG)', 'PINTO Arnaldo (BRA)', 1024, 8780, 'ROU', 'CRO'),
#  (1994, '09 Jul 1994 - 12:00 ', 'Quarter-finals', 'Foxboro Stadium', 'Boston ', 'Italy', 2, 1, 'Spain', ' ', 53400.0, 1, 0, 'PUHL Sandor (HUN)', 'DUNSTER Gordon (AUS)', 'MATTHYS Luc (BEL)', 796, 3097, 'ITA', 'ESP'),
#  (2014, '12 Jul 2014 - 17:00 ', 'Play-off for third place', 'Estadio Nacional', 'Brasilia ', 'Brazil', 0, 3, 'Netherlands', ' ', 68034.0, 0, 2, 'HAIMOUDI Djamel (ALG)', 'ACHIK Redouane (MAR)', 'ETCHIALI Abdelhak (ALG)', 255957, 300186502, 'BRA', 'NED'),
#  (1978, '25 Jun 1978 - 15:00 ', 'Final', 'El Monumental - Estadio Monumental Antonio Vespuci', 'Buenos Aires ', 'Argentina', 3, 1, 'Netherlands', 'Argentina win after extra time ', 71483.0, 0, 0, 'GONELLA Sergio (ITA)', 'BARRETO RUIZ Ramon (URU)', 'LINEMAYR Erich (AUT)', 639, 2198, 'ARG', 'NED'),
#  (2002, '06 Jun 2002 - 20:30 ', 'Group A', 'Busan Asiad Main Stadium', 'Busan ', 'France', 0, 0, 'Uruguay', ' ', 38289.0, 0, 0, 'RAMOS RIZO Felipe (MEX)', 'FERNANDEZ Vladimir (SLV)', 'CHARLES Curtis (ATG)', 43950100, 43950018, 'FRA', 'URU'),
#  (1990, '21 Jun 1990 - 21:00 ', 'Group F', 'Sant Elia', 'Cagliari ', 'England', 1, 0, 'Egypt', ' ', 34959.0, 0, 0, 'ROETHLISBERGER Kurt (SUI)', 'ULLOA MORERA Berny (CRC)', 'CODESAL MENDEZ Edgardo (MEX)', 322, 150, 'ENG', 'EGY'),
#  (2010, '06 Jul 2010 - 20:30 ', 'Semi-finals', 'Cape Town Stadium', 'Cape Town ', 'Uruguay', 2, 3, 'Netherlands', ' ', 62479.0, 1, 1, 'Ravshan IRMATOV (UZB)', 'ILYASOV Rafael (UZB)', 'KOCHKAROV Bakhadyr (KGZ)', 249719, 300061512, 'URU', 'NED'),
#  (1994, '02 Jul 1994 - 12:00 ', 'Round of 16', 'Soldier Field', 'Chicago ', 'Germany', 3, 2, 'Belgium', ' ', 60246.0, 3, 1, 'ROETHLISBERGER Kurt (SUI)', 'LISTKIEWICZ Michal (POL)', 'CHRISTENSEN Carl-Johan Meyer (DEN)', 338, 3085, 'GER', 'BEL'),
#  (2006, '26 Jun 2006 - 21:00 ', 'Round of 16', 'FIFA World Cup Stadium, Cologne', 'Cologne ', 'Switzerland', 0, 0, 'Ukraine', 'Ukraine win on penalties (0 - 3) ', 45000.0, 0, 0, 'ARCHUNDIA Benito (MEX)', 'RAMIREZ Jose (MEX)', 'VERGARA Hector (CAN)', 97410200, 97410054, 'SUI', 'UKR'),
#  (1938, '19 Jun 1938 - 17:00 ', 'Final', 'Stade Olympique', 'Colombes ', 'Italy', 4, 2, 'Hungary', ' ', 45000.0, 3, 1, 'CAPDEVILLE Georges (FRA)', 'WUETHRICH Hans (SUI)', 'KRIST Gustav (TCH)', 3487, 1174, 'ITA', 'HUN'),
#  (1978, '21 Jun 1978 - 13:45 ', 'Group A', 'Estadio Ol�mpico Chateau Carreras', 'Cordoba ', 'Austria', 3, 2, 'Germany FR', ' ', 38318.0, 0, 1, 'KLEIN Abraham (ISR)', 'JARGUZ Alojzy (POL)', 'GARRIDO Antonio (POR)', 279, 2217, 'AUT', 'FRG'),
#  (2014, '24 Jun 2014 - 16:00 ', 'Group C', 'Arena Pantanal', 'Cuiaba ', 'Japan', 1, 4, 'Colombia', ' ', 40340.0, 1, 1, 'PROENCA Pedro (POR)', 'MIRANDA Bertino (POR)', 'TRIGO Jose (POR)', 255931, 300186457, 'JPN', 'COL'),
#  (2014, '26 Jun 2014 - 17:00 ', 'Group H', 'Arena da Baixada', 'Curitiba ', 'Algeria', 1, 1, 'Russia', ' ', 39311.0, 0, 1, 'C�neyt �AKIR (TUR)', 'DURAN Bahattin (TUR)', 'ONGUN Tarik (TUR)', 255931, 300186506, 'ALG', 'RUS'),
#  (2002, '29 Jun 2002 - 20:00 ', 'Third place', 'Daegu World Cup Stadium', 'Daegu ', 'Korea Republic', 2, 3, 'Turkey', ' ', 63483.0, 1, 3, 'MANE Saad (KUW)', 'ALTRAIFI Ali (KSA)', 'VERGARA Hector (CAN)', 43950500, 43950063, 'KOR', 'TUR'),
#  (2002, '18 Jun 2002 - 20:30 ', 'Round of 16', 'Daejeon World Cup Stadium', 'Daejeon ', 'Korea Republic', 2, 1, 'Italy', 'Win on Golden Goal ', 38588.0, 0, 0, 'MORENO Byron (ECU)', 'RATTALINO Jorge (ARG)', 'SZEKELY Ferenc (HUN)', 43950200, 43950056, 'KOR', 'ITA'),
#  (1994, '09 Jul 1994 - 14:30 ', 'Quarter-finals', 'Cotton Bowl', 'Dallas ', 'Netherlands', 2, 3, 'Brazil', ' ', 63500.0, 0, 0, 'BADILLA Rodrigo (CRC)', 'AL GHATTAN Yousif Abdulla (BAH)', 'FANAEI Mohammad (IRN)', 796, 3098, 'NED', 'BRA'),
#  (1994, '28 Jun 1994 - 16:00 ', 'Group B', 'Pontiac Silverdome', 'Detroit ', 'Brazil', 1, 1, 'Sweden', ' ', 77217.0, 0, 1, 'PUHL Sandor (HUN)', 'MARTON Sandor (HUN)', 'MATTHYS Luc (BEL)', 337, 3080, 'BRA', 'SWE'),
#  (2006, '04 Jul 2006 - 21:00 ', 'Semi-finals', 'FIFA World Cup Stadium, Dortmund', 'Dortmund ', 'Germany', 0, 2, 'Italy', 'Italy win after extra time ', 65000.0, 0, 0, 'ARCHUNDIA Benito (MEX)', 'RAMIREZ Jose (MEX)', 'VERGARA Hector (CAN)', 97410400, 97410061, 'GER', 'ITA'),
#  (2010, '07 Jul 2010 - 20:30 ', 'Semi-finals', 'Durban Stadium', 'Durban ', 'Germany', 0, 1, 'Spain', ' ', 60960.0, 0, 0, 'KASSAI Viktor (HUN)', 'EROS Gabor (HUN)', 'VAMOS Tibor (HUN)', 249719, 300111114, 'GER', 'ESP'),
#  (1974, '03 Jul 1974 - 19:30 ', 'Group B', 'Rheinstadion', 'D�Sseldorf ', 'Sweden', 2, 1, 'Yugoslavia', ' ', 41300.0, 1, 1, 'PESTARINO Luis (ARG)', 'BARRETO RUIZ Ramon (URU)', 'LLOBREGAT Vicente (VEN)', 263, 2182, 'SWE', 'YUG'),
#  (1982, '22 Jun 1982 - 21:00 ', 'Group 3', 'Nuevo Estadio', 'Elche ', 'Belgium', 1, 1, 'Hungary', ' ', 37000.0, 0, 1, 'WHITE Clive (ENG)', 'ESCHWEILER Walter (GER)', 'LACARNE Belaid (ALG)', 293, 779, 'BEL', 'HUN'),
#  (1958, '15 Jun 1958 - 19:00 ', 'Group 2', 'Tunavallen', 'Eskilstuna ', 'Paraguay', 3, 3, 'Yugoslavia', ' ', 13103.0, 1, 2, 'MACKO Martin (TCH)', 'GRIFFITHS Benjamin (WAL)', 'GARDEAZABAL Juan (ESP)', 220, 1426, 'PAR', 'YUG'),
#  (1990, '30 Jun 1990 - 17:00 ', 'Quarter-finals', 'Comunale', 'Florence ', 'Yugoslavia', 0, 0, 'Argentina', ' win on penalties (2 - 3) ', 38971.0, 0, 0, 'ROETHLISBERGER Kurt (SUI)', 'JOUINI Neji (TUN)', 'HANSAL Mohamed (ALG)', 751, 31, 'YUG', 'ARG'),
#  (2014, '04 Jul 2014 - 17:00 ', 'Quarter-finals', 'Estadio Castelao', 'Fortaleza ', 'Brazil', 2, 1, 'Colombia', ' ', 60342.0, 1, 0, 'Carlos VELASCO CARBALLO (ESP)', 'ALONSO FERNANDEZ Roberto (ESP)', 'YUSTE Juan (ESP)', 255953, 300186461, 'BRA', 'COL'),
#  (2006, '01 Jul 2006 - 21:00 ', 'Quarter-finals', 'FIFA World Cup Stadium, Frankfurt', 'Frankfurt/Main ', 'Brazil', 0, 1, 'France', ' ', 48000.0, 0, 0, 'MEDINA CANTALEJO Luis (ESP)', 'GIRALDEZ CARRASCO Victoriano (ESP)', 'MEDINA HERNANDEZ Pedro (ESP)', 97410300, 97410060, 'BRA', 'FRA'),
#  (2006, '01 Jul 2006 - 17:00 ', 'Quarter-finals', 'FIFA World Cup Stadium, Gelsenkirchen', 'Gelsenkirchen ', 'England', 0, 0, 'Portugal', 'Portugal win on penalties (1 - 3) ', 52000.0, 0, 0, 'ELIZONDO Horacio (ARG)', 'GARCIA Dario (ARG)', 'OTERO Rodolfo (ARG)', 97410300, 97410059, 'ENG', 'POR'),
#  (1954, '27 Jun 1954 - 17:00 ', 'Quarter-finals', 'Charmilles', 'Geneva ', 'Germany FR', 2, 0, 'Yugoslavia', ' ', 17000.0, 1, 0, 'ZSOLT Istvan (HUN)', 'FRANKEN Laurent (BEL)', 'BUCHMUELLER Fritz (SUI)', 212, 1285, 'FRG', 'YUG'),
#  (1990, '25 Jun 1990 - 17:00 ', 'Round of 16', 'Luigi Ferraris', 'Genoa ', 'rn">Republic of Ireland', 0, 0, 'Romania', 'Republic of Ireland win on penalties (5 - 4) ', 31818.0, 0, 0, 'RAMIZ WRIGHT Jose (BRA)', 'MACIEL Carlos (PAR)', 'MANDI Jassim (BHR)', 323, 248, 'IRL', 'ROU'),
#  (1982, '25 Jun 1982 - 17:15 ', 'Group 2', 'El Molinon', 'Gijon ', 'Germany FR', 1, 0, 'Austria', ' ', 41000.0, 1, 0, 'VALENTINE Robert (SCO)', 'AL DOY Ebrahim (BHR)', 'COELHO Arnaldo (BRA)', 293, 770, 'FRG', 'AUT'),
#  (1958, '28 Jun 1958 - 17:00 ', 'Match for third place', 'Nya Ullevi', 'Gothenburg ', 'France', 6, 3, 'Germany FR', ' ', 32483.0, 3, 1, 'BROZZI Juan (ARG)', 'ELLIS Arthur (ENG)', 'LUNDELL Bengt (SWE)', 3483, 1382, 'FRA', 'FRG'),
#  (1986, '25 Jun 1986 - 12:00 ', 'Semi-finals', 'Jalisco', 'Guadalajara ', 'France', 0, 2, 'Germany FR', ' ', 45000.0, 0, 1, 'AGNOLIN Luigi (ITA)', 'PETROVIC Zoran (SRB)', 'NEMETH Lajos (HUN)', 3469, 564, 'FRA', 'FRG'),
#  (2002, '22 Jun 2002 - 15:30 ', 'Quarter-finals', 'Gwangju World Cup Stadium', 'Gwangju ', 'Spain', 0, 0, 'Korea Republic', 'Korea Republic win on penalties (3 - 5) ', 42114.0, 0, 0, 'EL GHANDOUR Gamal (EGY)', 'TOMUSANGE Ali (UGA)', 'RAGOONATH Michael (TRI)', 43950300, 43950059, 'ESP', 'KOR'),
#  (1958, '11 Jun 1958 - 19:00 ', 'Group 1', 'Orjans Vall', 'Halmstad ', 'Argentina', 3, 1, 'Northern Ireland', ' ', 14174.0, 1, 1, 'AHLNER Sten (SWE)', 'FERNANDES CAMPOS Joaquim (POR)', 'HELGE Leo (DEN)', 220, 1324, 'ARG', 'NIR'),
#  (2006, '30 Jun 2006 - 21:00 ', 'Quarter-finals', 'FIFA World Cup Stadium, Hamburg', 'Hamburg ', 'Italy', 3, 0, 'Ukraine', ' ', 50000.0, 1, 0, 'DE BLEECKERE Frank (BEL)', 'HERMANS Peter (BEL)', 'VROMANS Walter (BEL)', 97410300, 97410058, 'ITA', 'UKR'),
#  (2006, '27 Jun 2006 - 21:00 ', 'Round of 16', 'FIFA World Cup Stadium, Hanover', 'Hanover ', 'Spain', 1, 3, 'France', ' ', 43000.0, 1, 1, 'ROSETTI Roberto (ITA)', 'COPELLI Cristiano (ITA)', 'STAGNOLI Alessandro (ITA)', 97410200, 97410056, 'ESP', 'FRA'),
#  (1958, '15 Jun 1958 - 19:00 ', 'Group 1', 'Olympia Stadium', 'Helsingborg ', 'Czechoslovakia', 6, 1, 'Argentina', ' ', 16418.0, 3, 0, 'ELLIS Arthur (ENG)', 'LEAFE Reginald (ENG)', 'SEIPELT Fritz (AUT)', 220, 1325, 'TCH', 'ARG'),
#  (2002, '08 June 2002 - 18:00 ', 'Group G', 'Kashima Stadium', 'Ibaraki ', 'Italy', 1, 2, 'Croatia', ' ', 36472.0, 0, 0, 'POLL Graham (ENG)', 'SHARP Philip (ENG)', 'LARSEN Jens (DEN)', 43950100, 43950025, 'ITA', 'CRO'),
#  (2002, '14 Jun 2002 - 20:30 ', 'Group D', 'Incheon Football Stadium', 'Incheon ', 'Portugal', 0, 1, 'Korea Republic', ' ', 50239.0, 0, 0, 'SANCHEZ Angel (ARG)', 'ALTRAIFI Ali (KSA)', 'SZEKELY Ferenc (HUN)', 43950100, 43950047, 'POR', 'KOR'),
#  (1986, '09 Jun 1986 - 12:00 ', 'Group C', 'Estadio Irapuato', 'Irapuato ', 'Soviet Union', 2, 0, 'Canada', ' ', 14200.0, 0, 0, 'TRAORE Idrissa (MLI)', 'AL SHANAR Fallaj Khuzam (KSA)', 'GONZALEZ ROA Gabriel (PAR)', 308, 476, 'URS', 'CAN'),
#  (2002, '15 Jun 2002 - 15:30 ', 'Round of 16', 'Jeju World Cup Stadium', 'Jeju ', 'Germany', 1, 0, 'Paraguay', ' ', 25176.0, 0, 0, 'BATRES Carlos (GUA)', 'CHARLES Curtis (ATG)', 'DANTE Dramane (MLI)', 43950200, 43950049, 'GER', 'PAR'),
#  (2002, '17 June 2002 - 15:30 ', 'Round of 16', 'Jeonju World Cup Stadium', 'Jeonju ', 'Mexico', 0, 2, 'USA', ' ', 36380.0, 0, 1, 'MELO PEREIRA Vitor (POR)', 'MATOS Carlos (POR)', 'BEREUTER Egon (AUT)', 43950200, 43950053, 'MEX', 'USA'),
#  (2010, '11 Jul 2010 - 20:30 ', 'Final', 'Soccer City Stadium', 'Johannesburg ', 'Netherlands', 0, 1, 'Spain', 'Spain win after extra time ', 84490.0, 0, 0, 'WEBB Howard (ENG)', 'Darren CANN (ENG)', 'MULLARKEY Michael (ENG)', 249721, 300061509, 'NED', 'ESP'),
#  (2006, '26 Jun 2006 - 17:00 ', 'Round of 16', 'Fritz-Walter-Stadion', 'Kaiserslautern ', 'Italy', 1, 0, 'Australia', ' ', 46000.0, 0, 0, 'MEDINA CANTALEJO Luis (ESP)', 'GIRALDEZ CARRASCO Victoriano (ESP)', 'MEDINA HERNANDEZ Pedro (ESP)', 97410200, 97410053, 'ITA', 'AUS'),
#  (2002, '17 Jun 2002 - 20:30 ', 'Round of 16', 'Kobe Wing Stadium', 'Kobe ', 'Brazil', 2, 0, 'Belgium', ' ', 40440.0, 0, 0, 'PRENDERGAST Peter (JAM)', 'DUPANOV Yuri (BLR)', 'SAEED Mohamed (MDV)', 43950200, 43950054, 'BRA', 'BEL'),
#  (1982, '22 Jun 1982 - 17:15 ', 'Group 1', 'Riazor', 'La Coru�A ', 'Poland', 5, 1, 'Peru', ' ', 25000.0, 0, 0, 'RUBIO VAZQUEZ Mario (MEX)', 'SORIANO ALADREN Emilio (ESP)', 'SANCHEZ ARMINIO Victoriano (ESP)', 293, 1055, 'POL', 'PER'),
#  (1954, '30 Jun 1954 - 18:00 ', 'Semi-finals', 'La Pontaise', 'Lausanne ', 'Hungary', 4, 2, 'Uruguay', 'Hungary win after extra time ', 45000.0, 0, 0, 'GRIFFITHS Benjamin (WAL)', 'FAULTLESS Charlie (SCO)', 'VINCENTI Raymond (FRA)', 462, 1295, 'HUN', 'URU'),
#  (1938, '05 Jun 1938 - 18:30 ', 'First round', 'Cavee Verte', 'Le Havre ', 'Czechoslovakia', 3, 0, 'Netherlands', 'Czechoslovakia win after extra time ', 11000.0, 0, 0, 'LECLERCQ Lucien (FRA)', 'OLIVE D. (FRA)', 'SDEZ Victor (FRA)', 206, 1172, 'TCH', 'NED'),
#  (2006, '24 Jun 2006 - 21:00 ', 'Round of 16', 'Zentralstadion', 'Leipzig ', 'Argentina', 2, 1, 'Mexico', 'Argentina win after extra time ', 43000.0, 0, 0, 'BUSACCA Massimo (SUI)', 'BURAGINA Francesco (SUI)', 'ARNET Matthias (SUI)', 97410200, 97410050, 'ARG', 'MEX'),
#  (1998, '28 Jun 1998 - 16:30 ', 'Round of 16', 'Stade Felix Bollaert', 'Lens ', 'France', 1, 0, 'Paraguay', 'France win after extra time ', 31800.0, 0, 0, 'BUJSAIM Ali (UAE)', 'WICKRAMATUNGA Nimal (SRI)', 'FRED Lencie (VAN)', 1024, 8776, 'FRA', 'PAR'),
#  (1986, '15 Jun 1986 - 16:00 ', 'Round of 16', 'Nou Camp - Estadio Le�n', 'Leon ', 'Soviet Union', 3, 4, 'Belgium', 'Belgium win after extra time ', 32277.0, 0, 0, 'FREDRIKSSON Erik (SWE)', 'SANCHEZ ARMINIO Victoriano (ESP)', 'SOCHA David (USA)', 309, 432, 'URS', 'BEL'),
#  (1938, '12 Jun 1938 - 17:00 ', 'Quarter-finals', 'Victor Boucquey', 'Lille ', 'Hungary', 2, 0, 'Switzerland', ' ', 15000.0, 1, 0, 'BARLASSINA Rinaldo (ITA)', 'BERANEK Alois (AUT)', 'BOUTOURE D. (FRA)', 429, 1175, 'HUN', 'SUI'),
#  (1966, '25 Jul 1966 - 19:30 ', 'Semi-finals', 'Goodison Park', 'Liverpool ', 'Germany FR', 2, 1, 'Soviet Union', ' ', 38273.0, 1, 0, 'LO BELLO Concetto (ITA)', 'CODESAL Jose Maria (URU)', 'GARDEAZABAL Juan (ESP)', 536, 1659, 'FRG', 'URS'),
#  (1966, '30 Jul 1966 - 15:00 ', 'Final', 'Wembley Stadium', 'London ', 'England', 4, 2, 'Germany FR', 'England win after extra time ', 96924.0, 0, 0, 'DIENST Gottfried (SUI)', 'BAKHRAMOV Tofik (URS)', 'GALBA Karol (TCH)', 3478, 1633, 'ENG', 'FRG'),
#  (1994, '17 Jul 1994 - 12:30 ', 'Final', 'Rose Bowl', 'Los Angeles ', 'Brazil', 0, 0, 'Italy', 'Brazil win on penalties (3 - 2) ', 94194.0, 0, 0, 'PUHL Sandor (HUN)', 'ZARATE Venancio (PAR)', 'FANAEI Mohammad (IRN)', 3459, 3104, 'BRA', 'ITA'),
#  (1954, '20 Jun 1954 - 17:00 ', 'Group 4', 'Comunale di Cornaredo', 'Lugano ', 'Italy', 4, 1, 'Belgium', ' ', 24000.0, 1, 0, 'STEINER Carl (AUT)', 'VINCENTI Raymond (FRA)', 'SCHMETZER Emil (FRG)', 211, 1243, 'ITA', 'BEL'),
#  (1998, '04 Jul 1998 - 21:00 ', 'Quarter-finals', 'Stade de Gerland', 'Lyon ', 'Germany', 0, 3, 'Croatia', ' ', 39100.0, 0, 1, 'PEDERSEN Rune (NOR)', 'NILSSON Mikael (SWE)', 'VAN DEN BROECK Marc (BEL)', 1025, 8783, 'GER', 'CRO'),
#  (1982, '11 Jul 1982 - 20:00 ', 'Final', 'Santiago Bernabeu', 'Madrid ', 'Italy', 3, 1, 'Germany FR', ' ', 90000.0, 0, 0, 'COELHO Arnaldo (BRA)', 'KLEIN Abraham (ISR)', 'CHRISTOV Vojtech (TCH)', 3475, 923, 'ITA', 'FRG'),
#  (1982, '22 Jun 1982 - 21:00 ', 'Group 6', 'La Rosaleda', 'Malaga ', 'Soviet Union', 2, 2, 'Scotland', ' ', 45000.0, 0, 1, 'RAINEA Nicolae (ROU)', 'JARGUZ Alojzy (POL)', 'PONNET Alexis (BEL)', 293, 1071, 'URS', 'SCO'),
#  (1958, '19 Jun 1958 - 19:00 ', 'Quarter-finals', 'Malmo Stadion', 'Malm� ', 'Germany FR', 1, 0, 'Yugoslavia', ' ', 20055.0, 1, 0, 'WYSSLING Paul (SUI)', 'FERNANDES CAMPOS Joaquim (POR)', 'HELGE Leo (DEN)', 221, 1392, 'FRG', 'YUG'),
#  (2014, '25 Jun 2014 - 16:00 ', 'Group E', 'Arena Amazonia', 'Manaus ', 'Honduras', 0, 3, 'Switzerland', ' ', 40322.0, 0, 2, 'PITANA Nestor (ARG)', 'MAIDANA Hernan (ARG)', 'BELATTI Juan Pablo (ARG)', 255931, 300186482, 'HON', 'SUI'),
#  (1966, '20 Jul 1966 - 19:30 ', 'Group 3', 'Old Trafford Stadium', 'Manchester ', 'Hungary', 3, 1, 'Bulgaria', ' ', 24129.0, 2, 1, 'GOICOECHEA Roberto (ARG)', 'GARDEAZABAL Juan (ESP)', 'CODESAL Jose Maria (URU)', 238, 1599, 'HUN', 'BUL'),
#  (2010, '27 Jun 2010 - 16:00 ', 'Round of 16', 'Free State Stadium', 'Mangaung/Bloemfontein ', 'Germany', 4, 1, 'England', ' ', 40510.0, 2, 1, 'LARRIONDA Jorge (URU)', 'FANDINO Pablo (URU)', 'ESPINOSA Mauricio (URU)', 249717, 300061501, 'GER', 'ENG'),
#  (1978, '11 Jun 1978 - 13:45 ', 'Group 3', 'Estadio Jos� Mar�a Minella', 'Mar Del Plata ', 'Brazil', 1, 0, 'Austria', ' ', 35221.0, 1, 0, 'WURTZ Robert (FRA)', 'BOUZO Farouk (SYR)', 'GEBREYESUS DIFUE Tesfaye (ERI)', 278, 2215, 'BRA', 'AUT'),
#  (1998, '07 Jul 1998 - 21:00 ', 'Semi-finals', 'Stade V�lodrome', 'Marseilles ', 'Brazil', 1, 1, 'Netherlands', 'Brazil win on penalties (4 - 2) ', 54000.0, 0, 0, 'BUJSAIM Ali (UAE)', 'GHADANFARI Hussain (KUW)', 'AL MUSAWI Mohamed (OMA)', 1026, 8785, 'BRA', 'NED'),
#  (1978, '21 Jun 1978 - 16:45 ', 'Group B', 'San Martin', 'Mendoza ', 'Brazil', 3, 1, 'Poland', ' ', 39586.0, 1, 1, 'SILVAGNO CAVANNA Juan (CHI)', 'IVANOV Anatoly (URS)', 'GONZALEZ ARCHUNDIA Alfonso (MEX)', 279, 2252, 'BRA', 'POL'),
#  (1986, '29 Jun 1986 - 12:00 ', 'Final', 'Estadio Azteca', 'Mexico City ', 'Argentina', 3, 2, 'Germany FR', ' ', 114600.0, 1, 0, 'ARPPI FILHO Romualdo (BRA)', 'FREDRIKSSON Erik (SWE)', 'ULLOA MORERA Berny (CRC)', 3467, 393, 'ARG', 'FRG'),
#  (1966, '19 Jul 1966 - 19:30 ', 'Group 4', 'Ayresome Park', 'Middlesbrough ', 'Korea DPR', 1, 0, 'Italy', ' ', 17829.0, 1, 0, 'SCHWINTE Pierre (FRA)', 'ADAIR John (NIR)', 'TAYLOR John (ENG)', 238, 1679, 'PRK', 'ITA'),
#  (1990, '01 Jul 1990 - 17:00 ', 'Quarter-finals', 'Giuseppe Meazza', 'Milan ', 'Germany FR', 1, 0, 'Czechoslovakia', ' ', 73347.0, 1, 0, 'KOHL Helmut (AUT)', 'MIKKELSEN Peter (DEN)', 'LISTKIEWICZ Michal (POL)', 751, 197, 'FRG', 'TCH'),
#  (1986, '21 Jun 1986 - 16:00 ', 'Quarter-finals', 'Estadio Universitario', 'Monterrey ', 'Germany FR', 0, 0, 'Mexico', 'Germany FR win on penalties (4 - 1) ', 41700.0, 0, 0, 'DIAZ PALACIO Jesus (COL)', 'BAMBRIDGE Christopher (AUS)', 'SNODDY Alan (NIR)', 714, 575, 'FRG', 'MEX'),
#  (1930, '30 Jul 1930 - 14:15 ', 'Final', 'Estadio Centenario', 'Montevideo ', 'Uruguay', 4, 2, 'Argentina', ' ', 68346.0, 1, 2, 'LANGENUS Jean (BEL)', 'SAUCEDO Ulises (BOL)', 'CRISTOPHE Henry (BEL)', 405, 1087, 'URU', 'ARG'),
#  (1998, '29 Jun 1998 - 16:30 ', 'Round of 16', 'La Mosson', 'Montpellier ', 'Germany', 2, 1, 'Mexico', ' ', 29800.0, 0, 0, 'MELO PEREIRA Vitor (POR)', 'MANSRI Mohamed (TUN)', 'SALIE Achmat (RSA)', 1024, 8777, 'GER', 'MEX'),
#  (2006, '05 Jul 2006 - 21:00 ', 'Semi-finals', 'FIFA World Cup Stadium, Munich', 'Munich ', 'Portugal', 0, 1, 'France', ' ', 66000.0, 0, 1, 'LARRIONDA Jorge (URU)', 'RIAL Walter (URU)', 'FANDINO Pablo (URU)', 97410400, 97410062, 'POR', 'FRA'),
#  (1998, '03 Jul 1998 - 21:00 ', 'Quarter-finals', 'La Beaujoire', 'Nantes ', 'Brazil', 3, 2, 'Denmark', ' ', 35500.0, 2, 1, 'EL GHANDOUR Gamal (EGY)', 'MANSRI Mohamed (TUN)', 'DANTE Dramane (MLI)', 1025, 8782, 'BRA', 'DEN'),
#  (1990, '03 Jul 1990 - 20:00 ', 'Semi-finals', 'San Paolo', 'Naples ', 'Italy', 1, 1, 'Argentina', ' win on penalties (3 - 4) ', 59978.0, 0, 0, 'VAUTROT Michel (FRA)', 'LISTKIEWICZ Michal (POL)', 'MIKKELSEN Peter (DEN)', 3464, 28, 'ITA', 'ARG'),
#  (2014, '24 Jun 2014 - 13:00 ', 'Group D', 'Estadio das Dunas', 'Natal ', 'Italy', 0, 1, 'Uruguay', ' ', 39706.0, 0, 0, 'RODRIGUEZ Marco (MEX)', 'TORRENTERA Marvin (MEX)', 'QUINTERO Marcos (MEX)', 255931, 300186465, 'ITA', 'URU'),
#  (2010, '10 Jul 2010 - 20:30 ', 'Match for third place', 'Port Elizabeth Stadium', 'Nelson Mandela Bay/Port Elizabeth ', 'Uruguay', 2, 3, 'Germany', ' ', 36254.0, 1, 1, 'ARCHUNDIA Benito (MEX)', 'VERGARA Hector (CAN)', 'TORRENTERA Marvin (MEX)', 249720, 300061510, 'URU', 'GER'),
#  (2010, '25 Jun 2010 - 16:00 ', 'Group G', 'Mbombela Stadium', 'Nelspruit ', 'Korea DPR', 0, 3, "C�te d'Ivoire", ' ', 34763.0, 0, 2, 'Alberto UNDIANO MALLENCO (ESP)', 'MARTINEZ Fermin (ESP)', 'YUSTE Juan (ESP)', 249722, 300061486, 'PRK', 'CIV'),
#  (1994, '13 Jul 1994 - 16:00 ', 'Semi-finals', 'Giants Stadium', 'New York/New Jersey ', 'Bulgaria', 1, 2, 'Italy', ' ', 74110.0, 1, 2, 'QUINIOU Joel (FRA)', 'CHRISTENSEN Carl-Johan Meyer (DEN)', 'PEARSON Roy (ENG)', 3461, 3100, 'BUL', 'ITA'),
#  (1986, '13 Jun 1986 - 12:00 ', 'Group E', 'Neza', 'Nezahualcoyotl ', 'Scotland', 0, 0, 'Uruguay', ' ', 20000.0, 0, 0, 'QUINIOU Joel (FRA)', 'DIAZ PALACIO Jesus (COL)', 'BENNACEUR Ali (TUN)', 308, 712, 'SCO', 'URU'),
#  (2002, '15 Jun 2002 - 20:30 ', 'Round of 16', 'Niigata Stadium Big Swan', 'Niigata ', 'Denmark', 0, 3, 'England', ' ', 40582.0, 0, 3, 'MERK Markus (GER)', 'MUELLER Heiner (GER)', 'AMLER Evzen (CZE)', 43950200, 43950050, 'DEN', 'ENG'),
#  (1958, '19 Jun 1958 - 19:00 ', 'Quarter-finals', 'Idrottsparken', 'Norrk�Ping ', 'France', 4, 0, 'Northern Ireland', ' ', 11800.0, 1, 0, 'GARDEAZABAL Juan (ESP)', 'LATYCHEV Nikolaj (URS)', 'ANDREN Bengt (SWE)', 221, 1385, 'FRA', 'NIR'),
#  (2006, '25 Jun 2006 - 21:00 ', 'Round of 16', 'Franken-Stadion', 'Nuremberg ', 'Portugal', 1, 0, 'Netherlands', ' ', 41000.0, 1, 0, 'IVANOV Valentin (RUS)', 'GOLUBEV Nikolai (RUS)', 'VOLNIN Evgueni (RUS)', 97410200, 97410052, 'POR', 'NED'),
#  (2002, '16 Jun 2002 - 15:30 ', 'Round of 16', 'Oita Stadium Big Eye', 'Oita ', 'Sweden', 1, 2, 'Senegal', 'Win on Golden Goal ', 39747.0, 0, 0, 'AQUINO Ubaldo (PAR)', 'GIACOMUZZI Miguel (PAR)', 'VERGARA Hector (CAN)', 43950200, 43950051, 'SWE', 'SEN'),
#  (1958, '15 Jun 1958 - 19:00 ', 'Group 2', 'Eyravallen', 'Orebro ', 'France', 2, 1, 'Scotland', ' ', 13554.0, 2, 0, 'BROZZI Juan (ARG)', 'ORLANDINI Vincenzo (ITA)', 'WYSSLING Paul (SUI)', 220, 1387, 'FRA', 'SCO'),
#  (1994, '04 Jul 1994 - 12:00 ', 'Round of 16', 'Citrus Bowl', 'Orlando ', 'Netherlands', 2, 0, 'rn">Republic of Ireland', ' ', 61355.0, 2, 0, 'MIKKELSEN Peter (DEN)', 'DUNSTER Gordon (AUS)', 'BRAZZALE Eugene (AUS)', 338, 3089, 'NED', 'IRL'),
#  (2002, '22 Jun 2002 - 20:30 ', 'Quarter-finals', 'Osaka Nagai Stadium', 'Osaka ', 'Senegal', 0, 1, 'Turkey', 'Win on Golden Goal ', 44233.0, 0, 0, 'RUIZ Oscar (COL)', 'RATTALINO Jorge (ARG)', 'GIACOMUZZI Miguel (PAR)', 43950300, 43950060, 'SEN', 'TUR'),
#  (1982, '24 Jun 1982 - 17:15 ', 'Group 2', 'Carlos Tartiere', 'Oviedo ', 'Algeria', 3, 2, 'Chile', ' ', 16000.0, 3, 0, 'MENDEZ MOLINA Romulo (GUA)', 'FREDRIKSSON Erik (SWE)', 'COELHO Arnaldo (BRA)', 293, 740, 'ALG', 'CHI'),
#  (1990, '21 Jun 1990 - 21:00 ', 'Group F', 'Della Favorita', 'Palermo ', 'rn">Republic of Ireland', 1, 1, 'Netherlands', ' ', 33288.0, 0, 1, 'VAUTROT Michel (FRA)', 'LORENC Richard (AUS)', 'HANSAL Mohamed (ALG)', 322, 228, 'IRL', 'NED'),
#  (1998, '11 Jul 1998 - 21:00 ', 'Match for third place', 'Parc des Princes', 'Paris ', 'Netherlands', 1, 2, 'Croatia', ' ', 45500.0, 1, 2, 'GONZALEZ CHAVEZ Epifanio (PAR)', 'ZAMMIT Emanuel (MLT)', 'FRED Lencie (VAN)', 1028, 8787, 'NED', 'CRO'),
#  (2010, '26 Jun 2010 - 20:30 ', 'Round of 16', 'Royal Bafokeng Sports Palace', 'Phokeng ', 'USA', 1, 2, 'Ghana', 'Ghana win after extra time ', 34976.0, 0, 0, 'KASSAI Viktor (HUN)', 'EROS Gabor (HUN)', 'VAMOS Tibor (HUN)', 249717, 300061503, 'USA', 'GHA'),
#  (2010, '24 Jun 2010 - 16:00 ', 'Group F', 'Peter Mokaba Stadium', 'Polokwane ', 'Paraguay', 0, 0, 'New Zealand', ' ', 34850.0, 0, 0, 'NISHIMURA Yuichi (JPN)', 'SAGARA Toru (JPN)', 'JEONG Hae Sang (KOR)', 249722, 300061479, 'PAR', 'NZL'),
#  (2014, '30 Jun 2014 - 17:00 ', 'Round of 16', 'Estadio Beira-Rio', 'Porto Alegre ', 'Germany', 2, 1, 'Algeria', 'Germany win after extra time ', None, 0, 0, 'RICCI Sandro (BRA)', 'DE CARVALHO Emerson (BRA)', 'VAN GASSE Marcelo (BRA)', 255951, 300186460, 'GER', 'ALG'),
#  (1986, '28 Jun 1986 - 12:00 ', 'Match for third place', 'Cuauhtemoc', 'Puebla ', 'France', 4, 2, 'Belgium', 'France win after extra time ', 21000.0, 0, 0, 'COURTNEY George (ENG)', 'SILVA ARCE Hernan (CHI)', 'AL SHARIF Jamal (SYR)', 3468, 422, 'FRA', 'BEL'),
#  (1986, '18 Jun 1986 - 16:00 ', 'Round of 16', 'Estadio Corregidora', 'Queretaro ', 'Denmark', 1, 5, 'Spain', ' ', 38500.0, 1, 1, 'KEIZER Jan (NED)', 'BENNACEUR Ali (TUN)', 'DOTCHEV Bogdan (BUL)', 309, 511, 'DEN', 'ESP'),
#  (1962, '10 Jun 1962 - 14:30 ', 'Quarter-finals', 'Estadio El Teniente-Codelco', 'Rancagua ', 'Czechoslovakia', 1, 0, 'Hungary', ' ', 11690.0, 1, 0, 'LATYCHEV Nikolaj (URS)', 'BUERGO Fernando (MEX)', 'RUMENTCHEV Dimitar (BUL)', 232, 1525, 'TCH', 'HUN'),
#  (2014, '29 Jun 2014 - 17:00 ', 'Round of 16', 'Arena Pernambuco', 'Recife ', 'Costa Rica', 1, 1, 'Greece', 'Costa Rica win on penalties (5 - 3) ', 41242.0, 0, 0, 'Ben WILLIAMS (AUS)', 'CREAM Matthew (AUS)', 'ANAZ Hakan (AUS)', 255951, 300186459, 'CRC', 'GRE'),
#  (1938, '05 Jun 1938 - 17:00 ', 'First round', 'Velodrome Municipale', 'Reims ', 'Hungary', 6, 0, 'Dutch East Indies', ' ', 9000.0, 4, 0, 'CONRIE Roger (FRA)', 'DE LA SALLE Charles (FRA)', 'WEINGARTNER Karl (AUT)', 206, 1173, 'HUN', 'INH'),
#  (2002, '18 Jun 2002 - 15:30 ', 'Round of 16', 'Miyagi Stadium', 'Rifu ', 'Japan', 0, 1, 'Turkey', ' ', 45666.0, 0, 1, 'COLLINA Pierluigi (ITA)', 'WIERZBOWSKI Maciej (POL)', 'SMITH Paul (NZL)', 43950200, 43950055, 'JPN', 'TUR'),
#  (2014, '13 Jul 2014 - 16:00 ', 'Final', 'Estadio do Maracana', 'Rio De Janeiro ', 'Germany', 1, 0, 'Argentina', 'Germany win after extra time ', 74738.0, 0, 0, 'Nicola RIZZOLI (ITA)', 'Renato FAVERANI (ITA)', 'Andrea STEFANI (ITA)', 255959, 300186501, 'GER', 'ARG'),
#  (1990, '08 Jul 1990 - 20:00 ', 'Final', 'Stadio Olimpico', 'Rome ', 'Germany FR', 1, 0, 'Argentina', ' ', 73603.0, 0, 0, 'CODESAL MENDEZ Edgardo (MEX)', 'PEREZ HOYOS Armando (COL)', 'LISTKIEWICZ Michal (POL)', 3462, 27, 'FRG', 'ARG'),
#  (1978, '21 Jun 1978 - 19:15 ', 'Group B', 'Arroyito - Estadio Dr. Lisandro de la Torre', 'Rosario ', 'Argentina', 6, 0, 'Peru', ' ', 37315.0, 2, 0, 'WURTZ Robert (FRA)', 'BIWERSI Ferdinand (GER)', 'GONELLA Sergio (ITA)', 279, 2201, 'ARG', 'PER'),
#  (1998, '12 Jul 1998 - 21:00 ', 'Final', 'Stade de France', 'Saint-Denis ', 'Brazil', 0, 3, 'France', ' ', 80000.0, 0, 2, 'BELQOLA Said (MAR)', 'WARREN Mark (ENG)', 'SALIE Achmat (RSA)', 1027, 8788, 'BRA', 'FRA'),
#  (1998, '30 Jun 1998 - 21:00 ', 'Round of 16', 'Stade Geoffroy Guichard', 'Saint-Etienne ', 'Argentina', 2, 2, 'England', 'Argentina win on penalties (4 - 3) ', 30600.0, 0, 0, 'NIELSEN Kim Milton (DEN)', 'ABDUL HAMID Halim (MAS)', 'AL MUSAWI Mohamed (OMA)', 1024, 8779, 'ARG', 'ENG'),
#  (2002, '26 Jun 2002 - 20:30 ', 'Semi-finals', 'Saitama Stadium 2002', 'Saitama ', 'Brazil', 1, 0, 'Turkey', ' ', 61058.0, 0, 0, 'NIELSEN Kim Milton (DEN)', 'WIERZBOWSKI Maciej (POL)', 'SRAMKA Igor (SVK)', 43950400, 43950062, 'BRA', 'TUR'),
#  (2014, '05 Jul 2014 - 17:00 ', 'Quarter-finals', 'Arena Fonte Nova', 'Salvador ', 'Netherlands', 0, 0, 'Costa Rica', 'Netherlands win on penalties (4 - 3) ', 51179.0, 0, 0, 'Ravshan IRMATOV (UZB)', 'RASULOV Abduxamidullo (UZB)', 'KOCHKAROV Bakhadyr (KGZ)', 255953, 300186488, 'NED', 'CRC'),
#  (1994, '10 Jul 1994 - 12:30 ', 'Quarter-finals', 'Stanford Stadium', 'San Francisco ', 'Romania', 2, 2, 'Sweden', 'Sweden win on penalties (4 - 5) ', 83500.0, 0, 0, 'DON Philip (ENG)', 'PEARSON Roy (ENG)', 'PARK Hae-Yong (KOR)', 796, 3095, 'ROU', 'SWE'),
#  (1958, '15 Jun 1958 - 19:00 ', 'Group 3', 'Jarnvallen', 'Sandviken ', 'Hungary', 4, 0, 'Mexico', ' ', 13300.0, 1, 0, 'ERIKSSON Arne (FIN)', 'CODESAL Jose Maria (URU)', 'MOWAT Jack (SCO)', 220, 1403, 'HUN', 'MEX'),
#  (1962, '17 Jun 1962 - 14:30 ', 'Final', 'Nacional', 'Santiago De Chile ', 'Brazil', 3, 1, 'Czechoslovakia', ' ', 68679.0, 1, 1, 'LATYCHEV Nikolaj (URS)', 'HORN Leo (NED)', 'DAVIDSON Bob (SCO)', 3480, 1463, 'BRA', 'TCH'),
#  (2014, '09 Jul 2014 - 17:00 ', 'Semi-finals', 'Arena de Sao Paulo', 'Sao Paulo ', 'Netherlands', 0, 0, 'Argentina', 'Argentina win on penalties (2 - 4) ', 63267.0, 0, 0, 'C�neyt �AKIR (TUR)', 'DURAN Bahattin (TUR)', 'ONGUN Tarik (TUR)', 255955, 300186490, 'NED', 'ARG'),
#  (2002, '07 Jun 2002 - 20:30 ', 'Group F', 'Sapporo Dome', 'Sapporo ', 'Argentina', 0, 1, 'England', ' ', 35927.0, 0, 1, 'COLLINA Pierluigi (ITA)', 'VERGARA Hector (CAN)', 'SAEED Mohamed (MDV)', 43950100, 43950023, 'ARG', 'ENG'),
#  (2002, '25 Jun 2002 - 20:30 ', 'Semi-finals', 'Seoul World Cup Stadium', 'Seoul ', 'Germany', 1, 0, 'Korea Republic', ' ', 65256.0, 0, 0, 'MEIER Urs (SUI)', 'ARNAULT Frederic (FRA)', 'AMLER Evzen (CZE)', 43950400, 43950061, 'GER', 'KOR'),
#  (1982, '08 Jul 1982 - 21:00 ', 'Semi-finals', 'Ramon Sanchez Pizjuan', 'Seville ', 'Germany FR', 3, 3, 'France', ' win on penalties (5 - 4) ', 70000.0, 0, 0, 'CORVER Charles (NED)', 'GALLER Bruno (SUI)', 'VALENTINE Robert (SCO)', 295, 914, 'FRG', 'FRA'),
#  (1966, '23 Jul 1966 - 15:00 ', 'Quarter-finals', 'Hillsborough', 'Sheffield ', 'Germany FR', 4, 0, 'Uruguay', ' ', 40007.0, 1, 0, 'FINNEY Jim (ENG)', 'KANDIL Aly Hussein (EGY)', 'PHILLIPS Hugh (SCO)', 239, 1660, 'FRG', 'URU'),
#  (2002, '21 Jun 2002 - 15:30 ', 'Quarter-finals', 'Shizuoka Stadium Ecopa', 'Shizuoka ', 'England', 1, 2, 'Brazil', ' ', 47436.0, 1, 1, 'RAMOS RIZO Felipe (MEX)', 'VERGARA Hector (CAN)', 'SAEED Mohamed (MDV)', 43950300, 43950057, 'ENG', 'BRA'),
#  (1958, '29 Jun 1958 - 15:00 ', 'Final', 'Rasunda Stadium', 'Solna ', 'Brazil', 5, 2, 'Sweden', ' ', 49737.0, 2, 1, 'GUIGUE Maurice (FRA)', 'DUSCH Albert (GER)', 'GARDEAZABAL Juan (ESP)', 3482, 1343, 'BRA', 'SWE'),
#  (1938, '05 Jun 1938 - 17:30 ', 'First round', 'Stade de la Meinau', 'Strasbourg ', 'Brazil', 6, 5, 'Poland', 'Brazil win after extra time ', 13452.0, 0, 0, 'EKLIND Ivan (SWE)', 'POISSANT Louis (FRA)', 'KISSENBERGER Ernest (FRA)', 206, 1150, 'BRA', 'POL'),
#  (2006, '08 Jul 2006 - 21:00 ', 'Third place', 'Gottlieb-Daimler-Stadion', 'Stuttgart ', 'Germany', 3, 1, 'Portugal', ' ', 52000.0, 0, 0, 'KAMIKAWA Toru (JPN)', 'HIROSHIMA Yoshikazu (JPN)', 'KIM Dae Young (KOR)', 97410500, 97410063, 'GER', 'POR'),
#  (1966, '23 Jul 1966 - 15:00 ', 'Quarter-finals', 'Roker Park Ground', 'Sunderland ', 'Soviet Union', 2, 1, 'Hungary', ' ', 26844.0, 1, 0, 'GARDEAZABAL Juan (ESP)', 'CODESAL Jose Maria (URU)', 'FERNANDES CAMPOS Joaquim (POR)', 239, 1676, 'URS', 'HUN'),
#  (2002, '16 Jun 2002 - 20:30 ', 'Round of 16', 'Suwon World Cup Stadium', 'Suwon ', 'Spain', 1, 1, 'rn">Republic of Ireland', 'Spain win on penalties (3 - 2) ', 38926.0, 0, 0, 'FRISK Anders (SWE)', 'LINDBERG Leif (SWE)', 'SRAMKA Igor (SVK)', 43950200, 43950052, 'ESP', 'IRL'),
#  (1986, '11 Jun 1986 - 12:00 ', 'Group B', 'Bombonera - Estadio Nemesio Diez', 'Toluca ', 'Paraguay', 2, 2, 'Belgium', ' ', 16000.0, 0, 1, 'DOTCHEV Bogdan (BUL)', 'BENNACEUR Ali (TUN)', 'SILVA ARCE Hernan (CHI)', 308, 429, 'PAR', 'BEL'),
#  (1998, '29 Jun 1998 - 21:00 ', 'Round of 16', 'Stade Municipal', 'Toulouse ', 'Netherlands', 2, 1, 'Yugoslavia', ' ', 33500.0, 1, 0, 'GARCIA ARANDA Jose Maria (ESP)', 'RAUSIS Laurent (SUI)', 'GRIGORESCU Nicolae (ROU)', 1024, 8778, 'NED', 'YUG'),
#  (1934, '27 May 1934 - 16:30 ', 'Preliminary round', 'Littorio', 'Trieste ', 'Czechoslovakia', 2, 1, 'Romania', ' ', 9000.0, 0, 1, 'LANGENUS Jean (BEL)', 'SCARPI Giuseppe (ITA)', 'SCORZONI Raffaele (ITA)', 204, 1141, 'TCH', 'ROU'),
#  (2010, '29 Jun 2010 - 16:00 ', 'Round of 16', 'Loftus Versfeld Stadium', 'Tshwane/Pretoria ', 'Paraguay', 0, 0, 'Japan', 'Paraguay win on penalties (5 - 3) ', 36742.0, 0, 0, 'DE BLEECKERE Frank (BEL)', 'HERMANS Peter (BEL)', 'VROMANS Walter (BEL)', 249717, 300061497, 'PAR', 'JPN'),
#  (1990, '04 Jul 1990 - 20:00 ', 'Semi-finals', 'Stadio delle Alpi', 'Turin ', 'Germany FR', 1, 1, 'England', ' win on penalties (4 - 3) ', 62628.0, 0, 0, 'RAMIZ WRIGHT Jose (BRA)', 'QUINIOU Joel (FRA)', 'PEREZ HOYOS Armando (COL)', 3464, 159, 'FRG', 'ENG'),
#  (1958, '08 Jun 1958 - 19:00 ', 'Group 4', 'Rimnersvallen', 'Udevalla ', 'Brazil', 3, 0, 'Austria', ' ', 17788.0, 1, 0, 'GUIGUE Maurice (FRA)', 'DUSCH Albert (GER)', 'BRONKHORST Jan (NED)', 220, 1326, 'BRA', 'AUT'),
#  (1990, '21 Jun 1990 - 17:00 ', 'Group E', 'Friuli', 'Udine ', 'Korea Republic', 0, 1, 'Uruguay', ' ', 29039.0, 0, 0, 'LANESE Tullio (ITA)', 'DIRAMBA Jean Fidele (GAB)', 'JOUINI Neji (TUN)', 322, 290, 'KOR', 'URU'),
#  (2002, '21 Jun 2002 - 20:30 ', 'Quarter-finals', 'Munsu Football Stadium', 'Ulsan ', 'Germany', 1, 0, 'USA', ' ', 37337.0, 1, 0, 'DALLAS Hugh (SCO)', 'SHARP Philip (ENG)', 'ALTRAIFI Ali (KSA)', 43950300, 43950058, 'GER', 'USA'),
#  (1982, '25 Jun 1982 - 21:00 ', 'Group 5', 'Luis Casanova', 'Valencia ', 'Northern Ireland', 1, 0, 'Spain', ' ', 49562.0, 0, 0, 'ORTIZ Hector (PAR)', 'LABO REVOREDO Enrique (PER)', 'PONNET Alexis (BEL)', 293, 902, 'NIR', 'ESP'),
#  (1982, '24 Jun 1982 - 17:15 ', 'Group 4', 'Jose Zorrilla', 'Valladolid ', 'France', 1, 1, 'Czechoslovakia', ' ', 28000.0, 0, 0, 'CASARIN Paolo (ITA)', 'DWOMOH Benjamin (GHA)', 'PALOTAI Karoly (HUN)', 293, 922, 'FRA', 'TCH'),
#  (1958, '11 Jun 1958 - 19:00 ', 'Group 2', 'Arosvallen', 'Vasteras ', 'Yugoslavia', 3, 2, 'France', ' ', 12217.0, 1, 1, 'GRIFFITHS Benjamin (WAL)', 'WYSSLING Paul (SUI)', 'DRAGVOLL Georg (NOR)', 220, 1388, 'YUG', 'FRA'),
#  (1990, '26 Jun 1990 - 17:00 ', 'Round of 16', 'Marc Antonio Bentegodi', 'Verona ', 'Spain', 1, 2, 'Yugoslavia', 'Yugoslavia win after extra time ', 35500.0, 0, 0, 'SCHMIDHUBER Aron (GER)', 'SNODDY Alan (NIR)', 'LISTKIEWICZ Michal (POL)', 323, 181, 'ESP', 'YUG'),
#  (1982, '23 Jun 1982 - 17:15 ', 'Group 1', 'Estadio Municipal de Bala�dos', 'Vigo ', 'Italy', 1, 1, 'Cameroon', ' ', 20000.0, 0, 0, 'DOTCHEV Bogdan (BUL)', 'SORIANO ALADREN Emilio (ESP)', 'SANCHEZ ARMINIO Victoriano (ESP)', 293, 828, 'ITA', 'CMR'),
#  (1962, '13 Jun 1962 - 14:30 ', 'Semi-finals', 'Estadio Sausalito', 'Vina Del Mar ', 'Czechoslovakia', 3, 1, 'Yugoslavia', ' ', 5890.0, 0, 0, 'DIENST Gottfried (SUI)', 'STEINER Carl (AUT)', 'JONNI Cesare (ITA)', 514, 1559, 'TCH', 'YUG'),
#  (1994, '02 Jul 1994 - 16:30 ', 'Round of 16', 'RFK Stadium', 'Washington Dc ', 'Spain', 3, 0, 'Switzerland', ' ', 53121.0, 1, 0, 'VAN DER ENDE Mario (NED)', 'DOLSTRA Jan (NED)', 'MARTON Sandor (HUN)', 338, 3086, 'ESP', 'SUI'),
#  (2002, '30 Jun 2002 - 20:00 ', 'Final', 'International Stadium Yokohama', 'Yokohama ', 'Germany', 0, 2, 'Brazil', ' ', 69029.0, 0, 0, 'COLLINA Pierluigi (ITA)', 'LINDBERG Leif (SWE)', 'SHARP Philip (ENG)', 43950600, 43950064, 'GER', 'BRA'),
#  (1982, '24 Jun 1982 - 21:00 ', 'Group 5', 'La Romareda', 'Zaragoza ', 'Honduras', 0, 1, 'Yugoslavia', ' ', 25000.0, 0, 0, 'CASTRO Gaston (CHI)', 'SILES Jesus Paulino (CRC)', 'ITHURRALDE Arturo Andres (ARG)', 293, 962, 'HON', 'YUG'),
#  (1954, '03 Jul 1954 - 17:00 ', 'Match for third place', 'Hardturm', 'Zurich ', 'Austria', 3, 1, 'Uruguay', ' ', 32000.0, 1, 1, 'WYSSLING Paul (SUI)', 'ZSOLT Istvan (HUN)', 'ELLIS Arthur (ENG)', 3485, 1239, 'AUT', 'URU')]

# %% [markdown]
# ##1.11 Null Values

# %%
# Example 1
# Select any one record from the world cup dataset that has null examples?
# 
# %%sql
SELECT *
FROM WorldCup
WHERE Attendance IS NULL LIMIT 1;
# Out:
#  * sqlite://
# Done.
# [(2014, '30 Jun 2014 - 17:00 ', 'Round of 16', 'Estadio Beira-Rio', 'Porto Alegre ', 'Germany', 2, 1, 'Algeria', 'Germany win after extra time ', None, 0, 0, 'RICCI Sandro (BRA)', 'DE CARVALHO Emerson (BRA)', 'VAN GASSE Marcelo (BRA)', 255951, 300186460, 'GER', 'ALG')]

# %%
# Example 2
# Select any 5 records without null examples from the Worldcup Dataset 
#
# %%sql
SELECT *
FROM WorldCup
WHERE City IS NOT NULL
LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [(1930, '13 Jul 1930 - 15:00 ', 'Group 1', 'Pocitos', 'Montevideo ', 'France', 4, 1, 'Mexico', ' ', 4444.0, 3, 0, 'LOMBARDI Domingo (URU)', 'CRISTOPHE Henry (BEL)', 'REGO Gilberto (BRA)', 201, 1096, 'FRA', 'MEX'),
#  (1930, '13 Jul 1930 - 15:00 ', 'Group 4', 'Parque Central', 'Montevideo ', 'USA', 3, 0, 'Belgium', ' ', 18346.0, 2, 0, 'MACIAS Jose (ARG)', 'MATEUCCI Francisco (URU)', 'WARNKEN Alberto (CHI)', 201, 1090, 'USA', 'BEL'),
#  (1930, '14 Jul 1930 - 12:45 ', 'Group 2', 'Parque Central', 'Montevideo ', 'Yugoslavia', 2, 1, 'Brazil', ' ', 24059.0, 2, 0, 'TEJADA Anibal (URU)', 'VALLARINO Ricardo (URU)', 'BALWAY Thomas (FRA)', 201, 1093, 'YUG', 'BRA'),
#  (1930, '14 Jul 1930 - 14:50 ', 'Group 3', 'Pocitos', 'Montevideo ', 'Romania', 3, 1, 'Peru', ' ', 2549.0, 1, 0, 'WARNKEN Alberto (CHI)', 'LANGENUS Jean (BEL)', 'MATEUCCI Francisco (URU)', 201, 1098, 'ROU', 'PER'),
#  (1930, '15 Jul 1930 - 16:00 ', 'Group 1', 'Parque Central', 'Montevideo ', 'Argentina', 1, 0, 'France', ' ', 23409.0, 0, 0, 'REGO Gilberto (BRA)', 'SAUCEDO Ulises (BOL)', 'RADULESCU Constantin (ROU)', 201, 1085, 'ARG', 'FRA')]

# %% [markdown]
# ### <font color="green"> 1.11 Challenges</font>

# %%
# Challenge 1
# Using the Worldcup dataset, select all the records that contain null values?
#
# %%sql
SELECT * FROM WorldCup WHERE Datetime IS NULL OR Stage IS NULL OR Stadium IS NULL OR City IS NULL 
OR Home_Team_Name IS NULL OR Home_Team_Goals IS NULL OR Away_Team_Goals IS NULL 
OR Away_Team_Name IS NULL OR Win_conditions IS NULL OR Attendance IS NULL OR Halftime_Home_Goals IS NULL 
OR Halftime_Away_Goals IS NULL OR Referee IS NULL OR Assistant1 IS NULL OR Assistant2 IS NULL 
OR RoundID IS NULL OR MatchID IS NULL OR Home_Team_Initials IS NULL OR Away_Team_Initials IS NULL LIMIT 5;
# Out:
#  * sqlite://
# Done.
# [(2014, '30 Jun 2014 - 17:00 ', 'Round of 16', 'Estadio Beira-Rio', 'Porto Alegre ', 'Germany', 2, 1, 'Algeria', 'Germany win after extra time ', None, 0, 0, 'RICCI Sandro (BRA)', 'DE CARVALHO Emerson (BRA)', 'VAN GASSE Marcelo (BRA)', 255951, 300186460, 'GER', 'ALG'),
#  (2014, '30 Jun 2014 - 17:00 ', 'Round of 16', 'Estadio Beira-Rio', 'Porto Alegre ', 'Germany', 2, 1, 'Algeria', 'Germany win after extra time ', None, 0, 0, 'RICCI Sandro (BRA)', 'DE CARVALHO Emerson (BRA)', 'VAN GASSE Marcelo (BRA)', 255951, 300186460, 'GER', 'ALG')]

# %%
WorldCup.columns.values
# Out:
# array(['Datetime', 'Stage', 'Stadium', 'City', 'Home_Team_Name',
#        'Home_Team_Goals', 'Away_Team_Goals', 'Away_Team_Name',
#        'Win_conditions', 'Attendance', 'Halftime_Home_Goals',
#        'Halftime_Away_Goals', 'Referee', 'Assistant1', 'Assistant2',
#        'RoundID', 'MatchID', 'Home_Team_Initials', 'Away_Team_Initials'],
#       dtype=object)

# %%
# Challenge 2
# Select all the records that do not contain null values from the Interpol dataset
# %%sql
SELECT * FROM Interpol WHERE "National Fugitives" IS NOT NULL OR "Wanted Fugitives" IS NOT NULL 
OR "Possible Hosted Fugitives / Captured Fugitives" IS NOT NULL 
OR Region IS NOT NULL OR Flag IS NOT NULL;
# Out:
#  * sqlite://
# Done.
# [('Albania', 3, 3, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/al.gif'),
#  ('Angola', 0, 0, 1, 'Northern Africa', 'http://www.crwflags.com/fotw/images/a/ao.gif'),
#  ('Argentina', 2, 2, 1, 'South America', 'http://www.crwflags.com/fotw/images/a/ar.gif'),
#  ('Australia', 1, 1, 2, 'Oceania', 'http://www.crwflags.com/fotw/images/a/au.gif'),
#  ('Austria', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/a/at.gif'),
#  ('Bangladesh', 2, 1, 1, 'Asia', 'http://www.crwflags.com/fotw/images/b/bd.gif'),
#  ('Belarus', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/b/by.gif'),
#  ('Belgium', 0, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/b/be.gif'),
#  ('Belize', 1, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/b/bz.gif'),
#  ('Bolivia', 0, 0, 2, 'South America', 'http://www.crwflags.com/fotw/images/b/bo.gif'),
#  ('Botswana', 0, 1, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/b/bw.gif'),
#  ('Brazil', 2, 4, 3, 'South America', 'http://www.crwflags.com/fotw/images/b/br.gif'),
#  ('Cambodia', 0, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/k/kh.gif'),
#  ('Canada', 3, 4, 2, 'North America', 'http://www.crwflags.com/fotw/images/c/ca.gif'),
#  ('Cayman Islands', 0, 0, 1, 'Central America', 'http://www.crwflags.com/fotw/images/k/ky.gif'),
#  ('Chile', 1, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/c/cl.gif'),
#  ('Colombia', 3, 0, 1, 'South America', 'http://www.crwflags.com/fotw/images/c/co.gif'),
#  ('Congo', 0, 0, 1, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/c/cg.gif'),
#  ('Costa Rica', 0, 1, 2, 'Central America', 'http://www.crwflags.com/fotw/images/c/cr.gif'),
#  ('Croatia', 1, 1, 1, 'Europe', 'http://www.crwflags.com/fotw/images/h/hr.gif'),
#  ('Curaçao', 0, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/c/cw.gif'),
#  ('Czech Republic', 3, 3, 0, 'Europe', 'http://www.crwflags.com/fotw/images/c/cz.gif'),
#  ('Denmark', 0, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/d/dk.gif'),
#  ('Dominican Republic', 1, 1, 2, 'Central America', 'http://www.crwflags.com/fotw/images/d/do.gif'),
#  ('Ecuador', 0, 0, 1, 'South America', 'http://www.worldatlas.com/webimage/flags/countrys/zzzflags/eclarge.jpg'),
#  ('El Salvador', 2, 2, 0, 'Central America', 'http://www.crwflags.com/fotw/images/s/sv.gif'),
#  ('Estonia', 1, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/e/ee.gif'),
#  ('Finland', 2, 2, 3, 'Europe', 'http://www.crwflags.com/fotw/images/f/fi.gif'),
#  ('France', 0, 0, 7, 'Europe', 'http://www.crwflags.com/fotw/images/f/fr.gif'),
#  ('Georgia, Asia', 2, 2, 0, 'Asia', 'http://www.crwflags.com/fotw/images/g/ge.gif'),
#  ('Germany', 1, 0, 3, 'Europe', 'http://www.crwflags.com/fotw/images/d/de.gif'),
#  ('Greece', 1, 1, 3, 'Europe', 'http://www.crwflags.com/fotw/images/g/gr.gif'),
#  ('Honduras', 1, 0, 1, 'Central America', 'http://www.crwflags.com/fotw/images/h/hn.gif'),
#  ('Hungary', 2, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/h/hu.gif'),
#  ('India', 0, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/i/in.gif'),
#  ('Indonesia', 1, 1, 0, 'Asia', 'http://www.crwflags.com/fotw/images/i/id.gif'),
#  ('Iraq', 1, 0, 1, 'Asia', 'http://www.crwflags.com/fotw/images/i/iq.gif'),
#  ('Ireland', 2, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/i/ie.gif'),
#  ('Italy', 1, 1, 3, 'Europe', 'http://www.crwflags.com/fotw/images/i/it.gif'),
#  ('Kenya', 1, 1, 2, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/k/ke.gif'),
#  ('Lesotho', 0, 0, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/l/ls.gif'),
#  ('Lithuania', 1, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/l/lt.gif'),
#  ('Macedonia', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/mk.gif'),
#  ('Mali', 0, 1, 0, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/m/ml.gif'),
#  ('Malta', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/mt.gif'),
#  ('Mexico', 3, 0, 6, 'Central America', 'http://www.crwflags.com/fotw/images/m/mx.gif'),
#  ('Montenegro', 3, 2, 1, 'Europe', 'http://www.crwflags.com/fotw/images/m/me.gif'),
#  ('Morocco', 2, 0, 3, 'Northern Africa', 'http://www.crwflags.com/fotw/images/m/ma.gif'),
#  ('Mozambique', 0, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/m/mz.gif'),
#  ('Namibia', 0, 0, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/n/na.gif'),
#  ('New Zealand', 0, 0, 1, 'Oceania', 'http://www.crwflags.com/fotw/images/n/nz.gif'),
#  ('Nicaragua', 1, 1, 0, 'Central America', 'http://www.crwflags.com/fotw/images/n/ni.gif'),
#  ('Norway', 0, 1, 0, 'Europe', 'http://www.crwflags.com/fotw/images/n/no.gif'),
#  ('Pakistan', 1, 0, 2, 'Asia', 'http://www.crwflags.com/fotw/images/p/pk.gif'),
#  ('Panama', 0, 0, 2, 'Central America', 'http://www.crwflags.com/fotw/images/p/pa.gif'),
#  ('Paraguay', 1, 1, 1, 'South America', 'http://www.crwflags.com/fotw/images/p/py.gif'),
#  ('Peru', 2, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/p/pe.gif'),
#  ('Poland', 4, 4, 3, 'Europe', 'http://www.crwflags.com/fotw/images/p/pl.gif'),
#  ('Qatar', 0, 0, 1, 'Asia', 'http://upload.wikimedia.org/wikipedia/commons/6/65/Flag_of_Qatar.svg'),
#  ('Romania', 4, 4, 0, 'Europe', 'http://www.crwflags.com/fotw/images/r/ro.gif'),
#  ('Russia', 2, 1, 3, 'Europe, Asia', 'http://www.crwflags.com/fotw/images/r/ru.gif'),
#  ('Serbia', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/r/rs.gif'),
#  ('Slovakia', 2, 2, 0, 'Europe', 'http://www.crwflags.com/fotw/images/s/sk.gif'),
#  ('Somalia', 1, 0, 0, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/s/so.gif'),
#  ('South Africa', 3, 2, 4, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/za.gif'),
#  ('Spain', 1, 2, 13, 'Europe', 'http://www.crwflags.com/fotw/images/e/es.gif'),
#  ('Swaziland', 1, 1, 1, 'Southern Africa', 'http://www.crwflags.com/fotw/images/s/sz.gif'),
#  ('Sweden', 2, 3, 1, 'Europe', 'http://www.crwflags.com/fotw/images/s/se.gif'),
#  ('Tanzania', 0, 1, 2, 'Sub Saharan Africa', 'http://www.crwflags.com/fotw/images/t/tz.gif'),
#  ('The Netherlands', 6, 3, 8, 'Europe', 'http://www.crwflags.com/fotw/images/n/nl.gif'),
#  ('Turkey', 0, 0, 1, 'Europe', 'http://www.crwflags.com/fotw/images/t/tr.gif'),
#  ('Ukraine', 1, 1, 1, 'Europe', 'http://www.crwflags.com/fotw/images/u/ua.gif'),
#  ('United Kingdom', 6, 4, 7, 'Europe', 'http://www.crwflags.com/fotw/images/g/gb.gif'),
#  ('United States', 8, 11, 6, 'North America', 'http://www.crwflags.com/fotw/images/u/us.gif'),
#  ('Uruguay', 1, 1, 1, 'South America', 'http://www.crwflags.com/fotw/images/u/uy.gif'),
#  ('Venezuela', 0, 1, 0, 'South America', 'http://www.crwflags.com/fotw/images/v/ve.gif'),
#  ('Zambia', 1, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/zm.gif'),
#  ('Zimbabwe', 0, 0, 2, 'Southern Africa', 'http://www.crwflags.com/fotw/images/z/zw.gif')]
